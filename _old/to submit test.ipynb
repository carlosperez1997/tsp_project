# %% [markdown]
# # Set up

# %%
from typing import Dict, Tuple, List
from math import sqrt
from dataclasses import dataclass
from gurobipy import Model, GRB, tupledict, LinExpr, GurobiError
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

import numpy as np
import os
import re

from itertools import combinations

from graph_tool import Graph, EdgePropertyMap
from graph_tool.generation import complete_graph
from graph_tool.flow import boykov_kolmogorov_max_flow, min_st_cut

# %% [markdown]
# # Define classes

# %% [markdown]
# ## Data loader

# %%
class TspDataLoader:
    """ Class to load and process data for TSP instances. """

    def __init__(self, dir='data'):
        self.dir = dir

    def load_problem(self, problem):
        """ Load a TSP problem and return its vertices count and cost matrix. """
        file_name = "data/"+problem

        # Read file content
        with open(file_name, 'r') as file:
            content = file.read()

        problem_type = problem.split('.')[-1]

        n = int(re.search(r'\d+', problem).group())
        # 64 is actually 65 
        if n == 64:
            n = 65

        # Process the file content
        data_lines = content.split('\n')

        try:
            start_index = data_lines.index('EDGE_WEIGHT_SECTION')
        except:
            start_index = data_lines.index('NODE_COORD_SECTION')
            
        # Extract the data lines after 'EDGE_WEIGHT_SECTION'
        edge_weight_lines = data_lines[start_index + 1:][:-2]

        # Parse the distance matrix (lines are not rows)
        if problem_type == 'atsp':
            distance_matrix = [list(map(int, line.split())) for line in edge_weight_lines if line.strip()]

            def flatten(l):
                return [item for sublist in l for item in sublist]

            distance_list = flatten(distance_matrix)
            print(len(distance_list))

            my_matrix = np.array(distance_list).reshape((n, n))
            my_matrix.shape
        else:
            try:
                print('has_index')
                ys = [ float(line.split(' ')[3])  for line in edge_weight_lines if line.strip()]
                xs = [ float(line.split(' ')[2])  for line in edge_weight_lines if line.strip()]
            except:
                ys = [ float(line.split(' ')[2])  for line in edge_weight_lines if line.strip()]
                xs = [ float(line.split(' ')[1])  for line in edge_weight_lines if line.strip()]

        for line in data_lines:
            if 'EDGE_WEIGHT_TYPE' in line:
                weight_type = line.split(':')[1].strip()
        print(weight_type)

        V = range(n)
        if problem_type == 'atsp':
            cost = {
                (i, j): my_matrix[i,j]
                for i in V for j in V if i != j
            }
        else:
            if weight_type == 'GEO':
                cost = {
                    (i, j): haversine_distance((xs[i], ys[i]), (xs[j], ys[j]))
                    for i in V for j in V if i != j
                }
            else:
                cost = {
                    (i, j): math.sqrt((xs[i] - xs[j]) ** 2 + (ys[i] - ys[j]) ** 2)
                    for i in V for j in V if i != j
                }

        # Initialize an array to store the 5 closest vertices for each vertex
        closest_vertices_array = []

        # For each vertex, find the 5 closest vertices and add to the array
        for i in V:
            sorted_vertices = sorted(V, key=lambda j: cost[i, j] if i != j else float('inf'))
            closest_vertices_array.append(sorted_vertices[1:6])  # Skip the first one (itself) and take the next five

        return n, cost, closest_vertices_array

# %% [markdown]
# ## Integer solver

# %%
class TspInstance:
    """ An instance of the Travelling Salesman Problem. """

    def __init__(self, n_vertices, cost, closest_vertices_array = None, x=None, y=None):
        """
        Initialize a TSP instance.

        Parameters
        ----------
        n_vertices : int
            Number of vertices in the graph.
        cost : dict[tuple[int, int], float]
            Dictionary with arcs as key, and their corresponding costs as values.
        x : list[float], optional
            X coordinates of the vertices (for plotting).
        y : list[float], optional
            Y coordinates of the vertices (for plotting).
        """
        self.n_vertices = n_vertices
        self.cost = cost
        self.closest_vertices_array = closest_vertices_array if closest_vertices_array is not None else []
        self.x = x if x is not None else []
        self.y = y if y is not None else []
        
@dataclass
class TspSolution:
    """ Solution to an instance of the Travelling Salesman Problem.

        Attributes
        ----------
        instance: TspInstance
            Reference to the TSP instance being solved.
        tour: List[int]
            Ordered list of vertices visited (without repeating the first one).
        cost: float
            Travel cost of the tour.
    """

    instance: TspInstance
    tour: List[int]
    cost: float
    lazy_constraints_added: List[dict]
    model_metrics: Dict

    def plot(self) -> Tuple[Figure, plt.Axes]:
        """ Plots the solution of the TSP.
        
            Vertices are black dots, the solution is represented by red lines.

            Returns
            -------
            A tuple with the figure and axes object from matplotlib.    
        """

        xy = [(self.instance.x[i], self.instance.y[i]) for i in self.tour + [self.tour[0]]]

        fig, ax = plt.subplots(figsize=(10, 10))
        ax.scatter(self.instance.x, self.instance.y, color='black')
        
        for pt1, pt2 in zip(xy[1:], xy[:-1]):
            x1, y1 = pt1
            x2, y2 = pt2
            ax.plot([x1, x2], [y1, y2], color='red')

        ax.set_title(f"TSP Solution. Num vertices: {self.instance.n_vertices}. Tour cost: {self.cost:.2f}.")
        ax.set_axis_off()

        return fig, ax
    
class TspIntegerBCSolver:
    """ 
    Solver for the Travelling Salesman Problem using the branch-and-cut algorithm.

    This solver applies the Dantzig-Fulkerson-Johnson (DFJ) formulation of the TSP
    and focuses on separating subtour elimination constraints (SECs) only on integer solutions.

    Attributes:
    _instance : TspInstance
        The instance of the TSP to be solved.
    _V : List[int]
        List of vertex indices in the TSP instance.
    _A : List[Tuple[int, int]]
        List of arcs (edges between pairs of vertices) in the TSP instance.
    _model : Model
        The Gurobi model for the TSP instance.
    _x : tupledict
        Gurobi variables representing whether an arc is included in the tour.
    """

    def __init__(self, instance: TspInstance, cardinality=None, l = None):
        """
        Initializes the solver with a TSP instance and builds the model.

        Parameters:
        instance (TspInstance): The TSP instance to be solved.
        """
        # Store the TSP instance and create lists of vertices and arcs
        self._instance = instance
        self._V = list(range(self._instance.n_vertices))
        self._A = list(self._instance.cost.keys())
        self.lazy_constraints_added = []  # Initialize an empty list to store lazy constraints
        self.cardinality = cardinality  # Store the cardinality parameter
        self._L = l  # Contraint to be added for l closest vertices


        # Build the optimization model
        self.__build_model()


    def __build_model(self):
        """ 
        Builds the initial DFJ model for the TSP without subtour elimination constraints (SECs).
        """
        # Initialize the Gurobi model
        self._model = Model()
        
        # Set the time limit for the solver (in seconds)
        self._model.setParam(GRB.Param.TimeLimit, 300)  # 300 seconds = 5 minutes

        # Add variables representing whether each arc is included in the tour
        self._x = self._model.addVars(self._A, obj=self._instance.cost, vtype=GRB.BINARY, name='x')

    

        # Add constraints to ensure exactly one outgoing and one incoming arc for each vertex
        self._model.addConstrs((self._x.sum(i, '*') == 1 for i in self._V), name='outgoing')
        self._model.addConstrs((self._x.sum('*', i) == 1 for i in self._V), name='incoming')

        # Question 2: Add constraints to ensure x(i,j) + x(j,k)  <= 1
        if self.cardinality == 2.2 or self.cardinality == 2.3:
            self._model.addConstrs((self._x[i, j] + self._x[j, i] <= 1 for i in self._V for j in self._V if i != j), name='cardinality two')

        # Question 2: Add constraints to ensure x(i,j) + x(j,k) +x(k,i) <= 2
        if self.cardinality == 2.3:
            self._model.addConstrs((self._x[i, j] + self._x[j, k] + self._x[k, i]<= 2 for i in self._V for j in self._V for k in self._V if i != j and j != k and k != i), name='cardinality three')

        # Question 3 constraints of the type (2,L) 
        if self.cardinality == 3.2 or self.cardinality == 3.3 or self.cardinality ==3.4:

            # Add custom constraints for the closest l vertices
            for i in self._V:

                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]

                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    self._model.addConstr(self._x[i, j] + self._x[j, i] <= 1, name=f'closest_constraint_{i}_{j}')

        # Question 3 constraints of the type (3,L) 
        if self.cardinality ==3.3 or self.cardinality ==3.4:

            # Add custom constraints for the closest l vertices
            for i in self._V:

                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]

                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    for k in closest_vertices:
                        if k != j:
                            self._model.addConstr(self._x[i, j] + self._x[j, k] + self._x[k, i]<= 2, name=f'closest_constraint_{i}_{j}_{k}')

        # Question 3 constraints of the type (4,L) 
        if self.cardinality ==3.4:

            # Add custom constraints for the closest l vertices
            for i in self._V:

                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]

                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    for k in closest_vertices:
                            for z in closest_vertices:
                                if j != k and j != z and k != z:
                                    self._model.addConstr(self._x[i, j] + self._x[j, k] + self._x[k, z] + self._x[z, i] <= 3, name=f'closest_constraint_{i}_{j}_{k}_{z}')



    def __next_vertex(self, i: int) -> int:
        """
        Finds the next vertex in the current solution, starting from vertex i.

        Parameters:
        i (int): The starting vertex index.

        Returns:
        int: The index of the next vertex in the tour.
        """
        # Ensure the vertex index is valid
        assert 0 <= i < self._instance.n_vertices

        # Loop through all vertices to find the next one in the tour
        for j in self._V:
            if i != j:
                try:
                    # Inside a callback, retrieve the solution using cbGetSolution
                    val = self._model.cbGetSolution(self._x[i, j])
                except:
                    # Otherwise, access the variable's value directly
                    val = self._x[i, j].X

                # If the arc is part of the solution, return the next vertex
                if val > 0.5:
                    return j

        # If no successor is found, raise an error
        assert False, f"Vertex {j} has no successor?!"

    def __tour_staring_at(self, i: int) -> List[int]:
        """
        Constructs a tour (or subtour) starting at vertex i based on the current solution.

        Parameters:
        i (int): The starting vertex index.

        Returns:
        List[int]: A list of vertex indices representing the tour.
        """
        # Ensure the vertex index is valid
        assert 0 <= i < self._instance.n_vertices

        # Initialize the tour with the starting vertex
        tour = [i]
        current = self.__next_vertex(i)

        # Continue adding vertices to the tour until it loops back to the start
        while current != i:
            tour.append(current)
            current = self.__next_vertex(current)

        return tour

    def __add_sec_for(self, S: List[int]) -> None:
        """
        Adds a subtour elimination constraint (SEC) for the vertices in set S.

        Parameters:
        S (List[int]): A list of vertex indices forming a subtour.
        """
        # Ensure the subtour has a valid number of vertices
        assert 0 < len(S) < self._instance.n_vertices
   
        # Record the constraint information
        constraint_info = {
            'subtour': S,
            'constraint': sum(self._x[i, j] for (i, j) in self._A if i in S and j not in S) >= 1
        }

        self.lazy_constraints_added.append(constraint_info)
        
        # Add the actual lazy constraint to the model
        self._model.cbLazy(sum(self._x[i, j] for (i, j) in self._A if i in S and j not in S) >= 1)

    def __separate(self, where: int) -> None:
        """ Separates eventual violated SECs. """

        if where != GRB.Callback.MIPSOL:
            return
        
        # Set of vertices not yet placed in a tour
        remaining = set(self._V)

        while len(remaining) > 0:
            # Get any vertex in set `remaining`
            current = next(iter(remaining))

            # Get the subtour which includes the vertex
            subtour = self.__tour_staring_at(current)

            # If the tour visits all vertices, nothing to do
            if len(subtour) == self._instance.n_vertices:
                return

            # Otherwise, it's a subtour => Add a SEC
            self.__add_sec_for(subtour)

            # Update set `remaining`
            remaining -= set(subtour)

    def solve(self) -> TspSolution:
        """ Solves the TSP DFJ model and returns the solution.
        
            It throws a RuntimeError if Gurobi cannot solve the model to optimality.

            Returns
            -------
            A TspSolution object with details about the solution.
        """

        # We must set this parameter to use callbacks
        self._model.setParam(GRB.Param.LazyConstraints, 1)

        # Gurobi always passes two parameters to the callback: `model` and `where`
        self._model.optimize(lambda _, where: self.__separate(where))


        if self._model.Status != GRB.OPTIMAL:
            return "Solution not found"
        #    raise RuntimeError(f"Could not find the optimal solution. Gurobi status = {self._model.Status}")

        model_metrics = {} 
        for metric in ["NumVars", "ObjVal", "ObjBound", "IterCount", "SolCount", "NodeCount", "Runtime"]:
            model_metrics[metric] = self._model.getAttr(metric)

        return TspSolution(
            instance=self._instance,
            tour=self.__tour_staring_at(0),
            cost=self._model.ObjVal,
            model_metrics=model_metrics,
            lazy_constraints_added=self.lazy_constraints_added
        )

# %% [markdown]
# # Fractional solver

# %%
class TspFractionalBCSolver:
    """ Solver for the Travelling Salesman Problem.
    
        It uses the branch-and-cut algorithm applied to the "DFJ" formulation.
        Subtour elimination constraints are separated on integer and
        fractional solutions alike.
    """

    _EPS: float = 1e-6

    _instance: TspInstance
    _V: List[int]
    _A: List[Tuple[int, int]]
    _g: Graph
    _cap: EdgePropertyMap
    _model: Model
    _x: tupledict
    _L: int

    def __init__(self, instance: TspInstance, cardinality=None, l = None):
        """ Initialises the solver and builds the model.
        
            Parameters
            ----------
            instance: TspInstance
                The TSP instance.
        """
        self._L = l  # Contraint to be added for l closest vertices
        self._instance = instance
        self._V = list(range(self._instance.n_vertices))
        self._A = list(self._instance.cost.keys())
        self.lazy_constraints_added = []  # Initialize an empty list to store lazy constraints
        self.cardinality = cardinality  # Store the cardinality parameter
        self.__build_graph()
        self.__build_model()


    def __build_graph(self) -> None:
        """ Builds the graph for cut separation. """
        self._g = complete_graph(N=self._instance.n_vertices, self_loops=False, directed=True)
        self._cap = self._g.new_edge_property(value_type='double')
        self._g.edge_properties['cap'] = self._cap       

    def __build_model(self) -> None:
        """ Builds the DFJ model without SECs. """
         
        self._model = Model()
        # Set the time limit for the solver (in seconds)
        self._model.setParam(GRB.Param.TimeLimit, 300)  # 300 seconds = 5 minutes
        self._x = self._model.addVars(self._A, obj=self._instance.cost, vtype=GRB.BINARY, name='x')
        self._model.addConstrs((self._x.sum(i, '*') == 1 for i in self._V), name='outgoing')
        self._model.addConstrs((self._x.sum('*', i) == 1 for i in self._V), name='incoming')

        # Question 2: Add constraints to ensure x(i,j) + x(j,k)  <= 1
        if self.cardinality == 2.2 or self.cardinality == 2.3:
            self._model.addConstrs((self._x[i, j] + self._x[j, i] <= 1 for i in self._V for j in self._V if i != j), name='cardinality two')

        # Question 2: Add constraints to ensure x(i,j) + x(j,k) +x(k,i) <= 2
        if self.cardinality == 2.3:
            self._model.addConstrs((self._x[i, j] + self._x[j, k] + self._x[k, i]<= 2 for i in self._V for j in self._V for k in self._V if i != j and j != k and k != i), name='cardinality three')

        # Question 3 constraints of the type (2,L) 
        if self.cardinality == 3.2 or self.cardinality == 3.3 or self.cardinality ==3.4:

            # Add custom constraints for the closest l vertices
            for i in self._V:

                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]


                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    self._model.addConstr(self._x[i, j] + self._x[j, i] <= 1, name=f'closest_constraint_{i}_{j}')

        # Question 3 constraints of the type (3,L)
        if self.cardinality == 3.3 or self.cardinality == 3.4:
            # Add custom constraints for the closest l vertices
            for i in self._V:
                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]

                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    for k in closest_vertices:
                        if k != j:
                            self._model.addConstr(self._x[i, j] + self._x[j, k] + self._x[k, i] <= 2, name=f'closest_constraint_{i}_{j}_{k}')

        # Question 3 constraints of the type (4,L) 
        if self.cardinality ==3.4:

            # Add custom constraints for the closest l vertices
            for i in self._V:

                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]

                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    for k in closest_vertices:
                            for z in closest_vertices:
                                if j != k and j != z and k != z:
                                    self._model.addConstr(self._x[i, j] + self._x[j, k] + self._x[k, z] + self._x[z, i] <= 3, name=f'closest_constraint_{i}_{j}_{k}_{z}')

    def __next_vertex(self, i: int) -> int:
        """ Gets the vertex visited immediately after i in the current TSP solution.

            This is the (only) vertex j such that x[i,j] == 1. This function works both
            when inside a callback (when the value of x must be retrieved via cbGetSolution)
            and after the optimisation is over (when the value of X can be accessed via X).
        """

        assert 0 <= i < self._instance.n_vertices

        for j in self._V:
            if i != j:
                try:
                    # If inside a call-back, we use cbGetSolution
                    val = self._model.cbGetSolution(self._x[i, j])
                except:
                    # Otherwise we use .X
                    val = self._x[i, j].X

                if val > 0.5:
                    return j

        assert False, f"Vertex {j} has no successor?!"

    def __tour_staring_at(self, i: int) -> List[int]:
        """ Gives the (sub)tour starting at a given vertex i in the current TSP solution. """

        assert 0 <= i < self._instance.n_vertices

        tour = [i]
        current = self.__next_vertex(i)

        while current != i:
            tour.append(current)
            current = self.__next_vertex(current)

        return tour

    def __add_sec_for(self, S: List[int]) -> None:
        """ Adds a Subtour Elimination Constraint for set S. """

        assert 0 < len(S) < self._instance.n_vertices

        self._model.cbLazy(sum(self._x[i, j] for (i, j) in self._A if i in S and j not in S) >= 1)

        # Record the constraint information
        constraint_info = {
            'subtour': S,
            'constraint': sum(self._x[i, j] for (i, j) in self._A if i in S and j not in S) >= 1
        }

        self.lazy_constraints_added.append(constraint_info)

    def __set_capacity(self) -> None:
        """ Sets graph capacity based on current solution. """

        for e in self._g.edges():
            i, j = e.source(), e.target()

            try: # If we are in MIPSOL
                xval = self._model.cbGetSolution(self._x[i,j])
            except: # If we are in MIPNODE
                xval = self._model.cbGetNodeRel(self._x[i,j])

            self._cap[e] = xval

    def __separate(self, where: int) -> None:
        """ Separates eventual violated SECs. """

        if where not in [GRB.Callback.MIPSOL, GRB.Callback.MIPNODE]:
            return

        # In MIPNODE, we must ensure that we have the optimal solution to the
        # linear relaxation at that node. Otherwise we are not "authorised"
        # to call cbGetNodeRel. See:
        # https://www.gurobi.com/documentation/9.1/refman/py_model_cbgetnoderel.html
        if where == GRB.Callback.MIPNODE and self._model.cbGet(GRB.Callback.MIPNODE_STATUS) != GRB.OPTIMAL:
            return
        
        self.__set_capacity()

        source = self._g.vertex(0)
        already_added = set()

        print('Separation round!')

        for i in range(1, self._instance.n_vertices):
            if i in already_added:
                continue

            target = self._g.vertex(i)
            residual = boykov_kolmogorov_max_flow(
                g=self._g, source=source, target=target,
                capacity=self._cap
            )
            
            flow = residual.copy()
            flow.a = self._cap.a - residual.a

            total_flow = sum(flow[a] for a in target.in_edges())

            if total_flow < 1 - self._EPS: # Avoid numerical issues
                print(f"\tFound a subset which violate a SEC (flow = {total_flow:.3f} < 1)")
                
                cut = min_st_cut(g=self._g, source=source,capacity=self._cap, residual=residual)

                assert cut[source] == True
                assert cut[target] == False

                subtour = [j for j in self._V if cut[self._g.vertex(j)] == False]

                assert len(subtour) < self._instance.n_vertices

                print(f"\tSet size: {len(subtour)}")

                self.__add_sec_for(subtour)

                already_added = already_added.union(subtour)

    def solve(self) -> TspSolution:
        """ Solves the TSP DFJ model and returns the solution.
        
            It throws a RuntimeError if Gurobi cannot solve the model to optimality.

            Returns
            -------
            A TspSolution object with details about the solution.
        """

        # We must set this parameter to use callbacks
        self._model.setParam(GRB.Param.LazyConstraints, 1)

        # Gurobi always passes two parameters to the callback: `model` and `where`
        self._model.optimize(lambda _, where: self.__separate(where))

        if self._model.Status != GRB.OPTIMAL:
            return "Solution not found"
        #    raise RuntimeError(f"Could not find the optimal solution. Gurobi status = {self._model.Status}")

        model_metrics = {} 
        for metric in ["NumVars", "ObjVal", "ObjBound", "IterCount", "SolCount", "NodeCount", "Runtime"]:
            model_metrics[metric] = self._model.getAttr(metric)

        return TspSolution(
            instance=self._instance,
            tour=self.__tour_staring_at(0),
            cost=self._model.ObjVal,
            model_metrics=model_metrics,
            lazy_constraints_added=self.lazy_constraints_added
        )

# %% [markdown]
# # Question 1

# %%
# Load data set 1
tsp_loader = TspDataLoader()
n_vertices, cost, closest_vertices_array = tsp_loader.load_problem('rbg323.atsp')
# Out:
# 104329
# EXPLICIT

# %% [markdown]
# ### Solve with interger method

# %%
# interger
from tqdm import tqdm

# Output time and objective value for different number of vertices
vertices_list = range(23, 324, 50)


# Integer
time_list, objective_list, nrows_list, sol_list, iter_list, nvars_list = list(), list(), list(), list(), list(), list()
for vert in tqdm(vertices_list):
    filtered_vertices = vert
    filtered_cost = {(i, j): cost_val for (i, j), cost_val in cost.items() if i < filtered_vertices and j < filtered_vertices}

    i = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s = TspIntegerBCSolver(instance=i, cardinality=None)
    sol = s.solve()

    time_list.append(s._model.Runtime)
    objective_list.append(s._model.ObjVal)
    nrows_list.append(s._model.NumConstrs)
    sol_list.append(sol.model_metrics['SolCount'])
    iter_list.append(sol.model_metrics['IterCount'])
    nvars_list.append(sol.model_metrics['NumVars'])

time_list_int, objective_list_int, nrows_list_int, sol_list_int, iter_list_int, nvars_list_int = time_list, objective_list, nrows_list, sol_list, iter_list, nvars_list

print("INTEGER FINISHED!!!")
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-12
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 46 rows, 506 columns and 1012 nonzeros
# Model fingerprint: 0xd3a534b7
# Variable types: 0 continuous, 506 integer (506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 46 rows, 506 columns, 1012 nonzeros
# Variable types: 0 continuous, 506 integer (506 binary)
#
# Root relaxation: objective 1.920000e+02, 57 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  192.00000    0    -          -  192.00000      -     -    0s
# *    0     0               0     192.0000000  192.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 14
#
# Explored 1 nodes (62 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 192
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.920000000000e+02, best bound 1.920000000000e+02, gap 0.0000%
#
# User-callback calls 112, time in user-callback 0.01 sec
#  14%|█▍        | 1/7 [00:00<00:00,  7.67it/s]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 146 rows, 5256 columns and 10512 nonzeros
# Model fingerprint: 0xa95e0496
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 146 rows, 5256 columns, 10512 nonzeros
# Variable types: 0 continuous, 5256 integer (5256 binary)
#
# Root relaxation: objective 4.710000e+02, 313 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  471.00000    0    -          -  471.00000      -     -    0s
#      0     0  474.00000    0   18          -  474.00000      -     -    0s
# H    0     0                     474.0000000  474.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 51
#
# Explored 1 nodes (321 simplex iterations) in 0.24 seconds (0.03 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 474
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.740000000000e+02, best bound 4.740000000000e+02, gap 0.0000%
#
# User-callback calls 130, time in user-callback 0.19 sec
#  29%|██▊       | 2/7 [00:00<00:01,  4.31it/s]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 246 rows, 15006 columns and 30012 nonzeros
# Model fingerprint: 0x3ba73385
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.03s
# Presolved: 246 rows, 15006 columns, 30012 nonzeros
# Variable types: 0 continuous, 15006 integer (15006 binary)
#
# Root relaxation: objective 9.590000e+02, 715 iterations, 0.01 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  959.00000    0    -          -  959.00000      -     -    0s
#      0     0  959.00000    0    -          -  959.00000      -     -    0s
#      0     0  959.00000    0   59          -  959.00000      -     -    0s
# H    0     0                     959.0000000  959.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 75
#
# Explored 1 nodes (742 simplex iterations) in 0.81 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 959
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.590000000000e+02, best bound 9.590000000000e+02, gap 0.0000%
#
# User-callback calls 155, time in user-callback 0.69 sec
#  43%|████▎     | 3/7 [00:01<00:02,  1.63it/s]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 346 rows, 29756 columns and 59512 nonzeros
# Model fingerprint: 0xdbe6f12a
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.06s
# Presolved: 346 rows, 29756 columns, 59512 nonzeros
# Variable types: 0 continuous, 29756 integer (29756 binary)
#
# Root relaxation: objective 9.080000e+02, 1035 iterations, 0.05 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  908.00000    0    -          -  908.00000      -     -    1s
#      0     0  913.00000    0   22          -  913.00000      -     -    1s
#      0     0  914.00000    0    -          -  914.00000      -     -    2s
#      0     0  914.00000    0   16          -  914.00000      -     -    2s
# H    0     0                     914.0000000  914.00000  0.00%     -    2s
#      0     0  914.00000    0   16  914.00000  914.00000  0.00%     -    2s
#
# Cutting planes:
#   Lazy constraints: 107
#
# Explored 1 nodes (5869 simplex iterations) in 2.22 seconds (0.26 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 914
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.140000000000e+02, best bound 9.140000000000e+02, gap 0.0000%
#
# User-callback calls 227, time in user-callback 1.85 sec
#  57%|█████▋    | 4/7 [00:04<00:04,  1.40s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 446 rows, 49506 columns and 99012 nonzeros
# Model fingerprint: 0x72ee0acb
# Variable types: 0 continuous, 49506 integer (49506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.08s
# Presolved: 446 rows, 49506 columns, 99012 nonzeros
# Variable types: 0 continuous, 49506 integer (49506 binary)
#
# Root relaxation: objective 8.050000e+02, 1043 iterations, 0.19 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  805.00000    0    -          -  805.00000      -     -    2s
#      0     0  805.00000    0    -          -  805.00000      -     -    2s
#      0     0  805.00000    0   89          -  805.00000      -     -    2s
#      0     0  805.00000    0    -          -  805.00000      -     -    4s
#      0     0  805.00000    0    -          -  805.00000      -     -    5s
#      0     0  805.00000    0   10          -  805.00000      -     -    5s
# H    0     0                     805.0000000  805.00000  0.00%     -    5s
#      0     0  805.00000    0   10  805.00000  805.00000  0.00%     -    5s
#
# Cutting planes:
#   Lazy constraints: 141
#
# Explored 1 nodes (5096 simplex iterations) in 5.33 seconds (0.36 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 805
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.050000000000e+02, best bound 8.050000000000e+02, gap 0.0000%
#
# User-callback calls 267, time in user-callback 4.65 sec
#  71%|███████▏  | 5/7 [00:10<00:06,  3.03s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 546 rows, 74256 columns and 148512 nonzeros
# Model fingerprint: 0x0aa858ae
# Variable types: 0 continuous, 74256 integer (74256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.15s
# Presolved: 546 rows, 74256 columns, 148512 nonzeros
# Variable types: 0 continuous, 74256 integer (74256 binary)
#
# Root relaxation: objective 1.072000e+03, 1339 iterations, 0.10 seconds (0.10 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1072.00000    0    -          - 1072.00000      -     -    4s
#      0     0 1072.00000    0   58          - 1072.00000      -     -    4s
#      0     0 1072.00000    0   58          - 1072.00000      -     -    7s
#      0     0 1072.00000    0    -          - 1072.00000      -     -    8s
#      0     0 1072.00000    0    -          - 1072.00000      -     -    9s
#      0     0 1072.00000    0    8          - 1072.00000      -     -    9s
# H    0     0                    1072.0000000 1072.00000  0.00%     -    9s
#      0     0 1072.00000    0    8 1072.00000 1072.00000  0.00%     -    9s
#
# Cutting planes:
#   Lazy constraints: 157
#
# Explored 1 nodes (14492 simplex iterations) in 9.40 seconds (0.66 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1072
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.072000000000e+03, best bound 1.072000000000e+03, gap 0.0000%
#
# User-callback calls 345, time in user-callback 8.14 sec
#  86%|████████▌ | 6/7 [00:20<00:05,  5.48s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 646 rows, 104006 columns and 208012 nonzeros
# Model fingerprint: 0x6de01d01
# Variable types: 0 continuous, 104006 integer (104006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.21s
# Presolved: 646 rows, 104006 columns, 208012 nonzeros
# Variable types: 0 continuous, 104006 integer (104006 binary)
#
# Root relaxation: objective 1.326000e+03, 1691 iterations, 0.17 seconds (0.20 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1326.00000    0    -          - 1326.00000      -     -    6s
#      0     0 1326.00000    0   34          - 1326.00000      -     -    6s
# H    0     0                    1326.0000000 1326.00000  0.00%     -    9s
#      0     0 1326.00000    0   36 1326.00000 1326.00000  0.00%     -    9s
#
# Cutting planes:
#   Lazy constraints: 182
#
# Explored 1 nodes (1723 simplex iterations) in 9.49 seconds (0.67 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1326
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.326000000000e+03, best bound 1.326000000000e+03, gap 0.0000%
#
# User-callback calls 376, time in user-callback 8.56 sec
# 100%|██████████| 7/7 [00:31<00:00,  4.45s/it]
# INTEGER FINISHED!!!

# %% [markdown]
# ### Solve with fractional method

# %%
# Fractional
# Output time and objective value for different number of vertices
time_list, objective_list, nrows_list, sol_list, iter_list, nvars_list = list(), list(), list(), list(), list(), list()

for vert in tqdm(vertices_list):
    filtered_vertices = vert
    filtered_cost = {(i, j): cost_val for (i, j), cost_val in cost.items() if i < filtered_vertices and j < filtered_vertices}

    i = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s = TspFractionalBCSolver(instance=i, cardinality=None)
    sol = s.solve()

    if sol == 'Solution not found':
        time_list.append(300)
        objective_list.append(0)
        nrows_list.append(0)
        sol_list.append(0)
        iter_list.append(0)
        nvars_list.append(0)
        
    else :
        time_list.append(s._model.Runtime)
        objective_list.append(s._model.ObjVal)
        nrows_list.append(s._model.NumConstrs)
        sol_list.append(sol.model_metrics['SolCount'])
        iter_list.append(sol.model_metrics['IterCount'])
        nvars_list.append(sol.model_metrics['NumVars'])

time_list_frac, objective_list_frac, nrows_list_frac, sol_list_frac, iter_list_frac, nvars_list_frac = time_list, objective_list, nrows_list, sol_list, iter_list, nvars_list
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 46 rows, 506 columns and 1012 nonzeros
# Model fingerprint: 0xd3a534b7
# Variable types: 0 continuous, 506 integer (506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Presolve time: 0.02s
# Presolved: 46 rows, 506 columns, 1012 nonzeros
# Variable types: 0 continuous, 506 integer (506 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
#
# Root relaxation: objective 1.920000e+02, 55 iterations, 0.00 seconds (0.00 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  192.00000    0    -          -  192.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     0  192.00000    0    -          -  192.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     0  192.00000    0    -          -  192.00000      -     -    0s
# Separation round!
# *    0     0               0     192.0000000  192.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 4
#
# Explored 1 nodes (64 simplex iterations) in 0.42 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 192
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.920000000000e+02, best bound 1.920000000000e+02, gap 0.0000%
#
# User-callback calls 119, time in user-callback 0.27 sec
#  14%|█▍        | 1/7 [00:00<00:02,  2.08it/s]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 146 rows, 5256 columns and 10512 nonzeros
# Model fingerprint: 0xa95e0496
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 35
# Presolve time: 0.01s
# Presolved: 146 rows, 5256 columns, 10512 nonzeros
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 71
#
# Root relaxation: objective 4.710000e+02, 282 iterations, 0.00 seconds (0.00 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 45
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  471.00000    0    -          -  471.00000      -     -    0s
#      0     0  471.00000    0   48          -  471.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 64
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 31
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 42
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 43
#      0     0  471.00000    0    -          -  471.00000      -     -    1s
#      0     0  471.00000    0   48          -  471.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 40
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 5
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 28
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 36
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 49
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 8
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# *    0     0               0     474.0000000  474.00000  0.00%     -    3s
#
# Cutting planes:
#   Lazy constraints: 24
#
# Explored 1 nodes (291 simplex iterations) in 3.59 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 474
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.740000000000e+02, best bound 4.740000000000e+02, gap 0.0000%
#
# User-callback calls 215, time in user-callback 3.34 sec
#  29%|██▊       | 2/7 [00:04<00:12,  2.48s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 246 rows, 15006 columns and 30012 nonzeros
# Model fingerprint: 0x3ba73385
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 56
# Presolve time: 0.04s
# Presolved: 246 rows, 15006 columns, 30012 nonzeros
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 121
#
# Root relaxation: objective 9.590000e+02, 765 iterations, 0.05 seconds (0.02 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 56
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  959.00000    0    -          -  959.00000      -     -    1s
#      0     0  959.00000    0   46          -  959.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 53
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 32
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.625 < 1)
# 	Set size: 26
# 	Found a subset which violate a SEC (flow = 0.375 < 1)
# 	Set size: 15
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 19
#      0     0  959.00000    0    -          -  959.00000      -     -    3s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 34
#      0     0  959.00000    0    -          -  959.00000      -     -    4s
#      0     0  959.00000    0   20          -  959.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 17
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 21
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 88
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 81
#      0     0  959.00000    0   20          -  959.00000      -     -    6s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 84
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 65
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 65
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 100
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 15
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     2  959.00000    0    8          -  959.00000      -     -   10s
# Separation round!
# Separation round!
# *    1     0               1     959.0000000  959.00000  0.00%   7.0   11s
# Separation round!
# 	Found a subset which violate a SEC (flow = -0.000 < 1)
# 	Set size: 10
#
# Cutting planes:
#   Lazy constraints: 25
#
# Explored 3 nodes (2923 simplex iterations) in 12.30 seconds (0.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 959
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.590000000000e+02, best bound 9.590000000000e+02, gap 0.0000%
#
# User-callback calls 343, time in user-callback 11.58 sec
#  43%|████▎     | 3/7 [00:16<00:28,  7.05s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 346 rows, 29756 columns and 59512 nonzeros
# Model fingerprint: 0xdbe6f12a
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 122
# Presolve time: 0.05s
# Presolved: 346 rows, 29756 columns, 59512 nonzeros
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 171
#
# Root relaxation: objective 9.080000e+02, 1113 iterations, 0.05 seconds (0.06 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 84
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  908.00000    0    -          -  908.00000      -     -    1s
#      0     0  908.00000    0   44          -  908.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 61
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 37
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 73
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# 	Found a subset which violate a SEC (flow = 0.889 < 1)
# 	Set size: 9
#      0     0  908.00000    0    -          -  908.00000      -     -    6s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
#      0     0  908.00000    0    -          -  908.00000      -     -    6s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 40
#      0     0  908.00000    0    -          -  908.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
#      0     0  908.00000    0    -          -  908.00000      -     -    8s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 41
#      0     0  913.00000    0    -          -  913.00000      -     -    9s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#      0     0  913.00000    0    -          -  913.00000      -     -   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39
#      0     0  913.00000    0    -          -  913.00000      -     -   11s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     0  913.00000    0    -          -  913.00000      -     -   12s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39
#      0     0  914.00000    0    -          -  914.00000      -     -   13s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 37
#      0     0  914.00000    0    -          -  914.00000      -     -   13s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     0  914.00000    0    -          -  914.00000      -     -   14s
# Separation round!
# *    0     0               0     914.0000000  914.00000  0.00%     -   15s
#
# Cutting planes:
#   Lazy constraints: 18
#
# Explored 1 nodes (5038 simplex iterations) in 15.66 seconds (0.26 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 914
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.140000000000e+02, best bound 9.140000000000e+02, gap 0.0000%
#
# User-callback calls 256, time in user-callback 15.26 sec
#  57%|█████▋    | 4/7 [00:32<00:31, 10.59s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 446 rows, 49506 columns and 99012 nonzeros
# Model fingerprint: 0x72ee0acb
# Variable types: 0 continuous, 49506 integer (49506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 76
# Presolve time: 0.07s
# Presolved: 446 rows, 49506 columns, 99012 nonzeros
# Variable types: 0 continuous, 49506 integer (49506 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 221
#
# Root relaxation: objective 8.050000e+02, 1036 iterations, 0.06 seconds (0.07 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 209
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  805.00000    0    -          -  805.00000      -     -    3s
#      0     0  805.00000    0   22          -  805.00000      -     -    3s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 211
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 219
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 130
#      0     0  805.00000    0   22          -  805.00000      -     -    6s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 32
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 186
#      0     0  805.00000    0    -          -  805.00000      -     -    8s
#      0     0  805.00000    0   14          -  805.00000      -     -    8s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 61
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 93
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 181
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 94
#      0     0  805.00000    0   14          -  805.00000      -     -   14s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 38
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 104
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 57
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
#      0     2  805.00000    0    8          -  805.00000      -     -   21s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 137
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 73
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      3     6  805.00000    2   10          -  805.00000      -  14.0   29s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 25
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 50
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# Separation round!
# *    6     2               3     805.0000000  805.00000  0.00%  20.8   39s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 55
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 63
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 81
#      9     2     cutoff    3       805.00000  805.00000  0.00%  16.8   46s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 60
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 48
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 53
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
#
# Cutting planes:
#   Lazy constraints: 27
#
# Explored 12 nodes (2020 simplex iterations) in 52.69 seconds (0.93 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 805
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.050000000000e+02, best bound 8.050000000000e+02, gap 0.0000%
#
# User-callback calls 458, time in user-callback 51.30 sec
#  71%|███████▏  | 5/7 [01:26<00:52, 26.06s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 546 rows, 74256 columns and 148512 nonzeros
# Model fingerprint: 0x0aa858ae
# Variable types: 0 continuous, 74256 integer (74256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 203
# Presolve time: 0.16s
# Presolved: 546 rows, 74256 columns, 148512 nonzeros
# Variable types: 0 continuous, 74256 integer (74256 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 271
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.460000e+02   0.000000e+00      5s
#     1331    1.0720000e+03   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 1.072000e+03, 1331 iterations, 0.14 seconds (0.12 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 76
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1072.00000    0    -          - 1072.00000      -     -    8s
#      0     0 1072.00000    0   86          - 1072.00000      -     -    8s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 242
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 148
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 43
#      0     0 1072.00000    0   86          - 1072.00000      -     -   15s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 7
# 	Found a subset which violate a SEC (flow = 0.300 < 1)
# 	Set size: 37
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 33
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 11
# 	Found a subset which violate a SEC (flow = 0.900 < 1)
# 	Set size: 19
#      0     0 1072.00000    0    -          - 1072.00000      -     -   19s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 163
#      0     0 1072.00000    0    -          - 1072.00000      -     -   21s
#      0     0 1072.00000    0   18          - 1072.00000      -     -   21s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 218
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 151
#      0     0 1072.00000    0   18          - 1072.00000      -     -   27s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 41
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 98
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 40
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 143
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 177
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 123
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 116
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 170
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 120
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 113
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 64
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 175
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 10
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 121
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 118
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 168
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 114
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 57
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 111
# Separation round!
# *    0     0               0    1072.0000000 1072.00000  0.00%     -  101s
#
# Cutting planes:
#   Lazy constraints: 40
#
# Explored 1 nodes (5792 simplex iterations) in 101.78 seconds (1.60 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1072
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.072000000000e+03, best bound 1.072000000000e+03, gap 0.0000%
#
# User-callback calls 689, time in user-callback 99.17 sec
#  86%|████████▌ | 6/7 [03:09<00:52, 52.32s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 646 rows, 104006 columns and 208012 nonzeros
# Model fingerprint: 0x6de01d01
# Variable types: 0 continuous, 104006 integer (104006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 245
# Presolve time: 0.16s
# Presolved: 646 rows, 104006 columns, 208012 nonzeros
# Variable types: 0 continuous, 104006 integer (104006 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 321
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity      0.0000000e+00      5s
#        1        855   2.5000000e+08   1.2350000e+02      5s
#        2       1423   2.3800001e+08   2.4050000e+02      5s
#        3       1713   2.1800003e+08   3.4500000e+02      5s
#        4       1963   2.1000003e+08   4.4600001e+02      5s
#        5       2200   2.0200005e+08   5.4199971e+02      5s
#        6       2435   1.9400006e+08   6.3899962e+02      5s
#        7       2680   1.7600012e+08   7.1649980e+02      5s
#        8       2926   1.6800014e+08   7.9249965e+02      5s
#        9       3199   1.5800017e+08   8.5799896e+02      5s
#       10       3460   1.4600021e+08   9.1099943e+02      5s
#       11       3774   1.1400035e+08   9.2949914e+02      5s
#       12       4089   9.8000406e+07   9.4849910e+02      5s
#       13       4481   8.4000463e+07   9.8399966e+02      5s
#       14       4751   7.6000509e+07   1.0009993e+03      5s
#       15       5067   6.4000573e+07   1.0104987e+03      5s
#       16       5428   5.8000597e+07   1.0234985e+03      5s
#       17       5803   5.4000614e+07   1.0419983e+03      5s
#       18       6097   5.0000640e+07   1.0579977e+03      5s
#       19       6737   2.4000866e+07   1.0414981e+03      5s
#       20       7176   1.8000896e+07   1.0404978e+03      5s
#       21       7683   1.4000926e+07   1.0474980e+03      5s
#       22       8067   1.2000947e+07   1.0534981e+03      5s
#       23       8555   1.0000969e+07   1.0469984e+03      5s
#       24       8933   1.0000958e+07   1.0519984e+03      5s
#       25       9366   2.0010540e+06   1.0529984e+03      5s
#       26       9753   2.0010540e+06   1.0549984e+03      5s
#       27      10135   1.0810005e+03   1.0566072e+03      5s
#
# Sifting complete
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    10527    1.3260000e+03   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 1.326000e+03, 10527 iterations, 0.27 seconds (0.18 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 23
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1326.00000    0    -          - 1326.00000      -     -   10s
#      0     0 1326.00000    0   22          - 1326.00000      -     -   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 304
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 226
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 269
#      0     0 1326.00000    0   22          - 1326.00000      -     -   17s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 87
#      0     0 1326.00000    0   22          - 1326.00000      -     -   21s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 269
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
#      0     0 1326.00000    0    -          - 1326.00000      -     -   28s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     0 1326.00000    0    -          - 1326.00000      -     -   32s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
#      0     0 1326.00000    0    -          - 1326.00000      -     -   37s
# Separation round!
# *    0     0               0    1326.0000000 1326.00000  0.00%     -   41s
#
# Cutting planes:
#   Lazy constraints: 9
#
# Explored 1 nodes (15932 simplex iterations) in 41.22 seconds (0.78 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1326
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.326000000000e+03, best bound 1.326000000000e+03, gap 0.0000%
#
# User-callback calls 489, time in user-callback 40.15 sec
# 100%|██████████| 7/7 [03:52<00:00, 33.14s/it]

# %% [markdown]
# ### Output table

# %%
# !pip install pandas
# !pip install Jinja2
# Out:
# Requirement already satisfied: pandas in /Users/jonnycodd/anaconda3/envs/tsp/lib/python3.11/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in /Users/jonnycodd/anaconda3/envs/tsp/lib/python3.11/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jonnycodd/anaconda3/envs/tsp/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/jonnycodd/anaconda3/envs/tsp/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/jonnycodd/anaconda3/envs/tsp/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/jonnycodd/anaconda3/envs/tsp/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: Jinja2 in /Users/jonnycodd/anaconda3/envs/tsp/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jonnycodd/anaconda3/envs/tsp/lib/python3.11/site-packages (from Jinja2) (2.1.3)

# %%
import pandas as pd


int_df = pd.DataFrame({'time': time_list_int, 'obj': objective_list_int, 'rows': nrows_list_int, 'iter': iter_list_int})
int_df['type'] = 'integer'

frac_df = pd.DataFrame({'time': time_list_frac, 'obj': objective_list_frac, 'rows': nrows_list_frac, 'iter': iter_list_frac})
frac_df['type'] = 'fractional'


pd.concat([int_df, frac_df], axis='rows').to_csv('question 1.csv')

latex_table_temp = pd.concat([int_df, frac_df], axis='rows')
latex_table = latex_table_temp.to_latex(index = False)

# %% [markdown]
# ### Graphing time taken to solve

# %%
# Plotting the graph of computational time
plt.figure(figsize=(10, 6))
plt.plot(vertices_list, time_list_int, marker='o', label = 'Integer Model')
plt.plot(vertices_list, time_list_frac, marker='x', label = 'Fractional Model')
plt.xlabel('Number of Vertices')
plt.ylabel('Computation Time (seconds)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Question 2
# ### Integer Implementation

# %%
time_list_none = time_list_int
iter_list_none = iter_list_int

# %%
# Output time and objective value for different number of vertices
time_list_2 = list()
time_list_3 = list()

iter_list_2 = list()
iter_list_3 = list()

objective_list_2 = list()
objective_list_3 = list()

# %%
# Cardinality 2
vertices_list = range(23, 324, 50)
for vert in vertices_list:
    filtered_vertices = vert
    filtered_cost = {(i, j): cost_val for (i, j), cost_val in cost.items() if i < filtered_vertices and j < filtered_vertices}

    print(vert)

    i_2 = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s_2 = TspIntegerBCSolver(instance=i_2, cardinality=2.2)
    solution_2 = s_2.solve()

    if solution_2 == 'Solution not found':
        time_list_2.append(300)
        iter_list_2.append(0)
        objective_list_2.append(0)
    else:
        time_list_2.append(s_2._model.Runtime)
        iter_list_2.append(solution_2.model_metrics['IterCount'])
        objective_list_3.append(s_2._model.ObjVal)
# Out:
# 23
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 552 rows, 506 columns and 2024 nonzeros
# Model fingerprint: 0xb009aa87
# Variable types: 0 continuous, 506 integer (506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 253 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 299 rows, 506 columns, 1518 nonzeros
# Variable types: 0 continuous, 506 integer (506 binary)
#
# Root relaxation: objective 1.920000e+02, 67 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  192.00000    0    -          -  192.00000      -     -    0s
# *    0     0               0     192.0000000  192.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 7
#
# Explored 1 nodes (68 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 192
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.920000000000e+02, best bound 1.920000000000e+02, gap 0.0000%
#
# User-callback calls 143, time in user-callback 0.01 sec
# 73
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5402 rows, 5256 columns and 21024 nonzeros
# Model fingerprint: 0x145bbeba
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 2628 rows and 0 columns
# Presolve time: 0.04s
# Presolved: 2774 rows, 5256 columns, 15768 nonzeros
# Variable types: 0 continuous, 5256 integer (5256 binary)
#
# Root relaxation: objective 4.740000e+02, 303 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  474.00000    0    -          -  474.00000      -     -    0s
#      0     0  474.00000    0   20          -  474.00000      -     -    0s
#      0     0  474.00000    0   22          -  474.00000      -     -    0s
# H    0     0                     474.0000000  474.00000  0.00%     -    0s
#      0     0  474.00000    0   22  474.00000  474.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Lazy constraints: 34
#
# Explored 1 nodes (316 simplex iterations) in 0.49 seconds (0.11 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 474
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.740000000000e+02, best bound 4.740000000000e+02, gap 0.0000%
#
# User-callback calls 220, time in user-callback 0.28 sec
# 123
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 15252 rows, 15006 columns and 60024 nonzeros
# Model fingerprint: 0x394f57ed
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 7503 rows and 0 columns
# Presolve time: 0.10s
# Presolved: 7749 rows, 15006 columns, 45018 nonzeros
# Variable types: 0 continuous, 15006 integer (15006 binary)
#
# Root relaxation: objective 9.590000e+02, 682 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  959.00000    0    -          -  959.00000      -     -    0s
# *    0     0               0     959.0000000  959.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 32
#
# Explored 1 nodes (688 simplex iterations) in 0.64 seconds (0.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 959
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.590000000000e+02, best bound 9.590000000000e+02, gap 0.0000%
#
# User-callback calls 184, time in user-callback 0.44 sec
# 173
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 30102 rows, 29756 columns and 119024 nonzeros
# Model fingerprint: 0xa9e213cb
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 14878 rows and 0 columns
# Presolve time: 0.20s
# Presolved: 15224 rows, 29756 columns, 89268 nonzeros
# Variable types: 0 continuous, 29756 integer (29756 binary)
#
# Root relaxation: objective 9.080000e+02, 862 iterations, 0.06 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  908.00000    0    -          -  908.00000      -     -    1s
#      0     0  914.00000    0   32          -  914.00000      -     -    1s
#      0     0  914.00000    0    -          -  914.00000      -     -    2s
#      0     0  914.00000    0    8          -  914.00000      -     -    2s
# H    0     0                     914.0000000  914.00000  0.00%     -    2s
#      0     0  914.00000    0    8  914.00000  914.00000  0.00%     -    2s
#
# Cutting planes:
#   Lazy constraints: 70
#
# Explored 1 nodes (1644 simplex iterations) in 2.96 seconds (0.57 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 914
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.140000000000e+02, best bound 9.140000000000e+02, gap 0.0000%
#
# User-callback calls 329, time in user-callback 2.21 sec
# 223
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 49952 rows, 49506 columns and 198024 nonzeros
# Model fingerprint: 0x2f1b9a6b
# Variable types: 0 continuous, 49506 integer (49506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 24753 rows and 0 columns
# Presolve time: 0.29s
# Presolved: 25199 rows, 49506 columns, 148518 nonzeros
# Variable types: 0 continuous, 49506 integer (49506 binary)
# Root relaxation presolved: 25255 rows, 49506 columns, 149184 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 8.050000e+02, 3274 iterations, 0.16 seconds (0.15 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  805.00000    0    -          -  805.00000      -     -    2s
#      0     0  805.00000    0   18          -  805.00000      -     -    2s
# H    0     0                    1147.0000000  805.00000  29.8%     -    2s
# H    0     0                    1077.0000000  805.00000  25.3%     -    3s
#      0     0  805.00000    0    - 1077.00000  805.00000  25.3%     -    3s
#      0     0  805.00000    0   28 1077.00000  805.00000  25.3%     -    4s
#      0     0  805.00000    0   28 1077.00000  805.00000  25.3%     -    5s
#      0     2  805.00000    0    8 1077.00000  805.00000  25.3%     -    8s
# *    1     0               1     805.0000000  805.00000  0.00%   1.0    8s
#
# Cutting planes:
#   Lazy constraints: 93
#
# Explored 3 nodes (5080 simplex iterations) in 8.30 seconds (1.64 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 805 1077 1147
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.050000000000e+02, best bound 8.050000000000e+02, gap 0.0000%
#
# User-callback calls 707, time in user-callback 6.25 sec
# 273
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 74802 rows, 74256 columns and 297024 nonzeros
# Model fingerprint: 0x75d9b87b
# Variable types: 0 continuous, 74256 integer (74256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 37128 rows and 0 columns
# Presolve time: 0.55s
# Presolved: 37674 rows, 74256 columns, 222768 nonzeros
# Variable types: 0 continuous, 74256 integer (74256 binary)
# Root relaxation presolved: 37742 rows, 74256 columns, 223596 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.04s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.072000e+03, 3582 iterations, 0.27 seconds (0.26 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1072.00000    0    -          - 1072.00000      -     -    4s
# *    0     0               0    1072.0000000 1072.00000  0.00%     -    4s
#
# Cutting planes:
#   Lazy constraints: 69
#
# Explored 1 nodes (3585 simplex iterations) in 4.12 seconds (1.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1072
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.072000000000e+03, best bound 1.072000000000e+03, gap 0.0000%
#
# User-callback calls 346, time in user-callback 3.07 sec
# 323
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 104652 rows, 104006 columns and 416024 nonzeros
# Model fingerprint: 0x9be21f22
# Variable types: 0 continuous, 104006 integer (104006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 52003 rows and 0 columns
# Presolve time: 0.73s
# Presolved: 52649 rows, 104006 columns, 312018 nonzeros
# Variable types: 0 continuous, 104006 integer (104006 binary)
# Root relaxation presolved: 52730 rows, 104006 columns, 312984 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.04s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.326000e+03, 4245 iterations, 0.38 seconds (0.34 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1326.00000    0    -          - 1326.00000      -     -    6s
#      0     0 1326.00000    0    -          - 1326.00000      -     -    7s
#      0     0 1326.00000    0   24          - 1326.00000      -     -    7s
# H    0     0                    1326.0000000 1326.00000  0.00%     -    9s
#
# Cutting planes:
#   Lazy constraints: 92
#
# Explored 1 nodes (4303 simplex iterations) in 9.98 seconds (1.52 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1326
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.326000000000e+03, best bound 1.326000000000e+03, gap 0.0000%
#
# User-callback calls 530, time in user-callback 8.34 sec

# %%
# Cardinality 3
vertices_list = range(23, 272, 50)
for vert in vertices_list:
    filtered_vertices = vert
    filtered_cost = {(i, j): cost_val for (i, j), cost_val in cost.items() if i < filtered_vertices and j < filtered_vertices}

    print(vert)
    
    i_3 = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s_3 = TspIntegerBCSolver(instance=i_3, cardinality=2.3)
    solution_3 = s_3.solve()

    if solution_3 == 'Solution not found':
        time_list_3.append(300)
        objective_list_3.append(0)
        iter_list_3.append(0)
    else:
        time_list_3.append(s_3._model.Runtime)
        objective_list_3.append(s_3._model.ObjVal)
        iter_list_3.append(solution_3.model_metrics['IterCount'])
# Out:
# 23
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 11178 rows, 506 columns and 33902 nonzeros
# Model fingerprint: 0xc1811a43
# Variable types: 0 continuous, 506 integer (506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Found heuristic solution: objective 407.0000000
# Presolve removed 7337 rows and 0 columns
# Presolve time: 0.04s
# Presolved: 3841 rows, 506 columns, 12144 nonzeros
# Variable types: 0 continuous, 506 integer (506 binary)
# Root relaxation presolved: 3841 rows, 506 columns, 12144 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 1.920000e+02, 49 iterations, 0.05 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  192.00000    0    -  407.00000  192.00000  52.8%     -    0s
#      0     0  192.00000    0    8  407.00000  192.00000  52.8%     -    0s
# H    0     0                     192.0000000  192.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 3
#
# Explored 1 nodes (56 simplex iterations) in 0.15 seconds (0.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 192 407
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.920000000000e+02, best bound 1.920000000000e+02, gap 0.0000%
#
# User-callback calls 166, time in user-callback 0.01 sec
# 73
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 378578 rows, 5256 columns and 1140552 nonzeros
# Model fingerprint: 0xe76d9a0c
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 251412 rows and 0 columns
# Presolve time: 2.37s
# Presolved: 127166 rows, 5256 columns, 388944 nonzeros
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Root relaxation presolved: 127189 rows, 5256 columns, 390604 nonzeros
#
#
# Root relaxation: objective 4.740000e+02, 332 iterations, 0.23 seconds (0.16 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  474.00000    0    -          -  474.00000      -     -    3s
# *    0     0               0     474.0000000  474.00000  0.00%     -    3s
#
# Cutting planes:
#   Lazy constraints: 27
#
# Explored 1 nodes (337 simplex iterations) in 3.38 seconds (2.58 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 474
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.740000000000e+02, best bound 4.740000000000e+02, gap 0.0000%
#
# User-callback calls 520, time in user-callback 0.22 sec
# 123
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1830978 rows, 15006 columns and 5507202 nonzeros
# Model fingerprint: 0xaf2b8f60
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 1217987 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 1217987 rows and 0 columns
# Presolve time: 8.98s
# Presolved: 612991 rows, 15006 columns, 1860744 nonzeros
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Root relaxation presolved: 613028 rows, 15006 columns, 1863914 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.7700000e+02   3.000000e+00   9.000977e+06     13s
#      810    9.5900000e+02   0.000000e+00   0.000000e+00     14s
# Concurrent spin time: 0.20s
#
# Solved with dual simplex
#
# Root relaxation: objective 9.590000e+02, 889 iterations, 2.52 seconds (1.36 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  959.00000    0    -          -  959.00000      -     -   14s
#      0     0  959.00000    0   38          -  959.00000      -     -   15s
#      0     0  959.00000    0   38          -  959.00000      -     -   20s
# *    0     0               0     959.0000000  959.00000  0.00%     -   24s
#
# Cutting planes:
#   Gomory: 1
#   Lazy constraints: 51
#
# Explored 1 nodes (906 simplex iterations) in 24.54 seconds (15.71 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 959
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.590000000000e+02, best bound 9.590000000000e+02, gap 0.0000%
#
# User-callback calls 2412, time in user-callback 1.03 sec
# 173
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5118378 rows, 29756 columns and 15383852 nonzeros
# Model fingerprint: 0xb74ba7a6
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 3407062 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 3407062 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 3407062 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 3407062 rows and 0 columns (presolve time = 21s) ...
# Presolve removed 3407062 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 3407062 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 3407062 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 3407062 rows and 0 columns (presolve time = 40s) ...
# Presolve removed 3407062 rows and 0 columns (presolve time = 45s) ...
# Presolve removed 3407062 rows and 0 columns
# Presolve time: 45.88s
# Presolved: 1711316 rows, 29756 columns, 5177544 nonzeros
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Root relaxation presolved: 1711365 rows, 29756 columns, 5183646 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Concurrent spin time: 0.92s
#
# Solved with dual simplex
#
# Root relaxation: objective 9.133333e+02, 847 iterations, 20.03 seconds (2.81 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  913.33333    0    8          -  913.33333      -     -   81s
#      0     0  913.33333    0    8          -  913.33333      -     -  109s
#      0     0  914.00000    0   30          -  914.00000      -     -  128s
#      0     0  914.00000    0    -          -  914.00000      -     -  144s
#      0     0  914.00000    0   18          -  914.00000      -     -  148s
# H    0     0                     914.0000000  914.00000  0.00%     -  149s
#      0     0  914.00000    0   18  914.00000  914.00000  0.00%     -  149s
#
# Cutting planes:
#   Zero half: 1
#   Lazy constraints: 57
#
# Explored 1 nodes (1770 simplex iterations) in 149.60 seconds (50.15 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 914
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.140000000000e+02, best bound 9.140000000000e+02, gap 0.0000%
#
# User-callback calls 5297, time in user-callback 3.32 sec
# 223
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 10990778 rows, 49506 columns and 33020502 nonzeros
# Model fingerprint: 0x3379d828
# Variable types: 0 continuous, 49506 integer (49506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 0 rows and 0 columns (presolve time = 7s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 7318637 rows and 0 columns (presolve time = 18s) ...
# Presolve removed 7318637 rows and 0 columns (presolve time = 24s) ...
# Presolve removed 7318637 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 7318637 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 7318637 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 7318637 rows and 0 columns (presolve time = 40s) ...
# Presolve removed 7318637 rows and 0 columns (presolve time = 45s) ...
# Presolve removed 7318637 rows and 0 columns (presolve time = 50s) ...
# Presolve removed 7318637 rows and 0 columns (presolve time = 55s) ...
# Presolve removed 7318637 rows and 0 columns (presolve time = 60s) ...
# Presolve removed 7318637 rows and 0 columns (presolve time = 65s) ...
# Presolve removed 7318637 rows and 0 columns (presolve time = 71s) ...
# Presolve removed 7318637 rows and 0 columns (presolve time = 75s) ...
# Presolve removed 7318637 rows and 0 columns (presolve time = 80s) ...
# Presolve removed 7318637 rows and 0 columns (presolve time = 85s) ...
# Presolve removed 7318637 rows and 0 columns (presolve time = 91s) ...
# Presolve removed 7318637 rows and 0 columns
# Presolve time: 90.60s
# Presolved: 3672141 rows, 49506 columns, 11089344 nonzeros
# Variable types: 0 continuous, 49506 integer (49506 binary)
# Root relaxation presolved: 3672199 rows, 49506 columns, 11095298 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Concurrent spin time: 0.31s
#
# Solved with dual simplex
#
# Root relaxation: objective 8.050000e+02, 743 iterations, 40.76 seconds (5.20 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  805.00000    0    -          -  805.00000      -     -  156s
#      0     0  805.00000    0    -          -  805.00000      -     -  160s
#      0     0  805.00000    0   36          -  805.00000      -     -  164s
#      0     0  805.00000    0    -          -  805.00000      -     -  270s
#      0     0  805.00000    0   34          -  805.00000      -     -  280s
#      0     0  805.00000    0   34          -  805.00000      -     -  289s
#
# Cutting planes:
#   Lazy constraints: 75
#
# Explored 1 nodes (1463 simplex iterations) in 301.28 seconds (108.88 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 8.050000000000e+02, gap -
#
# User-callback calls 10958, time in user-callback 6.82 sec

# %%
vertices_list_2 = range(273, 324, 50)

for vert in vertices_list_2:
    time_list_3.append(300)
    iter_list_3.append(0)
    objective_list_3.append(0)

# %% [markdown]
# ### Output to table

# %%
time_list_2
# Out:
# [0.029508113861083984,
#  0.4967479705810547,
#  0.650475025177002,
#  2.972564935684204,
#  8.303906917572021,
#  4.1245410442352295,
#  10.007158994674683]

# %%
time_list_3
# Out:
# []

# %%
int_no_cons = pd.DataFrame({'time': time_list_int, 'obj': objective_list_int, 'iter': iter_list_int})
int_no_cons['type'] = 'No constraints'

int_card_2 = pd.DataFrame({'time': time_list_2, 'obj': objective_list_2, 'iter': iter_list_2})
int_card_2 ['type'] = 'Cardinaility 2'


int_card_3 = pd.DataFrame({'time': time_list_3, 'obj': objective_list_3, 'iter': iter_list_3})
int_card_3 ['type'] = 'Cardinaility 3'


pd.concat([int_no_cons, int_card_2, int_card_3], axis='rows').to_csv('question 2 - int.csv')

latex_table_temp = pd.concat([int_no_cons, int_card_2, int_card_3])
latex_table_2_int = latex_table_temp.to_latex(index = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 4
#       1 int_no_cons = pd.DataFrame({'time': time_list_int, 'obj': objective_list_int, 'iter': iter_list_int})
#       2 int_no_cons['type'] = 'No constraints'
# ----> 4 int_card_2 = pd.DataFrame({'time': time_list_2, 'obj': objective_list_2, 'iter': iter_list_2})
#       5 int_card_2 ['type'] = 'Cardinaility 2'
#       8 int_card_3 = pd.DataFrame({'time': time_list_3, 'obj': objective_list_3, 'iter': iter_list_3})
#
# File ~/anaconda3/envs/tsp/lib/python3.11/site-packages/pandas/core/frame.py:733, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     727     mgr = self._init_mgr(
#     728         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     729     )
#     731 elif isinstance(data, dict):
#     732     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 733     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     734 elif isinstance(data, ma.MaskedArray):
#     735     from numpy.ma import mrecords
#
# File ~/anaconda3/envs/tsp/lib/python3.11/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/anaconda3/envs/tsp/lib/python3.11/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~/anaconda3/envs/tsp/lib/python3.11/site-packages/pandas/core/internals/construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %% [markdown]
# ### Graph computational time

# %%
# Plotting the graph of computational time
plt.figure(figsize=(10, 6))
plt.plot(vertices_list, time_list_none, marker='o', label = "No Additional Contraints")
plt.plot(vertices_list, time_list_2, marker='x', label = "Cardinality 2 SEC")
plt.plot(vertices_list, time_list_3, marker='s', label = "Cardinality 3 SEC")
plt.xlabel('Number of Vertices')
plt.ylabel('Computation Time (seconds)')
#plt.title('Computation Time vs Number of Vertices in TSP')
plt.legend()
plt.grid(True)
plt.show()


for i in range(len(objective_list_none)):
        
        assert objective_list_none[i]==objective_list_2[i]

# %% [markdown]
# ### Fractional

# %%
time_list_none_f = time_list_frac
time_list_2_f = list()
time_list_3_f = list()

objective_list_none_f = objective_list_frac
objective_list_2_f = list()
objective_list_3_f = list()

nrows_list_none_f = nrows_list_frac
nrows_list_2_f = list()
nrows_list_3_f = list()

iter_list_none_f = iter_list_frac
iter_list_2_f = list()
iter_list_3_f= list()

# Cardinality 2
for vert in vertices_list:
    filtered_vertices = vert
    filtered_cost = {(i, j): cost_val for (i, j), cost_val in cost.items() if i < filtered_vertices and j < filtered_vertices}
    print(vert)

    i_2 = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s_2 = TspFractionalBCSolver(instance=i_2, cardinality=2.2)
    solution_2 = s_2.solve()

    if solution_2 == 'Solution not found':
        time_list_2_f.append(300)
        #objective_list_2_f.append(0)
        #nrows_list_2_f.append(0)
        iter_list_2_f.append(0)
    else:
        time_list_2_f.append(s_2._model.Runtime)
        #objective_list_2_f.append(s_2._model.ObjVal)
        #nrows_list_2_f.append(s_2._model.NumConstrs)
        iter_list_2_f.append(solution_2.model_metrics['IterCount'])
# Out:
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 552 rows, 506 columns and 2024 nonzeros
# Model fingerprint: 0xb009aa87
# Variable types: 0 continuous, 506 integer (506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Presolve removed 253 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 299 rows, 506 columns, 1518 nonzeros
# Variable types: 0 continuous, 506 integer (506 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 19
#
# Root relaxation: objective 1.920000e+02, 66 iterations, 0.00 seconds (0.00 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  192.00000    0    -          -  192.00000      -     -    0s
# Separation round!
# *    0     0               0     192.0000000  192.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 2
#
# Explored 1 nodes (69 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 192
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.920000000000e+02, best bound 1.920000000000e+02, gap 0.0000%
#
# User-callback calls 143, time in user-callback 0.04 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 11178 rows, 506 columns and 33902 nonzeros
# Model fingerprint: 0xc1811a43
# Variable types: 0 continuous, 506 integer (506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# Found heuristic solution: objective 407.0000000
# Presolve removed 7337 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 3841 rows, 506 columns, 12144 nonzeros
# Variable types: 0 continuous, 506 integer (506 binary)
# Root relaxation presolved: 3841 rows, 506 columns, 12144 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 1.920000e+02, 49 iterations, 0.01 seconds (0.01 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 8
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  192.00000    0    -  407.00000  192.00000  52.8%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#      0     0  192.00000    0    -  407.00000  192.00000  52.8%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#      0     0  192.00000    0    -  407.00000  192.00000  52.8%     -    0s
# Separation round!
# *    0     0               0     192.0000000  192.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 3
#
# Explored 1 nodes (55 simplex iterations) in 0.09 seconds (0.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 192 407
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.920000000000e+02, best bound 1.920000000000e+02, gap 0.0000%
#
# User-callback calls 160, time in user-callback 0.06 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2352 rows, 2256 columns and 9024 nonzeros
# Model fingerprint: 0xbb283011
# Variable types: 0 continuous, 2256 integer (2256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 35
# Presolve removed 1128 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 1224 rows, 2256 columns, 6768 nonzeros
# Variable types: 0 continuous, 2256 integer (2256 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 44
#
# Root relaxation: objective 3.410000e+02, 214 iterations, 0.00 seconds (0.00 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  341.00000    0    -          -  341.00000      -     -    0s
#      0     0  341.00000    0   14          -  341.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 44
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 36
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
#      0     0  341.00000    0   22          -  341.00000      -     -    0s
# Separation round!
# H    0     0                     341.0000000  341.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Lazy constraints: 6
#
# Explored 1 nodes (221 simplex iterations) in 0.28 seconds (0.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 341
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.410000000000e+02, best bound 3.410000000000e+02, gap 0.0000%
#
# User-callback calls 168, time in user-callback 0.23 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 106128 rows, 2256 columns and 320352 nonzeros
# Model fingerprint: 0x2fcb9854
# Variable types: 0 continuous, 2256 integer (2256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 35
# Presolve removed 70312 rows and 0 columns
# Presolve time: 0.17s
# Presolved: 35816 rows, 2256 columns, 110544 nonzeros
# Variable types: 0 continuous, 2256 integer (2256 binary)
# Separation round!
# Found heuristic solution: objective 871.0000000
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 44
# Root relaxation presolved: 35817 rows, 2256 columns, 110556 nonzeros
#
#
# Root relaxation: objective 3.410000e+02, 188 iterations, 0.04 seconds (0.05 work units)
# Separation round!
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     341.0000000  341.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 1
#
# Explored 1 nodes (188 simplex iterations) in 0.36 seconds (0.58 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 341 871
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.410000000000e+02, best bound 3.410000000000e+02, gap 0.0000%
#
# User-callback calls 233, time in user-callback 0.11 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5402 rows, 5256 columns and 21024 nonzeros
# Model fingerprint: 0x145bbeba
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 35
# Presolve removed 2628 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 2774 rows, 5256 columns, 15768 nonzeros
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 67
#
# Root relaxation: objective 4.740000e+02, 311 iterations, 0.00 seconds (0.01 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 23
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  474.00000    0    -          -  474.00000      -     -    0s
#      0     0  474.00000    0    8          -  474.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 20
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 16
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 70
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 51
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 63
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 34
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 3
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 21
#      0     0  474.00000    0   33          -  474.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 58
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.714 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 54
#      0     0  474.00000    0    -          -  474.00000      -     -    0s
#      0     0  474.00000    0   16          -  474.00000      -     -    0s
# Separation round!
# Separation round!
# H    0     0                     474.0000000  474.00000  0.00%     -    1s
#      0     0  474.00000    0   16  474.00000  474.00000  0.00%     -    1s
#
# Cutting planes:
#   Lazy constraints: 13
#
# Explored 1 nodes (481 simplex iterations) in 1.12 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 474
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.740000000000e+02, best bound 4.740000000000e+02, gap 0.0000%
#
# User-callback calls 218, time in user-callback 1.00 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 378578 rows, 5256 columns and 1140552 nonzeros
# Model fingerprint: 0xe76d9a0c
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 35
# Presolve removed 251412 rows and 0 columns
# Presolve time: 0.85s
# Presolved: 127166 rows, 5256 columns, 388944 nonzeros
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 69
# Root relaxation presolved: 127168 rows, 5256 columns, 388998 nonzeros
#
#
# Root relaxation: objective 4.740000e+02, 336 iterations, 0.13 seconds (0.18 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  474.00000    0    -          -  474.00000      -     -    1s
#      0     0  474.00000    0   20          -  474.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 40
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 56
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 9
#      0     0  474.00000    0    -          -  474.00000      -     -    2s
#      0     0  474.00000    0   28          -  474.00000      -     -    2s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 10
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 6
#      0     0  474.00000    0    8          -  474.00000      -     -    2s
# Separation round!
# H    0     0                     474.0000000  474.00000  0.00%     -    2s
#
# Cutting planes:
#   MIR: 1
#   Lazy constraints: 10
#
# Explored 1 nodes (345 simplex iterations) in 2.74 seconds (3.56 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 474
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.740000000000e+02, best bound 4.740000000000e+02, gap 0.0000%
#
# User-callback calls 584, time in user-callback 0.61 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 9702 rows, 9506 columns and 38024 nonzeros
# Model fingerprint: 0x70ea0c9b
# Variable types: 0 continuous, 9506 integer (9506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Presolve removed 4753 rows and 0 columns
# Presolve time: 0.03s
# Presolved: 4949 rows, 9506 columns, 28518 nonzeros
# Variable types: 0 continuous, 9506 integer (9506 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 92
#
# Root relaxation: objective 7.550000e+02, 516 iterations, 0.01 seconds (0.02 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  755.00000    0    -          -  755.00000      -     -    0s
#      0     0  755.00000    0   28          -  755.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 31
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 88
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 55
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 85
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 3
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 3
#      0     0  755.00000    0   38          -  755.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 55
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.833 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 20
#      0     0  755.00000    0    -          -  755.00000      -     -    1s
#      0     0  755.00000    0   16          -  755.00000      -     -    1s
# Separation round!
# Separation round!
# H    0     0                     755.0000000  755.00000  0.00%     -    1s
#      0     0  755.00000    0   16  755.00000  755.00000  0.00%     -    1s
#
# Cutting planes:
#   Lazy constraints: 10
#
# Explored 1 nodes (902 simplex iterations) in 1.64 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 755
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.550000000000e+02, best bound 7.550000000000e+02, gap 0.0000%
#
# User-callback calls 223, time in user-callback 1.44 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 922278 rows, 9506 columns and 2775752 nonzeros
# Model fingerprint: 0x340cde1d
# Variable types: 0 continuous, 9506 integer (9506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Presolve removed 613137 rows and 0 columns
# Presolve time: 1.91s
# Presolved: 309141 rows, 9506 columns, 941094 nonzeros
# Variable types: 0 continuous, 9506 integer (9506 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 76
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 92
# Root relaxation presolved: 309143 rows, 9506 columns, 941586 nonzeros
#
#
# Root relaxation: objective 7.550000e+02, 609 iterations, 0.37 seconds (0.55 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 80
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  755.00000    0    -          -  755.00000      -     -    3s
#      0     0  755.00000    0   32          -  755.00000      -     -    3s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 77
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 56
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 29
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 89
#      0     0  755.00000    0    -          -  755.00000      -     -    5s
#      0     0  755.00000    0   44          -  755.00000      -     -    5s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 11
#      0     0  755.00000    0    -          -  755.00000      -     -    6s
#      0     0  755.00000    0   12          -  755.00000      -     -    6s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 69
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 49
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 64
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 13
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 16
#      0     0  755.00000    0    -          -  755.00000      -     -    7s
#      0     0  755.00000    0   20          -  755.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 75
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 8
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 46
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 37
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 92
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 13
# Separation round!
# H    0     0                     755.0000000  755.00000  0.00%     -    9s
#
# Cutting planes:
#   Lazy constraints: 20
#
# Explored 1 nodes (1849 simplex iterations) in 9.03 seconds (11.55 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 755
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.550000000000e+02, best bound 7.550000000000e+02, gap 0.0000%
#
# User-callback calls 1360, time in user-callback 1.84 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 15252 rows, 15006 columns and 60024 nonzeros
# Model fingerprint: 0x394f57ed
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 56
# Presolve removed 7503 rows and 0 columns
# Presolve time: 0.05s
# Presolved: 7749 rows, 15006 columns, 45018 nonzeros
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 119
#
# Root relaxation: objective 9.590000e+02, 701 iterations, 0.01 seconds (0.02 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 36
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  959.00000    0    -          -  959.00000      -     -    0s
#      0     0  959.00000    0   42          -  959.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 76
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 41
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# Separation round!
# H    0     0                     959.0000000  959.00000  0.00%     -    1s
#
# Cutting planes:
#   Lazy constraints: 5
#
# Explored 1 nodes (1768 simplex iterations) in 1.32 seconds (0.24 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 959
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.590000000000e+02, best bound 9.590000000000e+02, gap 0.0000%
#
# User-callback calls 193, time in user-callback 1.20 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1830978 rows, 15006 columns and 5507202 nonzeros
# Model fingerprint: 0xaf2b8f60
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 56
# Presolve removed 1217987 rows and 0 columns
# Presolve time: 4.33s
# Presolved: 612991 rows, 15006 columns, 1860744 nonzeros
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 117
# Root relaxation presolved: 612993 rows, 15006 columns, 1860930 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.6280000e+01   2.334912e+01   2.144907e+08      7s
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      691    9.5900000e+02   0.000000e+00   0.000000e+00      7s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 7s
#
#       96 PPushes remaining with PInf 0.0000000e+00                 7s
#        0 PPushes remaining with PInf 0.0000000e+00                 7s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      7s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      791    9.5900000e+02   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 9.590000e+02, 791 iterations, 1.55 seconds (1.88 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 47
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  959.00000    0    -          -  959.00000      -     -    7s
#      0     0  959.00000    0   34          -  959.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 48
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 74
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 33
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 73
#      0     0  959.00000    0   34          -  959.00000      -     -   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.625 < 1)
# 	Set size: 30
# 	Found a subset which violate a SEC (flow = 0.375 < 1)
# 	Set size: 21
#      0     0  959.00000    0    -          -  959.00000      -     -   12s
#      0     0  959.00000    0   28          -  959.00000      -     -   12s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 8
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 25
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 95
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 29
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 77
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
#      0     0  959.00000    0   28          -  959.00000      -     -   15s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 103
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 45
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 72
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 65
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 108
# Separation round!
# H    0     0                     959.0000000  959.00000  0.00%     -   19s
#
# Cutting planes:
#   Lazy constraints: 22
#
# Explored 1 nodes (1544 simplex iterations) in 19.10 seconds (24.33 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 959
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.590000000000e+02, best bound 9.590000000000e+02, gap 0.0000%
#
# User-callback calls 2284, time in user-callback 3.42 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 22052 rows, 21756 columns and 87024 nonzeros
# Model fingerprint: 0xac00860c
# Variable types: 0 continuous, 21756 integer (21756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 57
# Presolve removed 10878 rows and 0 columns
# Presolve time: 0.07s
# Presolved: 11174 rows, 21756 columns, 65268 nonzeros
# Variable types: 0 continuous, 21756 integer (21756 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 144
#
# Root relaxation: objective 9.440000e+02, 833 iterations, 0.02 seconds (0.04 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 113
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  944.00000    0    -          -  944.00000      -     -    0s
#      0     0  944.00000    0   46          -  944.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 33
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 94
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 98
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.714 < 1)
# 	Set size: 35
# 	Found a subset which violate a SEC (flow = 0.714 < 1)
# 	Set size: 46
# 	Found a subset which violate a SEC (flow = 0.429 < 1)
# 	Set size: 38
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 67
#      0     0  944.00000    0    -          -  944.00000      -     -    2s
#      0     0  944.00000    0   28          -  944.00000      -     -    2s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 32
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 35
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 111
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 75
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 57
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
# Separation round!
# *    0     0               0     944.0000000  944.00000  0.00%     -    4s
#
# Cutting planes:
#   Lazy constraints: 17
#
# Explored 1 nodes (1579 simplex iterations) in 4.48 seconds (0.76 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 944
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.440000000000e+02, best bound 9.440000000000e+02, gap 0.0000%
#
# User-callback calls 352, time in user-callback 3.95 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3198428 rows, 21756 columns and 9616152 nonzeros
# Model fingerprint: 0xd42086f4
# Variable types: 0 continuous, 21756 integer (21756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 57
# Presolve removed 2128462 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 2128462 rows and 0 columns
# Presolve time: 9.70s
# Presolved: 1069966 rows, 21756 columns, 3241644 nonzeros
# Variable types: 0 continuous, 21756 integer (21756 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 68
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 144
# Root relaxation presolved: 1069968 rows, 21756 columns, 3246212 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root relaxation presolved: 1069967 rows, 21756 columns, 3246065 nonzeros
#
# Concurrent spin time: 0.47s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: objective 9.440000e+02, 826 iterations, 2.63 seconds (1.93 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 23
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  944.00000    0    -          -  944.00000      -     -   15s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
#      0     0  944.00000    0    -          -  944.00000      -     -   15s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 18
#      0     0  944.00000    0    -          -  944.00000      -     -   16s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
#      0     0  944.00000    0    -          -  944.00000      -     -   16s
#      0     0  944.00000    0   16          -  944.00000      -     -   17s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 48
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 121
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 78
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 83
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 83
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 76
#      0     0  944.00000    0    -          -  944.00000      -     -   26s
#      0     0  944.00000    0   57          -  944.00000      -     -   26s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.462 < 1)
# 	Set size: 5
#      0     0  944.00000    0    -          -  944.00000      -     -   28s
#      0     0  944.00000    0   14          -  944.00000      -     -   29s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 67
# Separation round!
# H    0     0                     944.0000000  944.00000  0.00%     -   30s
#
# Cutting planes:
#   Lazy constraints: 12
#
# Explored 1 nodes (1595 simplex iterations) in 30.46 seconds (33.04 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 944
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.440000000000e+02, best bound 9.440000000000e+02, gap 0.0000%
#
# User-callback calls 3334, time in user-callback 4.42 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 30102 rows, 29756 columns and 119024 nonzeros
# Model fingerprint: 0xa9e213cb
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 122
# Presolve removed 14878 rows and 0 columns
# Presolve time: 0.10s
# Presolved: 15224 rows, 29756 columns, 89268 nonzeros
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 167
#
# Root relaxation: objective 9.080000e+02, 978 iterations, 0.03 seconds (0.07 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 109
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  908.00000    0    -          -  908.00000      -     -    0s
#      0     0  908.00000    0   34          -  908.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 8
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 129
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 160
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 35
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 36
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 28
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 107
#      0     0  908.00000    0    -          -  908.00000      -     -    3s
#      0     0  908.00000    0   14          -  908.00000      -     -    3s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 96
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 40
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 99
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 45
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 58
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 127
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 121
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 95
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 42
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 22
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 65
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 81
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 14
#      0     2  908.00000    0    8          -  908.00000      -     -    8s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
# Separation round!
# 	Found a subset which violate a SEC (flow = -0.000 < 1)
# 	Set size: 8
#      3     0  908.00000    1    -          -  908.00000      -  10.3   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 142
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 75
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 132
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 72
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#     14     6  914.00000    1    -          -  914.00000      -  16.8   15s
# Separation round!
# Separation round!
# Separation round!
# Separation round!
# *   17     6               3     914.0000000  914.00000  0.00%  16.2   17s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 134
# Separation round!
#
# Cutting planes:
#   Lazy constraints: 35
#
# Explored 20 nodes (2011 simplex iterations) in 18.10 seconds (1.57 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 914
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.140000000000e+02, best bound 9.140000000000e+02, gap 0.0000%
#
# User-callback calls 456, time in user-callback 17.13 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5118378 rows, 29756 columns and 15383852 nonzeros
# Model fingerprint: 0xb74ba7a6
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 122
# Presolve removed 3407062 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 3407062 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 3407062 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 3407062 rows and 0 columns
# Presolve time: 15.90s
# Presolved: 1711316 rows, 29756 columns, 5177544 nonzeros
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 67
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 169
# Root relaxation presolved: 1711318 rows, 29756 columns, 5181978 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
#
# Barrier performed 0 iterations in 24.55 seconds (36.94 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.53s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      650    9.1333333e+02   0.000000e+00   0.000000e+00     25s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        4 DPushes remaining with DInf 0.0000000e+00                25s
#        0 DPushes remaining with DInf 0.0000000e+00                25s
#
#      130 PPushes remaining with PInf 0.0000000e+00                25s
#        0 PPushes remaining with PInf 0.0000000e+00                25s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.8817842e-16     25s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      784    9.1333333e+02   0.000000e+00   0.000000e+00     26s
#
# Root relaxation: objective 9.133333e+02, 784 iterations, 5.56 seconds (5.21 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  913.33333    0    8          -  913.33333      -     -   25s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 168
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 122
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 167
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 41
# Separation round!
# H    0     0                     924.0000000  913.33333  1.15%     -   32s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 41
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 44
#      0     0  914.00000    0   18  924.00000  914.00000  1.08%     -   35s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 58
#      0     0  914.00000    0    8  924.00000  914.00000  1.08%     -   39s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 137
#      0     0  914.00000    0    -  924.00000  914.00000  1.08%     -   39s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 107
#      0     0  914.00000    0    -  924.00000  914.00000  1.08%     -   39s
#      0     0  914.00000    0   16  924.00000  914.00000  1.08%     -   39s
# Separation round!
# H    0     0                     914.0000000  914.00000  0.00%     -   40s
#      0     0  914.00000    0   16  914.00000  914.00000  0.00%     -   40s
#
# Cutting planes:
#   Lazy constraints: 2
#
# Explored 1 nodes (2018 simplex iterations) in 40.30 seconds (52.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 914 924
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.140000000000e+02, best bound 9.140000000000e+02, gap 0.0000%
#
# User-callback calls 4900, time in user-callback 4.50 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 39402 rows, 39006 columns and 156024 nonzeros
# Model fingerprint: 0x3b93f1ae
# Variable types: 0 continuous, 39006 integer (39006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
# Presolve removed 19503 rows and 0 columns
# Presolve time: 0.13s
# Presolved: 19899 rows, 39006 columns, 117018 nonzeros
# Variable types: 0 continuous, 39006 integer (39006 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 192
# Root relaxation presolved: 19900 rows, 39006 columns, 117048 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 9.120000e+02, 2814 iterations, 0.10 seconds (0.12 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 93
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  912.00000    0    -          -  912.00000      -     -    1s
#      0     0  912.00000    0   26          -  912.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 75
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 35
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 93
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 63
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 16
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 26
#      0     0  912.00000    0    -          -  912.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 16
#      0     0  912.00000    0    -          -  912.00000      -     -    5s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 80
#      0     0  912.00000    0    -          -  912.00000      -     -    5s
#      0     0  912.00000    0   28          -  912.00000      -     -    5s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 131
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 120
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 26
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 177
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 77
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 23
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 33
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 13
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 103
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 95
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# ...
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 146
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 143
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# *    0     0               0     923.0000000  923.00000  0.00%     -   25s
#
# Cutting planes:
#   Lazy constraints: 28
#
# Explored 1 nodes (6757 simplex iterations) in 25.62 seconds (3.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 923
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.230000000000e+02, best bound 9.230000000000e+02, gap 0.0000%
#
# User-callback calls 792, time in user-callback 23.80 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 15130728 rows, 61256 columns and 45451952 nonzeros
# Model fingerprint: 0xa1990ad9
# Variable types: 0 continuous, 61256 integer (61256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 199
# Presolve removed 0 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 16s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 22s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 40s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 46s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 50s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 55s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 60s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 66s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 72s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 75s) ...
# Presolve removed 10076612 rows and 0 columns
# Presolve time: 77.60s
# Presolved: 5054116 rows, 61256 columns, 15252744 nonzeros
# Variable types: 0 continuous, 61256 integer (61256 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 103
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 244
# Root relaxation presolved: 5054118 rows, 61256 columns, 15263262 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Concurrent spin time: 0.19s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      902    9.2300000e+02   0.000000e+00   0.000000e+00    105s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#       13 DPushes remaining with DInf 0.0000000e+00               107s
#        0 DPushes remaining with DInf 0.0000000e+00               107s
#
#      290 PPushes remaining with PInf 0.0000000e+00               107s
#        0 PPushes remaining with PInf 0.0000000e+00               108s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00    108s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1196    9.2300000e+02   0.000000e+00   0.000000e+00    108s
#
# Root relaxation: objective 9.230000e+02, 1196 iterations, 17.37 seconds (15.49 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 28
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  923.00000    0    -          -  923.00000      -     -  110s
#      0     0  923.00000    0   30          -  923.00000      -     -  112s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 209
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 83
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 198
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.600 < 1)
# 	Set size: 21
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 7
#      0     0  923.00000    0    -          -  923.00000      -     -  171s
#      0     0  923.00000    0    8          -  923.00000      -     -  175s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 155
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 158
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 194
#      0     0  923.00000    0    8          -  923.00000      -     -  180s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 98
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 87
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 205
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 157
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 49
#      0     0  923.00000    0    8          -  923.00000      -     -  186s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 53
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 198
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 161
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 181
#      0     0  923.00000    0    8          -  923.00000      -     -  190s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 151
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 73
#      0     0  923.00000    0    8          -  923.00000      -     -  213s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 206
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 199
#      0     0  923.00000    0    8          -  923.00000      -     -  215s
# Separation round!
# H    0     0                     923.0000000  923.00000  0.00%     -  217s
#
# Cutting planes:
#   Lazy constraints: 24
#
# Explored 1 nodes (2460 simplex iterations) in 217.74 seconds (193.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 923
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.230000000000e+02, best bound 9.230000000000e+02, gap 0.0000%
#
# User-callback calls 16606, time in user-callback 20.06 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 74802 rows, 74256 columns and 297024 nonzeros
# Model fingerprint: 0x75d9b87b
# Variable types: 0 continuous, 74256 integer (74256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 203
# Presolve removed 37128 rows and 0 columns
# Presolve time: 0.25s
# Presolved: 37674 rows, 74256 columns, 222768 nonzeros
# Variable types: 0 continuous, 74256 integer (74256 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 267
# Root relaxation presolved: 37675 rows, 74256 columns, 222798 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.02s
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 1.072000e+03, 4456 iterations, 0.21 seconds (0.26 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 114
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1072.00000    0    -          - 1072.00000      -     -    3s
#      0     0 1072.00000    0   46          - 1072.00000      -     -    3s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 118
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 186
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 145
#      0     0 1072.00000    0   46          - 1072.00000      -     -    6s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 245
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.889 < 1)
# 	Set size: 110
# 	Found a subset which violate a SEC (flow = 0.111 < 1)
# 	Set size: 10
#      0     0 1072.00000    0    -          - 1072.00000      -     -    8s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 75
#      0     0 1072.00000    0    -          - 1072.00000      -     -   10s
#      0     0 1072.00000    0   14          - 1072.00000      -     -   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 215
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 53
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 238
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 123
#      0     0 1072.00000    0   14          - 1072.00000      -     -   16s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 90
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 14
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 69
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 94
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 121
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 54
#      0     2 1072.00000    0    8          - 1072.00000      -     -   24s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 42
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 16
#      1     2 1072.00000    1   10          - 1072.00000      -  71.0   26s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 96
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 84
#      4     1 1072.00000    1    -          - 1072.00000      -  50.5   30s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 232
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 232
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 233
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 33
#      9     4 1072.00000    2    8          - 1072.00000      -  50.7   36s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 55
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 117
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 50
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 194
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 28
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 5
#     12     4 1072.00000    3   14          - 1072.00000      -  41.8   41s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 38
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 28
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 49
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 165
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 209
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 166
# Separation round!
# Separation round!
# *   17     6               4    1072.0000000 1072.00000  0.00%  39.1   50s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 112
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 88
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
#     20     6     cutoff    2      1072.00000 1072.00000  0.00%  35.8   55s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 40
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 249
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 40
# Separation round!
#
# Cutting planes:
#   Lazy constraints: 47
#
# Explored 24 nodes (8982 simplex iterations) in 59.12 seconds (4.67 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1072
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.072000000000e+03, best bound 1.072000000000e+03, gap 0.0000%
#
# User-callback calls 818, time in user-callback 56.27 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 20198178 rows, 74256 columns and 60667152 nonzeros
# Model fingerprint: 0xd2eb040e
# Variable types: 0 continuous, 74256 integer (74256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 203
# Presolve removed 0 rows and 0 columns (presolve time = 6s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 11s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 27s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 36s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 40s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 45s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 50s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 55s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 60s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 66s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 70s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 75s) ...
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Cardinality 3
for vert in vertices_list:
    filtered_vertices = vert
    filtered_cost = {(i, j): cost_val for (i, j), cost_val in cost.items() if i < filtered_vertices and j < filtered_vertices}
    print(vert)
          
    i_3 = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s_3 = TspFractionalBCSolver(instance=i_3, cardinality=2.3)
    solution_3 = s_3.solve()

    if solution_3 == 'Solution not found':
        time_list_3_f.append(300)
        #objective_list_3_f.append(0)
        #nrows_list_3_f.append(0)
        iter_list_3_f.append(0)
    else:
        time_list_3_f.append(s_3._model.Runtime)
        #objective_list_3_f.append(s_3._model.ObjVal)
        #nrows_list_3_f.append(s_3._model.NumConstrs)
        iter_list_3_f.append(solution_3.model_metrics['IterCount'])

# %% [markdown]
# ### Output to table

# %%
frac_no_cons = pd.DataFrame({'time': time_list_frac, 'obj': objective_list_frac, 'iter': iter_list_frac})
frac_no_cons['type'] = 'No constraints'

frac_card_2 = pd.DataFrame({'time': time_list_2_f, 'obj': objective_list_2_f, 'iter': iter_list_2_f})
frac_card_2 ['type'] = 'Cardinality 2'


frac_card_3 = pd.DataFrame({'time': time_list_3_f, 'obj': objective_list_3_f,  'iter': iter_list_3_f})
frac_card_3 ['type'] = 'Cardinality 3'


pd.concat([frac_no_cons, frac_card_2, frac_card_3], axis='rows').to_csv('question 2 - frac.csv')

latex_table_temp = pd.concat([frac_no_cons, frac_card_2, frac_card_3]
latex_table_2_int = latex_table_temp.to_latex(index = False)

# %% [markdown]
# ### Graph

# %%
plt.figure(figsize=(10, 6))
plt.plot(vertices_list, time_list_none_f, marker='o', label = "No Additional Contraints")
plt.plot(vertices_list, time_list_2_f, marker='x', label = "Cardinality 2 SEC")
plt.plot(vertices_list, time_list_3_f, marker='s', label = "Cardinality 3 SEC")
plt.xlabel('Number of Vertices')
plt.ylabel('Computation Time (seconds)')
#plt.title('Computation Time vs Number of Vertices in TSP')
plt.legend()
plt.grid(True)
plt.show()



for i in range(len(objective_list_none_f)):
        
        assert objective_list_none_f[i]==objective_list_2_f[i]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/rossfleming/Documents/GitHub/tsp_project/master file.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(10, 6))
#       <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X45sZmlsZQ%3D%3D?line=1'>2</a> plt.plot(vertices_list, time_list_none_f, marker='o', label = "No Additional Contraints")
#       <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X45sZmlsZQ%3D%3D?line=2'>3</a> plt.plot(vertices_list, time_list_2_f, marker='x', label = "Cardinality 2 SEC")
#
# NameError: name 'plt' is not defined

# %%
for i in range(len(objective_list_none_f)):
        
        assert objective_list_none_f[i]==objective_list_2_f[i]

# %%
# Check how many times cardinality constraints where violated
for entry in s.lazy_constraints_added:
    subtour = entry['subtour']
    constraint = entry['constraint']
    
    # Check if the subtour length is exactly 2
    if len(subtour) == 2:
        # The subtour contains exactly two vertices i and j
        i, j = subtour
        # The corresponding constraint is for i to j and j to i
        print(f"Lazy constraint for subtour {subtour}")
# Out:
# Lazy constraint for subtour [35, 264]
# Lazy constraint for subtour [0, 322]
# Lazy constraint for subtour [1, 321]
# Lazy constraint for subtour [2, 320]
# Lazy constraint for subtour [3, 319]
# Lazy constraint for subtour [4, 318]
# Lazy constraint for subtour [5, 317]
# Lazy constraint for subtour [6, 316]
# Lazy constraint for subtour [7, 315]
# Lazy constraint for subtour [8, 314]
# Lazy constraint for subtour [9, 313]
# Lazy constraint for subtour [10, 312]
# Lazy constraint for subtour [11, 311]
# Lazy constraint for subtour [12, 310]
# Lazy constraint for subtour [13, 309]
# Lazy constraint for subtour [14, 308]
# Lazy constraint for subtour [15, 307]
# Lazy constraint for subtour [16, 306]
# Lazy constraint for subtour [17, 305]
# Lazy constraint for subtour [18, 304]
# Lazy constraint for subtour [19, 303]
# Lazy constraint for subtour [20, 302]
# Lazy constraint for subtour [21, 301]
# Lazy constraint for subtour [22, 300]
# Lazy constraint for subtour [23, 299]
# Lazy constraint for subtour [24, 298]
# Lazy constraint for subtour [25, 297]
# Lazy constraint for subtour [26, 296]
# Lazy constraint for subtour [27, 295]
# Lazy constraint for subtour [28, 294]
# Lazy constraint for subtour [29, 293]
# Lazy constraint for subtour [30, 292]
# Lazy constraint for subtour [31, 291]
# Lazy constraint for subtour [32, 290]
# Lazy constraint for subtour [33, 289]
# Lazy constraint for subtour [34, 288]
# Lazy constraint for subtour [35, 287]
# Lazy constraint for subtour [36, 286]
# Lazy constraint for subtour [37, 285]
# Lazy constraint for subtour [38, 284]
# Lazy constraint for subtour [39, 283]
# Lazy constraint for subtour [40, 282]
# Lazy constraint for subtour [41, 281]
# Lazy constraint for subtour [42, 280]
# Lazy constraint for subtour [43, 279]
# Lazy constraint for subtour [44, 278]
# Lazy constraint for subtour [45, 277]
# Lazy constraint for subtour [46, 276]
# Lazy constraint for subtour [47, 275]
# Lazy constraint for subtour [48, 274]
# Lazy constraint for subtour [49, 273]
# Lazy constraint for subtour [50, 272]
# Lazy constraint for subtour [51, 271]
# Lazy constraint for subtour [52, 270]
# Lazy constraint for subtour [53, 269]
# Lazy constraint for subtour [54, 268]
# Lazy constraint for subtour [55, 267]
# Lazy constraint for subtour [56, 266]
# Lazy constraint for subtour [57, 265]
# Lazy constraint for subtour [58, 264]
# Lazy constraint for subtour [59, 263]
# Lazy constraint for subtour [60, 262]
# Lazy constraint for subtour [61, 261]
# Lazy constraint for subtour [62, 260]
# Lazy constraint for subtour [63, 259]
# Lazy constraint for subtour [64, 258]
# Lazy constraint for subtour [65, 257]
# Lazy constraint for subtour [66, 256]
# Lazy constraint for subtour [67, 255]
# Lazy constraint for subtour [68, 254]
# Lazy constraint for subtour [69, 253]
# Lazy constraint for subtour [70, 252]
# Lazy constraint for subtour [71, 251]
# Lazy constraint for subtour [72, 250]
# Lazy constraint for subtour [73, 249]
# Lazy constraint for subtour [74, 248]
# Lazy constraint for subtour [75, 247]
# Lazy constraint for subtour [76, 246]
# Lazy constraint for subtour [77, 245]
# Lazy constraint for subtour [78, 244]
# Lazy constraint for subtour [79, 243]
# Lazy constraint for subtour [80, 242]
# Lazy constraint for subtour [81, 241]
# Lazy constraint for subtour [82, 240]
# Lazy constraint for subtour [83, 239]
# Lazy constraint for subtour [84, 238]
# Lazy constraint for subtour [85, 237]
# Lazy constraint for subtour [86, 236]
# Lazy constraint for subtour [87, 235]
# Lazy constraint for subtour [88, 234]
# Lazy constraint for subtour [89, 233]
# Lazy constraint for subtour [90, 232]
# Lazy constraint for subtour [91, 231]
# Lazy constraint for subtour [92, 230]
# Lazy constraint for subtour [93, 229]
# Lazy constraint for subtour [94, 228]
# Lazy constraint for subtour [95, 227]
# Lazy constraint for subtour [96, 226]
# Lazy constraint for subtour [97, 225]
# Lazy constraint for subtour [98, 224]
# Lazy constraint for subtour [99, 223]
# Lazy constraint for subtour [100, 222]
# Lazy constraint for subtour [101, 221]
# Lazy constraint for subtour [102, 220]
# Lazy constraint for subtour [103, 219]
# Lazy constraint for subtour [104, 218]
# Lazy constraint for subtour [105, 217]
# Lazy constraint for subtour [106, 216]
# Lazy constraint for subtour [107, 215]
# Lazy constraint for subtour [108, 214]
# Lazy constraint for subtour [109, 213]
# Lazy constraint for subtour [110, 212]
# Lazy constraint for subtour [111, 211]
# Lazy constraint for subtour [112, 210]
# Lazy constraint for subtour [113, 209]
# Lazy constraint for subtour [114, 208]
# Lazy constraint for subtour [115, 207]
# Lazy constraint for subtour [116, 206]
# Lazy constraint for subtour [117, 205]
# Lazy constraint for subtour [118, 204]
# Lazy constraint for subtour [119, 203]
# Lazy constraint for subtour [120, 202]
# Lazy constraint for subtour [121, 201]
# Lazy constraint for subtour [122, 200]
# Lazy constraint for subtour [123, 199]
# Lazy constraint for subtour [124, 198]
# Lazy constraint for subtour [125, 197]
# Lazy constraint for subtour [126, 196]
# Lazy constraint for subtour [127, 195]
# Lazy constraint for subtour [128, 194]
# Lazy constraint for subtour [129, 193]
# Lazy constraint for subtour [130, 192]
# Lazy constraint for subtour [131, 191]
# Lazy constraint for subtour [132, 190]
# Lazy constraint for subtour [133, 189]
# Lazy constraint for subtour [134, 188]
# Lazy constraint for subtour [135, 187]
# Lazy constraint for subtour [136, 186]
# Lazy constraint for subtour [137, 185]
# Lazy constraint for subtour [138, 184]
# Lazy constraint for subtour [139, 183]
# Lazy constraint for subtour [140, 182]
# Lazy constraint for subtour [141, 181]
# Lazy constraint for subtour [142, 180]
# Lazy constraint for subtour [143, 179]
# Lazy constraint for subtour [144, 178]
# Lazy constraint for subtour [145, 177]
# Lazy constraint for subtour [146, 176]
# Lazy constraint for subtour [147, 175]
# Lazy constraint for subtour [148, 174]
# Lazy constraint for subtour [149, 173]
# Lazy constraint for subtour [150, 172]
# Lazy constraint for subtour [151, 171]
# Lazy constraint for subtour [152, 170]
# Lazy constraint for subtour [153, 169]
# Lazy constraint for subtour [154, 168]
# Lazy constraint for subtour [155, 167]
# Lazy constraint for subtour [156, 166]
# Lazy constraint for subtour [157, 165]
# Lazy constraint for subtour [158, 164]
# Lazy constraint for subtour [159, 163]
# Lazy constraint for subtour [14, 235]
# Lazy constraint for subtour [18, 211]
# Lazy constraint for subtour [25, 300]
# Lazy constraint for subtour [6, 98]

# %%
# Check how many times cardinality constraints where violated
for entry in s.lazy_constraints_added:
    subtour = entry['subtour']
    constraint = entry['constraint']
    

    # Check if the subtour length is exactly 2
    if len(subtour) == 3:
        # The subtour contains exactly two vertices i and j
        i, j, k = subtour
        # The corresponding constraint is for i to j and j to i
        print(f"Lazy constraint for subtour {subtour}")
# Out:
# Lazy constraint for subtour [45, 88, 110]
# Lazy constraint for subtour [162, 195, 275]
# Lazy constraint for subtour [160, 161, 162]
# Lazy constraint for subtour [0, 317, 316]
# Lazy constraint for subtour [1, 308, 306]

# %% [markdown]
# # Question 3

# %% [markdown]
# ## Integer

# %%
# Load data set 1
#tsp_loader = TspDataLoader()
n_vertices, cost, closest_vertices_array = tsp_loader.load_problem('rbg443.atsp')
i = TspInstance(n_vertices=n_vertices, cost=cost, closest_vertices_array=closest_vertices_array)
solver = TspIntegerBCSolver(instance=i, cardinality=None)
solution = solver.solve()
No_cardinality = solver._model.Runtime

solver = TspFractionalBCSolver(instance=i, cardinality=None)
solution = solver.solve()
No_cardinality_frac = solver._model.Runtime
# Out:
# 196249
# EXPLICIT
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-12
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 886 rows, 195806 columns and 391612 nonzeros
# Model fingerprint: 0xf767418b
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.17s
# Presolved: 886 rows, 195806 columns, 391612 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity      0.0000000e+00      5s
#        1       1027   3.3000000e+08   1.4219039e-01      5s
#        2       2524   2.0600028e+08   2.5568452e-01      5s
#        3       3572   1.8600044e+08   5.2890655e-01      5s
#        4       4747   1.5600073e+08   5.4835000e-01      5s
#        5       5818   1.5000079e+08   6.3555867e-01      5s
#        6       6953   1.0400133e+08   9.4306010e+01      5s
#        7       8126   5.4001953e+07   8.9322049e+01      5s
#        8       9365   2.6002333e+07   8.7376135e+01      5s
#        9      10531   2.7581215e+03   8.7695513e+01      5s
#       10      11619   2.7581214e+03   8.7972592e+01      5s
#       11      12801   2.7581214e+03   8.8144064e+01      5s
#       12      14070   2.7371237e+03   8.8484330e+01      5s
#       13      15250   2.7371237e+03   8.8648074e+01      5s
#       14      16632   2.7241258e+03   8.9605263e+01      5s
#       15      18027   2.7141261e+03   9.1897003e+01      5s
#       16      19560   2.7131252e+03   9.4098532e+01      5s
#       17      21168   2.7131243e+03   1.8774188e+03      5s
#       18      22508   2.7131241e+03   2.5327374e+03      5s
#
# Sifting complete
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    23644    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.720000e+03, 23644 iterations, 0.52 seconds (0.65 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0  103          - 2720.00000      -     -    6s
#      0     0 2720.00000    0  103          - 2720.00000      -     -   11s
#      0     0 2720.00000    0    -          - 2720.00000      -     -   16s
#      0     0 2720.00000    0   14          - 2720.00000      -     -   16s
# H    0     0                    2720.0000000 2720.00000  0.00%     -   17s
#      0     0 2720.00000    0   14 2720.00000 2720.00000  0.00%     -   17s
#
# Cutting planes:
#   Lazy constraints: 254
#
# Explored 1 nodes (25485 simplex iterations) in 17.18 seconds (3.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 607, time in user-callback 15.07 sec
# 17.181227922439575

# %%
# Looping through different cardinality constraints
pairs = [(3.2, 3), (3.2, 4), (3.2, 5), (3.3, 4), (3.3, 5), (3.4, 5)]
solve_time_q3 = list()
iter_q3 = list()
objective_list_q3 = list()
nrows_list_q3 = list()


for cardinality, l in pairs:
    solver = TspIntegerBCSolver(instance=i, cardinality=cardinality, l=l)
    solution = solver.solve()
    solve_time_q3.append(solver._model.Runtime)
    iter_q3.append(solution.model_metrics['IterCount'])
    objective_list_q3.append(solver._model.ObjVal)
    nrows_list_q3.append(solver._model.NumConstrs)

    if solution == 'Solution not found':
        solve_time_q3.append(0)
        iter_q3.append(0)
        objective_list_q3.append(0)
        nrows_list_q3.append(0)
    else:
        solve_time_q3.append(solver._model.Runtime)
        iter_q3.append(solution.model_metrics['IterCount'])
        objective_list_q3.append(solver._model.ObjVal)
        nrows_list_q3.append(solver._model.NumConstrs)
# Out:
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2215 rows, 195806 columns and 394270 nonzeros
# Model fingerprint: 0x5c03eefe
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 14 rows and 0 columns
# Presolve time: 0.21s
# Presolved: 2201 rows, 195806 columns, 394242 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 2420 rows, 195806 columns, 394704 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 11061 iterations, 0.18 seconds (0.26 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   33          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   33          - 2720.00000      -     -   11s
#      0     0 2720.00000    0    -          - 2720.00000      -     -   16s
# *    0     0               0    2720.0000000 2720.00000  0.00%     -   17s
#
# Cutting planes:
#   Lazy constraints: 240
#
# Explored 1 nodes (47671 simplex iterations) in 17.46 seconds (4.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 528, time in user-callback 15.35 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2658 rows, 195806 columns and 395156 nonzeros
# Model fingerprint: 0x87b8bbaf
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 24 rows and 0 columns
# Presolve time: 0.21s
# Presolved: 2634 rows, 195806 columns, 395108 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 2851 rows, 195806 columns, 395586 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 10389 iterations, 0.18 seconds (0.27 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   35          - 2720.00000      -     -    6s
# H    0     0                    2720.0000000 2720.00000  0.00%     -    9s
#
# Cutting planes:
#   Lazy constraints: 229
#
# Explored 1 nodes (10585 simplex iterations) in 9.78 seconds (1.56 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 373, time in user-callback 8.91 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3101 rows, 195806 columns and 396042 nonzeros
# Model fingerprint: 0xc52dd3a8
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 38 rows and 0 columns
# Presolve time: 0.21s
# Presolved: 3063 rows, 195806 columns, 395966 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 3278 rows, 195806 columns, 396460 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 11326 iterations, 0.19 seconds (0.28 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   56          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   56          - 2720.00000      -     -   10s
# H    0     0                    2720.0000000 2720.00000  0.00%     -   11s
#      0     0 2720.00000    0   56 2720.00000 2720.00000  0.00%     -   11s
#
# Cutting planes:
#   Lazy constraints: 229
#
# Explored 1 nodes (11344 simplex iterations) in 11.23 seconds (1.52 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 444, time in user-callback 10.29 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 7974 rows, 195806 columns and 411104 nonzeros
# Model fingerprint: 0x67fa220d
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 98 rows and 0 columns
# Presolve time: 0.21s
# Presolved: 7876 rows, 195806 columns, 410834 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 8093 rows, 195806 columns, 411312 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 9957 iterations, 0.21 seconds (0.35 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   49          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   49          - 2720.00000      -     -   11s
#      0     0 2720.00000    0    -          - 2720.00000      -     -   15s
#      0     0 2720.00000    0   12          - 2720.00000      -     -   15s
# H    0     0                    2720.0000000 2720.00000  0.00%     -   19s
#      0     0 2720.00000    0   12 2720.00000 2720.00000  0.00%     -   19s
#
# Cutting planes:
#   Lazy constraints: 245
#
# Explored 1 nodes (28452 simplex iterations) in 19.39 seconds (4.71 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 739, time in user-callback 16.67 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 11961 rows, 195806 columns and 422622 nonzeros
# Model fingerprint: 0xf1b179a0
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 196 rows and 0 columns
# Presolve time: 0.23s
# Presolved: 11765 rows, 195806 columns, 422072 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 11980 rows, 195806 columns, 422566 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.7390000e+03   1.000000e+00   2.914933e+06      5s
#     8713    2.7200000e+03   0.000000e+00   0.000000e+00      5s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 8713 iterations, 0.21 seconds (0.34 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   48          - 2720.00000      -     -    7s
#      0     0 2720.00000    0   48          - 2720.00000      -     -   12s
#      0     0 2720.00000    0    -          - 2720.00000      -     -   16s
# *    0     0               0    2720.0000000 2720.00000  0.00%     -   16s
#
# Cutting planes:
#   Lazy constraints: 243
#
# Explored 1 nodes (29341 simplex iterations) in 16.65 seconds (4.74 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 566, time in user-callback 14.18 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38541 rows, 195806 columns and 528942 nonzeros
# Model fingerprint: 0xeb48c79c
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 700 rows and 0 columns
# Presolve time: 0.30s
# Presolved: 37841 rows, 195806 columns, 526376 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 38056 rows, 195806 columns, 526870 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.59s
#
# Barrier performed 0 iterations in 5.68 seconds (1.64 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.56s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 4748 iterations, 0.84 seconds (0.60 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    7s
#      0     0 2720.00000    0   30          - 2720.00000      -     -    7s
#      0     0 2720.00000    0   30          - 2720.00000      -     -   12s
#      0     0 2720.00000    0    -          - 2720.00000      -     -   14s
# *    0     0               0    2720.0000000 2720.00000  0.00%     -   15s
#
# Cutting planes:
#   Lazy constraints: 228
#
# Explored 1 nodes (33615 simplex iterations) in 15.11 seconds (5.41 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 676, time in user-callback 12.02 sec

# %% [markdown]
# ### Graph

# %%
# Convert pairs to string format for labeling
pairs_2 = [(2, 3), (2, 4), (2, 5), (3, 4), (3, 5), (4, 5)]
pair_labels = [f"({card}, {l})" for card, l in pairs_2]

# Plotting computational time
plt.figure(figsize=(10, 6))
plt.bar(pair_labels, solve_time_q3, color='skyblue')
plt.hlines(No_cardinality, xmin=-0.5, xmax=len(pair_labels)-0.5, colors='red', label='No added constraints')
plt.xlabel('K, L Pairs')
plt.ylabel('Solve Time (Seconds)')
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.legend()
plt.show()

# %% [markdown]
# # Fractional

# %%
# Looping through different cardinality constraints
pairs = [(3.2, 3), (3.2, 4), (3.2, 5), (3.3, 4), (3.3, 5), (3.4, 5)]
solve_time_q3_frac = list()
iter_q3_frac = list()
objective_list_q3_frac = list()
nrows_list_q3_frac = list()

for cardinality, l in pairs:
    solver = TspFractionalBCSolver(instance=i, cardinality=cardinality, len = l)
    solution = solver.solve()

    if solution == 'Solution not found':
        solve_time_q3.append(0)
        iter_q3.append(0)
        objective_list_q3_frac.append(0)
        nrows_list_q3_frac.append(0)
    else:
        solve_time_q3_frac.append(solver._model.Runtime)
        iter_q3_frac.append(solution.model_metrics['IterCount'])
        objective_list_q3_frac.append(solver._model.ObjVal)
        nrows_list_q3_frac.append(solver._model.NumConstrs)
# Out:
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2215 rows, 195806 columns and 394270 nonzeros
# Model fingerprint: 0x5c03eefe
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 320
# Presolve removed 14 rows and 0 columns
# Presolve time: 0.22s
# Presolved: 2201 rows, 195806 columns, 394242 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 441
# Root relaxation presolved: 2202 rows, 195806 columns, 394244 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.7719000e+02   1.028701e+02   2.196071e+09      5s
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1787    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#      399 DPushes remaining with DInf 0.0000000e+00                 5s
#        0 DPushes remaining with DInf 0.0000000e+00                 5s
#
#      454 PPushes remaining with PInf 0.0000000e+00                 5s
#        0 PPushes remaining with PInf 0.0000000e+00                 5s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      5s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2585    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.720000e+03, 2585 iterations, 0.36 seconds (0.44 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 329
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    8s
#      0     0 2720.00000    0   62          - 2720.00000      -     -    8s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 100
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 162
#      0     0 2720.00000    0   62          - 2720.00000      -     -   23s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 133
#      0     0 2720.00000    0   62          - 2720.00000      -     -   28s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.636 < 1)
# 	Set size: 221
# 	Found a subset which violate a SEC (flow = 0.727 < 1)
# 	Set size: 124
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 93
#      0     0 2720.00000    0    -          - 2720.00000      -     -   37s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 131
#      0     0 2720.00000    0    -          - 2720.00000      -     -   42s
#      0     0 2720.00000    0   14          - 2720.00000      -     -   42s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 30
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 126
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 35
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 343
#      0     0 2720.00000    0   14          - 2720.00000      -     -   50s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 439
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 117
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 23
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 119
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 105
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 313
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 282
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 117
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 96
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 163
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 142
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# Separation round!
# *    0     0               0    2720.0000000 2720.00000  0.00%     -  120s
#
# Cutting planes:
#   Lazy constraints: 29
#
# Explored 1 nodes (25342 simplex iterations) in 120.17 seconds (8.44 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 834, time in user-callback 115.60 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2658 rows, 195806 columns and 395156 nonzeros
# Model fingerprint: 0x87b8bbaf
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 320
# Presolve removed 24 rows and 0 columns
# Presolve time: 0.21s
# Presolved: 2634 rows, 195806 columns, 395108 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 441
# Root relaxation presolved: 2635 rows, 195806 columns, 395110 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.9963700e+02   1.074375e+02   2.245823e+09      5s
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1772    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#      398 DPushes remaining with DInf 0.0000000e+00                 5s
#        0 DPushes remaining with DInf 0.0000000e+00                 5s
#
#      373 PPushes remaining with PInf 0.0000000e+00                 5s
#        0 PPushes remaining with PInf 0.0000000e+00                 5s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      5s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2462    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.720000e+03, 2462 iterations, 0.37 seconds (0.49 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 94
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -   10s
#      0     0 2720.00000    0   40          - 2720.00000      -     -   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 185
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 116
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 356
#      0     0 2720.00000    0   40          - 2720.00000      -     -   22s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 351
#      0     0 2720.00000    0   40          - 2720.00000      -     -   25s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 54
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 63
# 	Found a subset which violate a SEC (flow = 0.875 < 1)
# 	Set size: 33
#      0     0 2720.00000    0    -          - 2720.00000      -     -   31s
#      0     0 2720.00000    0   10          - 2720.00000      -     -   31s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 247
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 80
#      0     0 2720.00000    0   10          - 2720.00000      -     -   40s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 47
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 420
#      0     0 2720.00000    0   10          - 2720.00000      -     -   49s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 54
#      0     0 2720.00000    0   10          - 2720.00000      -     -   54s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 253
#      0     0 2720.00000    0   10          - 2720.00000      -     -   58s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 403
#      0     0 2720.00000    0   10          - 2720.00000      -     -   60s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 23
#      0     0 2720.00000    0   10          - 2720.00000      -     -   66s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 201
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 397
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 178
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 129
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 126
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 77
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 409
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 201
#      0     2 2720.00000    0    8          - 2720.00000      -     -  100s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 206
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 142
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 70
#      2     4 2720.00000    1   18          - 2720.00000      -   250  110s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
#      3     6 2720.00000    2   12          - 2720.00000      -   272  117s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#      7     4 2720.00000    3    -          - 2720.00000      -   141  142s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 63
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 63
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 63
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 194
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 194
#     12     9 2720.00000    3   12          - 2720.00000      -  88.0  169s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 80
#     13     9 2720.00000    3   10          - 2720.00000      -  95.5  174s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 10
#     14     1 2720.00000    3    -          - 2720.00000      -   112  181s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 197
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 331
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 211
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 419
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 310
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 405
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
#     22     7 2720.00000    3    -          - 2720.00000      -  91.0  213s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 190
#     23     8 2720.00000    4   12          - 2720.00000      -  92.4  218s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.600 < 1)
# 	Set size: 304
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 13
#     24     8 2720.00000    4   22          - 2720.00000      -   102  221s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 190
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 152
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 272
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 17
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 138
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
#     30    10 2720.00000    3    -          - 2720.00000      -  85.4  252s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
#     31    11 2720.00000    5   12          - 2720.00000      -  86.3  259s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 92
#     32    11 2720.00000    5    -          - 2720.00000      -  92.0  264s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 131
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 10
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 324
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
#     37    15 2720.00000    2   16          - 2720.00000      -  87.1  291s
# Separation round!
# Separation round!
# *   38    11               3    2720.0000000 2720.00000  0.00%  84.8  305s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 347
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 286
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 265
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 187
#     43    11     cutoff    4      2720.00000 2720.00000  0.00%  83.2  326s
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 351
#
# Cutting planes:
#   Lazy constraints: 65
#
# Explored 46 nodes (23817 simplex iterations) in 335.99 seconds (19.67 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 2625, time in user-callback 326.29 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3101 rows, 195806 columns and 396042 nonzeros
# Model fingerprint: 0xc52dd3a8
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 320
# Presolve removed 38 rows and 0 columns
# Presolve time: 0.23s
# Presolved: 3063 rows, 195806 columns, 395966 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 441
# Root relaxation presolved: 3064 rows, 195806 columns, 395968 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.0134600e+02   2.187061e+02   2.425471e+09      5s
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1797    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#      397 DPushes remaining with DInf 0.0000000e+00                 5s
#        0 DPushes remaining with DInf 0.0000000e+00                 5s
#
#      348 PPushes remaining with PInf 0.0000000e+00                 5s
#        0 PPushes remaining with PInf 0.0000000e+00                 5s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      5s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2487    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.720000e+03, 2487 iterations, 0.36 seconds (0.46 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 427
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    7s
#      0     0 2720.00000    0   20          - 2720.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 109
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 199
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 388
#      0     0 2720.00000    0   20          - 2720.00000      -     -   18s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 180
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 187
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 108
#      0     0 2720.00000    0    -          - 2720.00000      -     -   28s
#      0     0 2720.00000    0   28          - 2720.00000      -     -   28s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.600 < 1)
# 	Set size: 86
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 31
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 28
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 13
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 406
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 101
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 200
#      0     0 2720.00000    0   28          - 2720.00000      -     -   45s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 72
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 331
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 80
#      0     2 2720.00000    0    8          - 2720.00000      -     -   61s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 74
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 30
#      1     4 2720.00000    1   28          - 2720.00000      -   261   67s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 30
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
#      3     2 2720.00000    2    -          - 2720.00000      -   180   79s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
#      4     3 2720.00000    2    -          - 2720.00000      -   156   86s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
#      5     4 2720.00000    2    -          - 2720.00000      -   158   92s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.600 < 1)
# 	Set size: 67
#      6     5 2720.00000    2   26          - 2720.00000      -   145   98s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
#      7     4 2720.00000    2    -          - 2720.00000      -   125  104s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 61
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 17
#      8     5 2720.00000    2   14          - 2720.00000      -   110  110s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 17
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 17
#     11     7 2720.00000    3   22          - 2720.00000      -  81.3  128s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 329
#     12     0 2720.00000    2    -          - 2720.00000      -  79.4  131s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 80
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 163
#     14     2 2720.00000    3    -          - 2720.00000      -  76.9  141s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 147
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 305
#     16     4 2720.00000    4    -          - 2720.00000      -  78.1  149s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 245
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 251
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 179
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 119
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 229
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 13
#     19    10 2720.00000    2   20          - 2720.00000      -  79.9  165s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 279
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 69
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 78
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 19
#     21    10 2720.00000    3   16          - 2720.00000      -  99.0  174s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 95
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 98
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 134
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 19
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 67
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 246
#     26    18 2720.00000    3    -          - 2720.00000      -  89.7  202s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 106
#     27    19 2720.00000    5   16          - 2720.00000      -  90.6  207s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#     28    19 2720.00000    4   16          - 2720.00000      -  88.8  213s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 82
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 67
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#     31    19 2720.00000    4   20          - 2720.00000      -  88.5  231s
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 50
# Separation round!
#     34    17 2720.00000    3    8          - 2720.00000      -  88.4  251s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 390
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 261
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 295
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 356
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 157
# Separation round!
# Separation round!
# *   42    22               4    2720.0000000 2720.00000  0.00%  84.1  294s
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 163
# Separation round!
#     45    22     cutoff    6      2720.00000 2720.00000  0.00%  84.8  312s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 76
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 67
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 306
#     48    22     cutoff    4      2720.00000 2720.00000  0.00%  92.8  327s
# Separation round!
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 252
#
# Cutting planes:
#   Lazy constraints: 66
#
# Explored 52 nodes (23362 simplex iterations) in 344.06 seconds (16.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 1584, time in user-callback 335.98 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 7974 rows, 195806 columns and 411104 nonzeros
# Model fingerprint: 0x67fa220d
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 320
# Presolve removed 98 rows and 0 columns
# Presolve time: 0.29s
# Presolved: 7876 rows, 195806 columns, 410834 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 441
# Root relaxation presolved: 7877 rows, 195806 columns, 410836 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.9963700e+02   1.074375e+02   2.223573e+09      5s
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2343    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 5s
#
#      441 PPushes remaining with PInf 0.0000000e+00                 5s
#        0 PPushes remaining with PInf 0.0000000e+00                 5s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      5s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3118    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.720000e+03, 3118 iterations, 0.43 seconds (0.55 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 417
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    7s
#      0     0 2720.00000    0   36          - 2720.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 325
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 83
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 273
#      0     0 2720.00000    0   36          - 2720.00000      -     -   19s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 227
#      0     0 2720.00000    0   36          - 2720.00000      -     -   23s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.833 < 1)
# 	Set size: 378
# 	Found a subset which violate a SEC (flow = 0.167 < 1)
# 	Set size: 51
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
#      0     0 2720.00000    0    -          - 2720.00000      -     -   31s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 82
#      0     0 2720.00000    0    -          - 2720.00000      -     -   37s
#      0     0 2720.00000    0   16          - 2720.00000      -     -   37s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 30
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 62
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 308
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 367
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 77
#      0     0 2720.00000    0   16          - 2720.00000      -     -   54s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 69
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 152
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 304
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 190
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 124
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 10
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 80
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 294
# Separation round!
# H    0     0                    2720.0000000 2720.00000  0.00%     -  100s
#
# Cutting planes:
#   Lazy constraints: 23
#
# Explored 1 nodes (21944 simplex iterations) in 100.09 seconds (9.76 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 1287, time in user-callback 94.73 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 11961 rows, 195806 columns and 422622 nonzeros
# Model fingerprint: 0xf1b179a0
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 320
# Presolve removed 196 rows and 0 columns
# Presolve time: 0.26s
# Presolved: 11765 rows, 195806 columns, 422072 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 441
# Root relaxation presolved: 11766 rows, 195806 columns, 422074 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.0134600e+02   2.187061e+02   2.411972e+09      5s
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2601    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#      365 DPushes remaining with DInf 0.0000000e+00                 5s
#        0 DPushes remaining with DInf 0.0000000e+00                 5s
#
#      415 PPushes remaining with PInf 0.0000000e+00                 5s
#        0 PPushes remaining with PInf 0.0000000e+00                 5s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      5s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3320    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.720000e+03, 3320 iterations, 0.44 seconds (0.62 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 386
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    7s
#      0     0 2720.00000    0   40          - 2720.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 278
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 394
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 235
#      0     0 2720.00000    0   40          - 2720.00000      -     -   17s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 419
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 351
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 56
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 77
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 380
#      0     0 2720.00000    0    -          - 2720.00000      -     -   24s
#      0     0 2720.00000    0   10          - 2720.00000      -     -   24s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 243
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
#      0     0 2720.00000    0   10          - 2720.00000      -     -   34s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 235
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 211
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 47
#      0     0 2720.00000    0   10          - 2720.00000      -     -   55s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 61
#      0     0 2720.00000    0   10          - 2720.00000      -     -   60s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 277
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 349
#      0     0 2720.00000    0   10          - 2720.00000      -     -   67s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 281
#      0     0 2720.00000    0   10          - 2720.00000      -     -   70s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 63
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 344
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 52
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 31
# Separation round!
# H    0     0                    2720.0000000 2720.00000  0.00%     -   98s
#
# Cutting planes:
#   Lazy constraints: 24
#
# Explored 1 nodes (20830 simplex iterations) in 98.19 seconds (8.58 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 1553, time in user-callback 93.46 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38541 rows, 195806 columns and 528942 nonzeros
# Model fingerprint: 0xeb48c79c
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 320
# Presolve removed 700 rows and 0 columns
# Presolve time: 0.31s
# Presolved: 37841 rows, 195806 columns, 526376 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 441
# Root relaxation presolved: 37842 rows, 195806 columns, 526378 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.36s
#
# Barrier statistics:
#  Dense cols : 99
#  AA' NZ     : 1.030e+06
#  Factor NZ  : 3.939e+06 (roughly 100 MB of memory)
#  Factor Ops : 1.018e+09 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.50614401e+07  0.00000000e+00  9.09e+02 0.00e+00  1.35e+02     6s
#    1   5.47257236e+06 -1.18059107e+05  2.20e+02 1.65e+01  3.00e+01     6s
#    2   9.76960212e+05 -7.53996464e+04  3.96e+01 4.96e-01  5.16e+00     6s
#
# Barrier performed 2 iterations in 5.80 seconds (1.77 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.36s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2258    2.7200000e+03   0.000000e+00   0.000000e+00      6s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 6s
#
#      423 PPushes remaining with PInf 0.0000000e+00                 6s
#        0 PPushes remaining with PInf 0.0000000e+00                 6s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      6s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2946    2.7200000e+03   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 2.720000e+03, 2946 iterations, 0.90 seconds (0.90 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 423
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    7s
#      0     0 2720.00000    0   60          - 2720.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 121
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 184
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 295
#      0     0 2720.00000    0   60          - 2720.00000      -     -   20s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.857 < 1)
# 	Set size: 280
# 	Found a subset which violate a SEC (flow = 0.714 < 1)
# 	Set size: 172
#      0     0 2720.00000    0    -          - 2720.00000      -     -   36s
#      0     0 2720.00000    0   20          - 2720.00000      -     -   36s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 355
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 394
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 162
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 202
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39

# %% [markdown]
# ### Graph

# %%
# Convert pairs to string format for labeling
pairs_2 = [(2, 3), (2, 4), (2, 5), (3, 4), (3, 5), (4, 5)]
pair_labels = [f"({card}, {l})" for card, l in pairs_2]

# Plotting computational time
plt.figure(figsize=(10, 6))
plt.bar(pair_labels, solve_time_q3_frac, color='skyblue')
plt.hlines(No_cardinality_frac, xmin=-0.5, xmax=len(pair_labels)-0.5, colors='red', label='No added constraints')
plt.xlabel('K, L Pairs')
plt.ylabel('Solve Time (Seconds)')
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.show()

# %% [markdown]
# ### Table

# %%
int_q3 = pd.DataFrame({'time': solve_time_q3, 'obj': objective_list_q3, 'rows': nrows_list_q3, 'iter': iter_q3})
int_q3['type'] = 'integer'

frac_q3 = pd.DataFrame({'time': solve_time_q3_frac, 'obj': objective_list_q3_frac, 'rows': nrows_list_q3_frac, 'iter': iter_q3_frac})
frac_q3['type'] = 'integer'



pd.concat([int_q3, frac_q3], axis='rows').to_csv('question 3')

latex_table_temp = pd.concat([int_q3, frac_q3], axis='rows')
latex_table_3_frac = latex_table_temp.to_latex(index = False)
