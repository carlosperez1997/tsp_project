# %% [markdown]
# # Set up

# %%
from typing import Dict, Tuple, List
from math import sqrt
from dataclasses import dataclass
from gurobipy import Model, GRB, tupledict, LinExpr, GurobiError
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

import numpy as np
import os
import re

from itertools import combinations

from graph_tool import Graph, EdgePropertyMap
from graph_tool.generation import complete_graph
from graph_tool.flow import boykov_kolmogorov_max_flow, min_st_cut
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/harrysmacbookpro/Documents/GitHub/tsp_project/master master file.ipynb Cell 2 line 4
#       <a href='vscode-notebook-cell:/Users/harrysmacbookpro/Documents/GitHub/tsp_project/master%20master%20file.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> from math import sqrt
#       <a href='vscode-notebook-cell:/Users/harrysmacbookpro/Documents/GitHub/tsp_project/master%20master%20file.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> from dataclasses import dataclass
# ----> <a href='vscode-notebook-cell:/Users/harrysmacbookpro/Documents/GitHub/tsp_project/master%20master%20file.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> from gurobipy import Model, GRB, tupledict, LinExpr, GurobiError
#       <a href='vscode-notebook-cell:/Users/harrysmacbookpro/Documents/GitHub/tsp_project/master%20master%20file.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/Users/harrysmacbookpro/Documents/GitHub/tsp_project/master%20master%20file.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> from matplotlib.figure import Figure
#
# ModuleNotFoundError: No module named 'gurobipy'

# %% [markdown]
# # Define classes

# %% [markdown]
# ## Data loader

# %%
class TspDataLoader:
    """ Class to load and process data for TSP instances. """

    def __init__(self, dir='data'):
        self.dir = dir

    def load_problem(self, problem):
        """ Load a TSP problem and return its vertices count and cost matrix. """
        file_name = "data/"+problem

        # Read file content
        with open(file_name, 'r') as file:
            content = file.read()

        problem_type = problem.split('.')[-1]

        n = int(re.search(r'\d+', problem).group())
        # 64 is actually 65 
        if n == 64:
            n = 65

        # Process the file content
        data_lines = content.split('\n')

        try:
            start_index = data_lines.index('EDGE_WEIGHT_SECTION')
        except:
            start_index = data_lines.index('NODE_COORD_SECTION')
            
        # Extract the data lines after 'EDGE_WEIGHT_SECTION'
        edge_weight_lines = data_lines[start_index + 1:][:-2]

        # Parse the distance matrix (lines are not rows)
        if problem_type == 'atsp':
            distance_matrix = [list(map(int, line.split())) for line in edge_weight_lines if line.strip()]

            def flatten(l):
                return [item for sublist in l for item in sublist]

            distance_list = flatten(distance_matrix)
            print(len(distance_list))

            my_matrix = np.array(distance_list).reshape((n, n))
            my_matrix.shape
        else:
            try:
                print('has_index')
                ys = [ float(line.split(' ')[3])  for line in edge_weight_lines if line.strip()]
                xs = [ float(line.split(' ')[2])  for line in edge_weight_lines if line.strip()]
            except:
                ys = [ float(line.split(' ')[2])  for line in edge_weight_lines if line.strip()]
                xs = [ float(line.split(' ')[1])  for line in edge_weight_lines if line.strip()]

        for line in data_lines:
            if 'EDGE_WEIGHT_TYPE' in line:
                weight_type = line.split(':')[1].strip()
        print(weight_type)

        V = range(n)
        if problem_type == 'atsp':
            cost = {
                (i, j): my_matrix[i,j]
                for i in V for j in V if i != j
            }
        else:
            if weight_type == 'GEO':
                cost = {
                    (i, j): haversine_distance((xs[i], ys[i]), (xs[j], ys[j]))
                    for i in V for j in V if i != j
                }
            else:
                cost = {
                    (i, j): math.sqrt((xs[i] - xs[j]) ** 2 + (ys[i] - ys[j]) ** 2)
                    for i in V for j in V if i != j
                }

        # Initialize an array to store the 5 closest vertices for each vertex
        closest_vertices_array = []

        # For each vertex, find the 5 closest vertices and add to the array
        for i in V:
            sorted_vertices = sorted(V, key=lambda j: cost[i, j] if i != j else float('inf'))
            closest_vertices_array.append(sorted_vertices[1:6])  # Skip the first one (itself) and take the next five

        return n, cost, closest_vertices_array

# %% [markdown]
# ## Integer solver

# %%
class TspInstance:
    """ An instance of the Travelling Salesman Problem. """

    def __init__(self, n_vertices, cost, closest_vertices_array = None, x=None, y=None):
        """
        Initialize a TSP instance.

        Parameters
        ----------
        n_vertices : int
            Number of vertices in the graph.
        cost : dict[tuple[int, int], float]
            Dictionary with arcs as key, and their corresponding costs as values.
        x : list[float], optional
            X coordinates of the vertices (for plotting).
        y : list[float], optional
            Y coordinates of the vertices (for plotting).
        """
        self.n_vertices = n_vertices
        self.cost = cost
        self.closest_vertices_array = closest_vertices_array if closest_vertices_array is not None else []
        self.x = x if x is not None else []
        self.y = y if y is not None else []
        
@dataclass
class TspSolution:
    """ Solution to an instance of the Travelling Salesman Problem.

        Attributes
        ----------
        instance: TspInstance
            Reference to the TSP instance being solved.
        tour: List[int]
            Ordered list of vertices visited (without repeating the first one).
        cost: float
            Travel cost of the tour.
    """

    instance: TspInstance
    tour: List[int]
    cost: float
    lazy_constraints_added: List[dict]
    model_metrics: Dict

    def plot(self) -> Tuple[Figure, plt.Axes]:
        """ Plots the solution of the TSP.
        
            Vertices are black dots, the solution is represented by red lines.

            Returns
            -------
            A tuple with the figure and axes object from matplotlib.    
        """

        xy = [(self.instance.x[i], self.instance.y[i]) for i in self.tour + [self.tour[0]]]

        fig, ax = plt.subplots(figsize=(10, 10))
        ax.scatter(self.instance.x, self.instance.y, color='black')
        
        for pt1, pt2 in zip(xy[1:], xy[:-1]):
            x1, y1 = pt1
            x2, y2 = pt2
            ax.plot([x1, x2], [y1, y2], color='red')

        ax.set_title(f"TSP Solution. Num vertices: {self.instance.n_vertices}. Tour cost: {self.cost:.2f}.")
        ax.set_axis_off()

        return fig, ax
    
class TspIntegerBCSolver:
    """ 
    Solver for the Travelling Salesman Problem using the branch-and-cut algorithm.

    This solver applies the Dantzig-Fulkerson-Johnson (DFJ) formulation of the TSP
    and focuses on separating subtour elimination constraints (SECs) only on integer solutions.

    Attributes:
    _instance : TspInstance
        The instance of the TSP to be solved.
    _V : List[int]
        List of vertex indices in the TSP instance.
    _A : List[Tuple[int, int]]
        List of arcs (edges between pairs of vertices) in the TSP instance.
    _model : Model
        The Gurobi model for the TSP instance.
    _x : tupledict
        Gurobi variables representing whether an arc is included in the tour.
    """

    def __init__(self, instance: TspInstance, cardinality=None, l = None):
        """
        Initializes the solver with a TSP instance and builds the model.

        Parameters:
        instance (TspInstance): The TSP instance to be solved.
        """
        # Store the TSP instance and create lists of vertices and arcs
        self._instance = instance
        self._V = list(range(self._instance.n_vertices))
        self._A = list(self._instance.cost.keys())
        self.lazy_constraints_added = []  # Initialize an empty list to store lazy constraints
        self.cardinality = cardinality  # Store the cardinality parameter
        self._L = l  # Contraint to be added for l closest vertices

        # Build the optimization model
        self.__build_model()


    def __build_model(self):
        """ 
        Builds the initial DFJ model for the TSP without subtour elimination constraints (SECs).
        """
        # Initialize the Gurobi model
        self._model = Model()

        # Add variables representing whether each arc is included in the tour
        self._x = self._model.addVars(self._A, obj=self._instance.cost, vtype=GRB.BINARY, name='x')

        # Add constraints to ensure exactly one outgoing and one incoming arc for each vertex
        self._model.addConstrs((self._x.sum(i, '*') == 1 for i in self._V), name='outgoing')
        self._model.addConstrs((self._x.sum('*', i) == 1 for i in self._V), name='incoming')

        # Question 2: Add constraints to ensure x(i,j) + x(j,k)  <= 1
        if self.cardinality == 2.2 or self.cardinality == 2.3:
            self._model.addConstrs((self._x[i, j] + self._x[j, i] <= 1 for i in self._V for j in self._V if i != j), name='cardinality two')

        # Question 2: Add constraints to ensure x(i,j) + x(j,k) +x(k,i) <= 2
        if self.cardinality == 2.3:
            self._model.addConstrs((self._x[i, j] + self._x[j, k] + self._x[k, i]<= 2 for i in self._V for j in self._V for k in self._V if i != j and j != k and k != i), name='cardinality three')

        # Question 3 constraints of the type (2,L) 
        if self.cardinality == 3.2 or self.cardinality == 3.3 or self.cardinality ==3.4:

            # Add custom constraints for the closest l vertices
            for i in self._V:

                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]

                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    self._model.addConstr(self._x[i, j] + self._x[j, i] <= 1, name=f'closest_constraint_{i}_{j}')

        # Question 3 constraints of the type (3,L) 
        if self.cardinality ==3.3 or self.cardinality ==3.4:

            # Add custom constraints for the closest l vertices
            for i in self._V:

                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]

                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    for k in closest_vertices:
                        if k != j:
                            self._model.addConstr(self._x[i, j] + self._x[j, k] + self._x[k, i]<= 2, name=f'closest_constraint_{i}_{j}_{k}')

        # Question 3 constraints of the type (4,L) 
        if self.cardinality ==3.4:

            # Add custom constraints for the closest l vertices
            for i in self._V:

                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]

                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    for k in closest_vertices:
                            for z in closest_vertices:
                                if j != k and j != z and k != z:
                                    self._model.addConstr(self._x[i, j] + self._x[j, k] + self._x[k, z] + self._x[z, i] <= 3, name=f'closest_constraint_{i}_{j}_{k}_{z}')



    def __next_vertex(self, i: int) -> int:
        """
        Finds the next vertex in the current solution, starting from vertex i.

        Parameters:
        i (int): The starting vertex index.

        Returns:
        int: The index of the next vertex in the tour.
        """
        # Ensure the vertex index is valid
        assert 0 <= i < self._instance.n_vertices

        # Loop through all vertices to find the next one in the tour
        for j in self._V:
            if i != j:
                try:
                    # Inside a callback, retrieve the solution using cbGetSolution
                    val = self._model.cbGetSolution(self._x[i, j])
                except:
                    # Otherwise, access the variable's value directly
                    val = self._x[i, j].X

                # If the arc is part of the solution, return the next vertex
                if val > 0.5:
                    return j

        # If no successor is found, raise an error
        assert False, f"Vertex {j} has no successor?!"

    def __tour_staring_at(self, i: int) -> List[int]:
        """
        Constructs a tour (or subtour) starting at vertex i based on the current solution.

        Parameters:
        i (int): The starting vertex index.

        Returns:
        List[int]: A list of vertex indices representing the tour.
        """
        # Ensure the vertex index is valid
        assert 0 <= i < self._instance.n_vertices

        # Initialize the tour with the starting vertex
        tour = [i]
        current = self.__next_vertex(i)

        # Continue adding vertices to the tour until it loops back to the start
        while current != i:
            tour.append(current)
            current = self.__next_vertex(current)

        return tour

    def __add_sec_for(self, S: List[int]) -> None:
        """
        Adds a subtour elimination constraint (SEC) for the vertices in set S.

        Parameters:
        S (List[int]): A list of vertex indices forming a subtour.
        """
        # Ensure the subtour has a valid number of vertices
        assert 0 < len(S) < self._instance.n_vertices
   
        # Record the constraint information
        constraint_info = {
            'subtour': S,
            'constraint': sum(self._x[i, j] for (i, j) in self._A if i in S and j not in S) >= 1
        }

        self.lazy_constraints_added.append(constraint_info)
        
        # Add the actual lazy constraint to the model
        self._model.cbLazy(sum(self._x[i, j] for (i, j) in self._A if i in S and j not in S) >= 1)

    def __separate(self, where: int) -> None:
        """ Separates eventual violated SECs. """

        if where != GRB.Callback.MIPSOL:
            return
        
        # Set of vertices not yet placed in a tour
        remaining = set(self._V)

        while len(remaining) > 0:
            # Get any vertex in set `remaining`
            current = next(iter(remaining))

            # Get the subtour which includes the vertex
            subtour = self.__tour_staring_at(current)

            # If the tour visits all vertices, nothing to do
            if len(subtour) == self._instance.n_vertices:
                return

            # Otherwise, it's a subtour => Add a SEC
            self.__add_sec_for(subtour)

            # Update set `remaining`
            remaining -= set(subtour)

    def solve(self) -> TspSolution:
        """ Solves the TSP DFJ model and returns the solution.
        
            It throws a RuntimeError if Gurobi cannot solve the model to optimality.

            Returns
            -------
            A TspSolution object with details about the solution.
        """

        # We must set this parameter to use callbacks
        self._model.setParam(GRB.Param.LazyConstraints, 1)

        # Gurobi always passes two parameters to the callback: `model` and `where`
        self._model.optimize(lambda _, where: self.__separate(where))

        if self._model.Status != GRB.OPTIMAL:
            raise RuntimeError(f"Could not find the optimal solution. Gurobi status = {self._model.Status}")

        model_metrics = {} 
        for metric in ["NumVars", "ObjVal", "ObjBound", "IterCount", "SolCount", "NodeCount", "Runtime"]:
            model_metrics[metric] = self._model.getAttr(metric)

        return TspSolution(
            instance=self._instance,
            tour=self.__tour_staring_at(0),
            cost=self._model.ObjVal,
            model_metric=model_metrics,
            lazy_constraints_added=self.lazy_constraints_added
        )

# %% [markdown]
# # Fractional solver

# %%
class TspFractionalBCSolver:
    """ Solver for the Travelling Salesman Problem.
    
        It uses the branch-and-cut algorithm applied to the "DFJ" formulation.
        Subtour elimination constraints are separated on integer and
        fractional solutions alike.
    """

    _EPS: float = 1e-6

    _instance: TspInstance
    _V: List[int]
    _A: List[Tuple[int, int]]
    _g: Graph
    _cap: EdgePropertyMap
    _model: Model
    _x: tupledict

    def __init__(self, instance: TspInstance, cardinality=None, l = None):
        """ Initialises the solver and builds the model.
        
            Parameters
            ----------
            instance: TspInstance
                The TSP instance.
        """

        self._instance = instance
        self._V = list(range(self._instance.n_vertices))
        self._A = list(self._instance.cost.keys())
        self.cardinality = cardinality  # Store the cardinality parameter
        self.__build_graph()
        self.__build_model()
        self._L = l  # Contraint to be added for l closest vertices

        

    def __build_graph(self) -> None:
        """ Builds the graph for cut separation. """
        self._g = complete_graph(N=self._instance.n_vertices, self_loops=False, directed=True)
        self._cap = self._g.new_edge_property(value_type='double')
        self._g.edge_properties['cap'] = self._cap       

    def __build_model(self) -> None:
        """ Builds the DFJ model without SECs. """
         
        self._model = Model()
        self._x = self._model.addVars(self._A, obj=self._instance.cost, vtype=GRB.BINARY, name='x')
        self._model.addConstrs((self._x.sum(i, '*') == 1 for i in self._V), name='outgoing')
        self._model.addConstrs((self._x.sum('*', i) == 1 for i in self._V), name='incoming')

        # Question 2: Add constraints to ensure x(i,j) + x(j,k)  <= 1
        if self.cardinality == 2.2 or self.cardinality == 2.3:
            self._model.addConstrs((self._x[i, j] + self._x[j, i] <= 1 for i in self._V for j in self._V if i != j), name='cardinality two')

        # Question 2: Add constraints to ensure x(i,j) + x(j,k) +x(k,i) <= 2
        if self.cardinality == 2.3:
            self._model.addConstrs((self._x[i, j] + self._x[j, k] + self._x[k, i]<= 2 for i in self._V for j in self._V for k in self._V if i != j and j != k and k != i), name='cardinality three')

        # Question 3 constraints of the type (2,L) 
        if self.cardinality == 3.2 or self.cardinality == 3.3 or self.cardinality ==3.4:

            # Add custom constraints for the closest l vertices
            for i in self._V:

                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]

                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    self._model.addConstr(self._x[i, j] + self._x[j, i] <= 1, name=f'closest_constraint_{i}_{j}')

        # Question 3 constraints of the type (3,L) 
        if self.cardinality ==3.3 or self.cardinality ==3.4:

            # Add custom constraints for the closest l vertices
            for i in self._V:

                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]

                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    for k in closest_vertices:
                        if k != j:
                            self._model.addConstr(self._x[i, j] + self._x[j, k] + self._x[k, i]<= 2, name=f'closest_constraint_{i}_{j}_{k}')

        # Question 3 constraints of the type (4,L) 
        if self.cardinality ==3.4:

            # Add custom constraints for the closest l vertices
            for i in self._V:

                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]

                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    for k in closest_vertices:
                            for z in closest_vertices:
                                if j != k and j != z and k != z:
                                    self._model.addConstr(self._x[i, j] + self._x[j, k] + self._x[k, z] + self._x[z, i] <= 3, name=f'closest_constraint_{i}_{j}_{k}_{z}')

    def __next_vertex(self, i: int) -> int:
        """ Gets the vertex visited immediately after i in the current TSP solution.

            This is the (only) vertex j such that x[i,j] == 1. This function works both
            when inside a callback (when the value of x must be retrieved via cbGetSolution)
            and after the optimisation is over (when the value of X can be accessed via X).
        """

        assert 0 <= i < self._instance.n_vertices

        for j in self._V:
            if i != j:
                try:
                    # If inside a call-back, we use cbGetSolution
                    val = self._model.cbGetSolution(self._x[i, j])
                except:
                    # Otherwise we use .X
                    val = self._x[i, j].X

                if val > 0.5:
                    return j

        assert False, f"Vertex {j} has no successor?!"

    def __tour_staring_at(self, i: int) -> List[int]:
        """ Gives the (sub)tour starting at a given vertex i in the current TSP solution. """

        assert 0 <= i < self._instance.n_vertices

        tour = [i]
        current = self.__next_vertex(i)

        while current != i:
            tour.append(current)
            current = self.__next_vertex(current)

        return tour

    def __add_sec_for(self, S: List[int]) -> None:
        """ Adds a Subtour Elimination Constraint for set S. """

        assert 0 < len(S) < self._instance.n_vertices

        self._model.cbLazy(sum(self._x[i, j] for (i, j) in self._A if i in S and j not in S) >= 1)

    def __set_capacity(self) -> None:
        """ Sets graph capacity based on current solution. """

        for e in self._g.edges():
            i, j = e.source(), e.target()

            try: # If we are in MIPSOL
                xval = self._model.cbGetSolution(self._x[i,j])
            except: # If we are in MIPNODE
                xval = self._model.cbGetNodeRel(self._x[i,j])

            self._cap[e] = xval

    def __separate(self, where: int) -> None:
        """ Separates eventual violated SECs. """

        if where not in [GRB.Callback.MIPSOL, GRB.Callback.MIPNODE]:
            return

        # In MIPNODE, we must ensure that we have the optimal solution to the
        # linear relaxation at that node. Otherwise we are not "authorised"
        # to call cbGetNodeRel. See:
        # https://www.gurobi.com/documentation/9.1/refman/py_model_cbgetnoderel.html
        if where == GRB.Callback.MIPNODE and self._model.cbGet(GRB.Callback.MIPNODE_STATUS) != GRB.OPTIMAL:
            return
        
        self.__set_capacity()

        source = self._g.vertex(0)
        already_added = set()

        print('Separation round!')

        for i in range(1, self._instance.n_vertices):
            if i in already_added:
                continue

            target = self._g.vertex(i)
            residual = boykov_kolmogorov_max_flow(
                g=self._g, source=source, target=target,
                capacity=self._cap
            )
            
            flow = residual.copy()
            flow.a = self._cap.a - residual.a

            total_flow = sum(flow[a] for a in target.in_edges())

            if total_flow < 1 - self._EPS: # Avoid numerical issues
                print(f"\tFound a subset which violate a SEC (flow = {total_flow:.3f} < 1)")
                
                cut = min_st_cut(g=self._g, source=source,capacity=self._cap, residual=residual)

                assert cut[source] == True
                assert cut[target] == False

                subtour = [j for j in self._V if cut[self._g.vertex(j)] == False]

                assert len(subtour) < self._instance.n_vertices

                print(f"\tSet size: {len(subtour)}")

                self.__add_sec_for(subtour)

                already_added = already_added.union(subtour)

    def solve(self) -> TspSolution:
        """ Solves the TSP DFJ model and returns the solution.
        
            It throws a RuntimeError if Gurobi cannot solve the model to optimality.

            Returns
            -------
            A TspSolution object with details about the solution.
        """

        # We must set this parameter to use callbacks
        self._model.setParam(GRB.Param.LazyConstraints, 1)

        # Gurobi always passes two parameters to the callback: `model` and `where`
        self._model.optimize(lambda _, where: self.__separate(where))

        if self._model.Status != GRB.OPTIMAL:
            raise RuntimeError(f"Could not find the optimal solution. Gurobi status = {self._model.Status}")

        model_metrics = {} 
        for metric in ["NumVars", "ObjVal", "ObjBound", "IterCount", "SolCount", "NodeCount", "Runtime"]:
            model_metrics[metric] = self._model.getAttr(metric)

        return TspSolution(
            instance=self._instance,
            tour=self.__tour_staring_at(0),
            cost=self._model.ObjVal,
            model_metric=model_metrics,
            lazy_constraints_added=self.lazy_constraints_added
        )

# %% [markdown]
# # Question 1

# %%
# Load data set 1
tsp_loader = TspDataLoader()
n_vertices, cost, closest_vertices_array = tsp_loader.load_problem('rbg323.atsp')
# Out:
# 104329
# EXPLICIT

# %%
# Subtours added
from helper import lazy_constraints_size_count

i = TspInstance(n_vertices=vertices, cost=cost)
s = TspIntegerBCSolver(instance=i, cardinality=None)
solution = s.solve()

lazy_constraints_size_count(solution.lazy_constraints_added, max_level=3)

# %%
# Output time and objective value for different number of vertices
time_list_int = list()
objective_list_int = list()
time_list_frac = list()
objective_list_frac = list()
nrows_list_int = list()
vertices_list = range(23, 324, 25)
nrows_list_frac = list()

for vert in vertices_list:
    filtered_vertices = vert
    filtered_cost = {(i, j): cost_val for (i, j), cost_val in cost.items() if i < filtered_vertices and j < filtered_vertices}

    i_int = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s_int = TspIntegerBCSolver(instance=i_int, cardinality=None)
    solution = s_int.solve()

    time_list_int.append(s_int._model.Runtime)
    objective_list_int.append(s_int._model.ObjVal)
    nrows_list_int.append(s_int._model.NumConstrs)
    
    i_frac = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s_frac = TspFractionalBCSolver(instance=i_frac, cardinality=None)
    solution = s_frac.solve()

    time_list_frac.append(s_frac._model.Runtime)
    objective_list_frac.append(s_frac._model.ObjVal)
    nrows_list_frac.append(s_int._model.NumConstrs)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-12
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 46 rows, 506 columns and 1012 nonzeros
# Model fingerprint: 0xd3a534b7
# Variable types: 0 continuous, 506 integer (506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 46 rows, 506 columns, 1012 nonzeros
# Variable types: 0 continuous, 506 integer (506 binary)
#
# Root relaxation: objective 1.920000e+02, 57 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  192.00000    0    -          -  192.00000      -     -    0s
# *    0     0               0     192.0000000  192.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 14
#
# Explored 1 nodes (62 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 192
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.920000000000e+02, best bound 1.920000000000e+02, gap 0.0000%
#
# User-callback calls 109, time in user-callback 0.01 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 46 rows, 506 columns and 1012 nonzeros
# Model fingerprint: 0xd3a534b7
# Variable types: 0 continuous, 506 integer (506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Presolve time: 0.00s
# Presolved: 46 rows, 506 columns, 1012 nonzeros
# Variable types: 0 continuous, 506 integer (506 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
#
# Root relaxation: objective 1.920000e+02, 55 iterations, 0.00 seconds (0.00 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  192.00000    0    -          -  192.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     0  192.00000    0    -          -  192.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     0  192.00000    0    -          -  192.00000      -     -    0s
# Separation round!
# *    0     0               0     192.0000000  192.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 4
#
# Explored 1 nodes (64 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 192
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.920000000000e+02, best bound 1.920000000000e+02, gap 0.0000%
#
# User-callback calls 112, time in user-callback 0.06 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 96 rows, 2256 columns and 4512 nonzeros
# Model fingerprint: 0x9924bbf8
# Variable types: 0 continuous, 2256 integer (2256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 96 rows, 2256 columns, 4512 nonzeros
# Variable types: 0 continuous, 2256 integer (2256 binary)
#
# Root relaxation: objective 3.410000e+02, 187 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  341.00000    0    -          -  341.00000      -     -    0s
#      0     0  341.00000    0   24          -  341.00000      -     -    0s
# H    0     0                     341.0000000  341.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 38
#
# Explored 1 nodes (197 simplex iterations) in 0.05 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 341
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.410000000000e+02, best bound 3.410000000000e+02, gap 0.0000%
#
# User-callback calls 114, time in user-callback 0.04 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 96 rows, 2256 columns and 4512 nonzeros
# Model fingerprint: 0x9924bbf8
# Variable types: 0 continuous, 2256 integer (2256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 35
# Presolve time: 0.00s
# Presolved: 96 rows, 2256 columns, 4512 nonzeros
# Variable types: 0 continuous, 2256 integer (2256 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 46
#
# Root relaxation: objective 3.410000e+02, 190 iterations, 0.00 seconds (0.00 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 20
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  341.00000    0    -          -  341.00000      -     -    0s
#      0     0  341.00000    0   16          -  341.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 23
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 37
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 40
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 37
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 18
#      0     0  341.00000    0    -          -  341.00000      -     -    0s
#      0     0  341.00000    0   12          -  341.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 13
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 29
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 34
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 16
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# *    0     0               0     341.0000000  341.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 22
#
# Explored 1 nodes (693 simplex iterations) in 0.68 seconds (0.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 341
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.410000000000e+02, best bound 3.410000000000e+02, gap 0.0000%
#
# User-callback calls 167, time in user-callback 0.63 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 146 rows, 5256 columns and 10512 nonzeros
# Model fingerprint: 0xa95e0496
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 146 rows, 5256 columns, 10512 nonzeros
# Variable types: 0 continuous, 5256 integer (5256 binary)
#
# Root relaxation: objective 4.710000e+02, 313 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  471.00000    0    -          -  471.00000      -     -    0s
#      0     0  474.00000    0   18          -  474.00000      -     -    0s
# H    0     0                     474.0000000  474.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 51
#
# Explored 1 nodes (321 simplex iterations) in 0.12 seconds (0.03 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 474
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.740000000000e+02, best bound 4.740000000000e+02, gap 0.0000%
#
# User-callback calls 121, time in user-callback 0.10 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 146 rows, 5256 columns and 10512 nonzeros
# Model fingerprint: 0xa95e0496
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 35
# Presolve time: 0.01s
# Presolved: 146 rows, 5256 columns, 10512 nonzeros
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 71
#
# Root relaxation: objective 4.710000e+02, 282 iterations, 0.00 seconds (0.00 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 45
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  471.00000    0    -          -  471.00000      -     -    0s
#      0     0  471.00000    0   48          -  471.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 64
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 31
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 42
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 43
#      0     0  471.00000    0    -          -  471.00000      -     -    0s
#      0     0  471.00000    0   48          -  471.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 40
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 5
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 28
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 36
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 49
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 8
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# *    0     0               0     474.0000000  474.00000  0.00%     -    1s
#
# Cutting planes:
#   Lazy constraints: 24
#
# Explored 1 nodes (291 simplex iterations) in 1.62 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 474
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.740000000000e+02, best bound 4.740000000000e+02, gap 0.0000%
#
# User-callback calls 179, time in user-callback 1.55 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 196 rows, 9506 columns and 19012 nonzeros
# Model fingerprint: 0x72dbade5
# Variable types: 0 continuous, 9506 integer (9506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 196 rows, 9506 columns, 19012 nonzeros
# Variable types: 0 continuous, 9506 integer (9506 binary)
#
# Root relaxation: objective 7.550000e+02, 601 iterations, 0.01 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  755.00000    0    -          -  755.00000      -     -    0s
#      0     0  755.00000    0    -          -  755.00000      -     -    0s
#      0     0  755.00000    0   42          -  755.00000      -     -    0s
#      0     0  755.00000    0    -          -  755.00000      -     -    0s
#      0     0  755.00000    0    -          -  755.00000      -     -    0s
#      0     0  755.00000    0   20          -  755.00000      -     -    0s
# H    0     0                     755.0000000  755.00000  0.00%     -    0s
#      0     0  755.00000    0   20  755.00000  755.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 76
#
# Explored 1 nodes (2096 simplex iterations) in 0.42 seconds (0.12 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 755
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.550000000000e+02, best bound 7.550000000000e+02, gap 0.0000%
#
# User-callback calls 162, time in user-callback 0.33 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 196 rows, 9506 columns and 19012 nonzeros
# Model fingerprint: 0x72dbade5
# Variable types: 0 continuous, 9506 integer (9506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Presolve time: 0.01s
# Presolved: 196 rows, 9506 columns, 19012 nonzeros
# Variable types: 0 continuous, 9506 integer (9506 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 96
#
# Root relaxation: objective 7.550000e+02, 600 iterations, 0.01 seconds (0.01 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 78
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  755.00000    0    -          -  755.00000      -     -    0s
#      0     0  755.00000    0   44          -  755.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 74
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 74
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 11
# 	Found a subset which violate a SEC (flow = 0.125 < 1)
# 	Set size: 20
#      0     0  755.00000    0    -          -  755.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 16
#      0     0  755.00000    0    -          -  755.00000      -     -    0s
#      0     0  755.00000    0   18          -  755.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 36
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 72
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 79
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 74
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 68
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 84
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# *    0     0               0     755.0000000  755.00000  0.00%     -    1s
#
# Cutting planes:
#   Lazy constraints: 19
#
# Explored 1 nodes (2275 simplex iterations) in 1.95 seconds (0.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 755
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.550000000000e+02, best bound 7.550000000000e+02, gap 0.0000%
#
# User-callback calls 202, time in user-callback 1.80 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 246 rows, 15006 columns and 30012 nonzeros
# Model fingerprint: 0x3ba73385
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 246 rows, 15006 columns, 30012 nonzeros
# Variable types: 0 continuous, 15006 integer (15006 binary)
#
# Root relaxation: objective 9.590000e+02, 715 iterations, 0.01 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  959.00000    0    -          -  959.00000      -     -    0s
#      0     0  959.00000    0    -          -  959.00000      -     -    0s
#      0     0  959.00000    0   59          -  959.00000      -     -    0s
# H    0     0                     959.0000000  959.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 75
#
# Explored 1 nodes (742 simplex iterations) in 0.42 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 959
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.590000000000e+02, best bound 9.590000000000e+02, gap 0.0000%
#
# User-callback calls 139, time in user-callback 0.36 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 246 rows, 15006 columns and 30012 nonzeros
# Model fingerprint: 0x3ba73385
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 56
# Presolve time: 0.01s
# Presolved: 246 rows, 15006 columns, 30012 nonzeros
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 121
#
# Root relaxation: objective 9.590000e+02, 765 iterations, 0.01 seconds (0.02 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 56
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  959.00000    0    -          -  959.00000      -     -    0s
#      0     0  959.00000    0   46          -  959.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 53
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 32
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.625 < 1)
# 	Set size: 26
# 	Found a subset which violate a SEC (flow = 0.375 < 1)
# 	Set size: 15
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 19
#      0     0  959.00000    0    -          -  959.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 34
#      0     0  959.00000    0    -          -  959.00000      -     -    1s
#      0     0  959.00000    0   20          -  959.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 17
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 21
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 88
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 81
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 84
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 65
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 65
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 100
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 15
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     2  959.00000    0    8          -  959.00000      -     -    3s
# Separation round!
# Separation round!
# *    1     0               1     959.0000000  959.00000  0.00%   7.0    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = -0.000 < 1)
# 	Set size: 10
#
# Cutting planes:
#   Lazy constraints: 25
#
# Explored 3 nodes (2923 simplex iterations) in 4.42 seconds (0.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 959
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.590000000000e+02, best bound 9.590000000000e+02, gap 0.0000%
#
# User-callback calls 244, time in user-callback 4.15 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 296 rows, 21756 columns and 43512 nonzeros
# Model fingerprint: 0x950ea869
# Variable types: 0 continuous, 21756 integer (21756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.02s
# Presolved: 296 rows, 21756 columns, 43512 nonzeros
# Variable types: 0 continuous, 21756 integer (21756 binary)
#
# Root relaxation: objective 9.440000e+02, 842 iterations, 0.02 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  944.00000    0    -          -  944.00000      -     -    0s
#      0     0  944.00000    0   55          -  944.00000      -     -    0s
#      0     0  944.00000    0    -          -  944.00000      -     -    0s
#      0     0  944.00000    0    8          -  944.00000      -     -    0s
# H    0     0                     944.0000000  944.00000  0.00%     -    0s
#      0     0  944.00000    0    8  944.00000  944.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 85
#
# Explored 1 nodes (2055 simplex iterations) in 0.74 seconds (0.17 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 944
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.440000000000e+02, best bound 9.440000000000e+02, gap 0.0000%
#
# User-callback calls 169, time in user-callback 0.62 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 296 rows, 21756 columns and 43512 nonzeros
# Model fingerprint: 0x950ea869
# Variable types: 0 continuous, 21756 integer (21756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 57
# Presolve time: 0.02s
# Presolved: 296 rows, 21756 columns, 43512 nonzeros
# Variable types: 0 continuous, 21756 integer (21756 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 146
#
# Root relaxation: objective 9.440000e+02, 1038 iterations, 0.02 seconds (0.05 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 65
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  944.00000    0    -          -  944.00000      -     -    0s
#      0     0  944.00000    0   34          -  944.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 71
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 109
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 55
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 5
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 32
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 11
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 7
#      0     0  944.00000    0    -          -  944.00000      -     -    1s
#      0     0  944.00000    0    8          -  944.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 39
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 42
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 38
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 61
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 91
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 46
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 50
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 74
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 123
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 124
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 63
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 61
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 17
#      0     2  944.00000    0    8          -  944.00000      -     -    5s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 12
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 15
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 15
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 10
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 22
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 10
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 54
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 143
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 8
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 13
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 15
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 54
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 99
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 57
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 15
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
# Separation round!
# Separation round!
# *   15     4               2     944.0000000  944.00000  0.00%   7.7   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 46
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 49
#
# Cutting planes:
#   Lazy constraints: 47
#
# Explored 21 nodes (3672 simplex iterations) in 12.52 seconds (0.74 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 944
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.440000000000e+02, best bound 9.440000000000e+02, gap 0.0000%
#
# User-callback calls 345, time in user-callback 12.08 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 346 rows, 29756 columns and 59512 nonzeros
# Model fingerprint: 0xdbe6f12a
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.02s
# Presolved: 346 rows, 29756 columns, 59512 nonzeros
# Variable types: 0 continuous, 29756 integer (29756 binary)
#
# Root relaxation: objective 9.080000e+02, 1035 iterations, 0.02 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  908.00000    0    -          -  908.00000      -     -    0s
#      0     0  913.00000    0   22          -  913.00000      -     -    0s
#      0     0  914.00000    0    -          -  914.00000      -     -    0s
#      0     0  914.00000    0   16          -  914.00000      -     -    1s
# H    0     0                     914.0000000  914.00000  0.00%     -    1s
#      0     0  914.00000    0   16  914.00000  914.00000  0.00%     -    1s
#
# Cutting planes:
#   Lazy constraints: 107
#
# Explored 1 nodes (5869 simplex iterations) in 1.02 seconds (0.26 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 914
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.140000000000e+02, best bound 9.140000000000e+02, gap 0.0000%
#
# User-callback calls 176, time in user-callback 0.86 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 346 rows, 29756 columns and 59512 nonzeros
# Model fingerprint: 0xdbe6f12a
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 122
# Presolve time: 0.02s
# Presolved: 346 rows, 29756 columns, 59512 nonzeros
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 171
#
# Root relaxation: objective 9.080000e+02, 1113 iterations, 0.03 seconds (0.06 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 84
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  908.00000    0    -          -  908.00000      -     -    0s
#      0     0  908.00000    0   44          -  908.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 61
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 37
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 73
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# 	Found a subset which violate a SEC (flow = 0.889 < 1)
# 	Set size: 9
#      0     0  908.00000    0    -          -  908.00000      -     -    2s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
#      0     0  908.00000    0    -          -  908.00000      -     -    3s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 40
#      0     0  908.00000    0    -          -  908.00000      -     -    3s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
#      0     0  908.00000    0    -          -  908.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 41
#      0     0  913.00000    0    -          -  913.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#      0     0  913.00000    0    -          -  913.00000      -     -    5s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39
#      0     0  913.00000    0    -          -  913.00000      -     -    5s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     0  913.00000    0    -          -  913.00000      -     -    6s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39
#      0     0  914.00000    0    -          -  914.00000      -     -    6s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 37
#      0     0  914.00000    0    -          -  914.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     0  914.00000    0    -          -  914.00000      -     -    7s
# Separation round!
# *    0     0               0     914.0000000  914.00000  0.00%     -    8s
#
# Cutting planes:
#   Lazy constraints: 18
#
# Explored 1 nodes (5038 simplex iterations) in 8.04 seconds (0.26 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 914
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.140000000000e+02, best bound 9.140000000000e+02, gap 0.0000%
#
# User-callback calls 207, time in user-callback 7.87 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 396 rows, 39006 columns and 78012 nonzeros
# Model fingerprint: 0x4ec014e8
# Variable types: 0 continuous, 39006 integer (39006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.03s
# Presolved: 396 rows, 39006 columns, 78012 nonzeros
# Variable types: 0 continuous, 39006 integer (39006 binary)
#
# Root relaxation: objective 9.120000e+02, 1095 iterations, 0.03 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  912.00000    0    -          -  912.00000      -     -    0s
#      0     0  916.00000    0   46          -  916.00000      -     -    0s
# H    0     0                     934.0000000  916.00000  1.93%     -    1s
# H    0     0                     917.0000000  916.00000  0.11%     -    1s
#      0     0  917.00000    0   46  917.00000  917.00000  0.00%     -    1s
#
# Cutting planes:
#   Lazy constraints: 116
#
# Explored 1 nodes (1112 simplex iterations) in 1.17 seconds (0.25 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 917 934
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.170000000000e+02, best bound 9.170000000000e+02, gap 0.0000%
#
# User-callback calls 184, time in user-callback 1.02 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 396 rows, 39006 columns and 78012 nonzeros
# Model fingerprint: 0x4ec014e8
# Variable types: 0 continuous, 39006 integer (39006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
# Presolve time: 0.03s
# Presolved: 396 rows, 39006 columns, 78012 nonzeros
# Variable types: 0 continuous, 39006 integer (39006 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 196
#
# Root relaxation: objective 9.120000e+02, 1084 iterations, 0.03 seconds (0.07 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 41
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  912.00000    0    -          -  912.00000      -     -    1s
#      0     0  912.00000    0   52          -  912.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 172
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 50
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 123
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 35
# 	Found a subset which violate a SEC (flow = 0.125 < 1)
# 	Set size: 5
# 	Found a subset which violate a SEC (flow = 0.875 < 1)
# 	Set size: 8
# 	Found a subset which violate a SEC (flow = 0.125 < 1)
# 	Set size: 7
#      0     0  912.00000    0    -          -  912.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 62
#      0     0  912.00000    0    -          -  912.00000      -     -    4s
#      0     0  912.00000    0   20          -  912.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 21
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# *    0     0               0     917.0000000  917.00000  0.00%     -    8s
#
# Cutting planes:
#   Lazy constraints: 16
#
# Explored 1 nodes (4711 simplex iterations) in 8.98 seconds (0.60 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 917
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.170000000000e+02, best bound 9.170000000000e+02, gap 0.0000%
#
# User-callback calls 304, time in user-callback 8.56 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 446 rows, 49506 columns and 99012 nonzeros
# Model fingerprint: 0x72ee0acb
# Variable types: 0 continuous, 49506 integer (49506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.04s
# Presolved: 446 rows, 49506 columns, 99012 nonzeros
# Variable types: 0 continuous, 49506 integer (49506 binary)
#
# Root relaxation: objective 8.050000e+02, 1043 iterations, 0.03 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  805.00000    0    -          -  805.00000      -     -    1s
#      0     0  805.00000    0    -          -  805.00000      -     -    1s
#      0     0  805.00000    0   89          -  805.00000      -     -    1s
#      0     0  805.00000    0    -          -  805.00000      -     -    2s
#      0     0  805.00000    0    -          -  805.00000      -     -    2s
#      0     0  805.00000    0   10          -  805.00000      -     -    2s
# H    0     0                     805.0000000  805.00000  0.00%     -    2s
#      0     0  805.00000    0   10  805.00000  805.00000  0.00%     -    2s
#
# Cutting planes:
#   Lazy constraints: 141
#
# Explored 1 nodes (5096 simplex iterations) in 2.66 seconds (0.36 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 805
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.050000000000e+02, best bound 8.050000000000e+02, gap 0.0000%
#
# User-callback calls 208, time in user-callback 2.40 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 446 rows, 49506 columns and 99012 nonzeros
# Model fingerprint: 0x72ee0acb
# Variable types: 0 continuous, 49506 integer (49506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 76
# Presolve time: 0.04s
# Presolved: 446 rows, 49506 columns, 99012 nonzeros
# Variable types: 0 continuous, 49506 integer (49506 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 221
#
# Root relaxation: objective 8.050000e+02, 1036 iterations, 0.03 seconds (0.07 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 209
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  805.00000    0    -          -  805.00000      -     -    1s
#      0     0  805.00000    0   22          -  805.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 211
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 219
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 130
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 32
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 186
#      0     0  805.00000    0    -          -  805.00000      -     -    4s
#      0     0  805.00000    0   14          -  805.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 61
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 93
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 181
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 94
#      0     0  805.00000    0   14          -  805.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 38
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 104
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 57
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
#      0     2  805.00000    0    8          -  805.00000      -     -   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 137
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 73
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 25
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 50
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# Separation round!
# *    6     2               3     805.0000000  805.00000  0.00%  20.8   16s
# Separation round!
# ...
# Variable types: 0 continuous, 74256 integer (74256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 203
# Presolve time: 0.06s
# Presolved: 546 rows, 74256 columns, 148512 nonzeros
# Variable types: 0 continuous, 74256 integer (74256 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 271
#
# Root relaxation: objective 1.072000e+03, 1331 iterations, 0.06 seconds (0.12 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 76
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1072.00000    0    -          - 1072.00000      -     -    2s
#      0     0 1072.00000    0   86          - 1072.00000      -     -    2s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 242
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 148
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 43
#      0     0 1072.00000    0   86          - 1072.00000      -     -    5s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 7
# 	Found a subset which violate a SEC (flow = 0.300 < 1)
# 	Set size: 37
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 33
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 11
# 	Found a subset which violate a SEC (flow = 0.900 < 1)
# 	Set size: 19
#      0     0 1072.00000    0    -          - 1072.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 163
#      0     0 1072.00000    0    -          - 1072.00000      -     -    8s
#      0     0 1072.00000    0   18          - 1072.00000      -     -    8s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 218
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 151
#      0     0 1072.00000    0   18          - 1072.00000      -     -   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 41
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 98
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 40
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 143
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 177
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 123
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 116
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 170
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 120
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 113
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 64
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 175
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 10
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 121
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 118
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 168
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 114
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 57
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 111
# Separation round!
# *    0     0               0    1072.0000000 1072.00000  0.00%     -   40s
#
# Cutting planes:
#   Lazy constraints: 40
#
# Explored 1 nodes (5792 simplex iterations) in 40.41 seconds (1.60 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1072
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.072000000000e+03, best bound 1.072000000000e+03, gap 0.0000%
#
# User-callback calls 460, time in user-callback 39.30 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 596 rows, 88506 columns and 177012 nonzeros
# Model fingerprint: 0x87526db6
# Variable types: 0 continuous, 88506 integer (88506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.07s
# Presolved: 596 rows, 88506 columns, 177012 nonzeros
# Variable types: 0 continuous, 88506 integer (88506 binary)
#
# Root relaxation: objective 1.173000e+03, 1390 iterations, 0.05 seconds (0.10 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1173.00000    0    -          - 1173.00000      -     -    2s
#      0     0 1173.00000    0    8          - 1173.00000      -     -    2s
#      0     0 1173.00000    0    8          - 1173.00000      -     -    5s
# H    0     0                    1173.0000000 1173.00000  0.00%     -    7s
#      0     0 1173.00000    0   36 1173.00000 1173.00000  0.00%     -    7s
#
# Cutting planes:
#   Lazy constraints: 190
#
# Explored 1 nodes (1444 simplex iterations) in 7.21 seconds (0.68 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1173
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.173000000000e+03, best bound 1.173000000000e+03, gap 0.0000%
#
# User-callback calls 276, time in user-callback 6.82 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 596 rows, 88506 columns and 177012 nonzeros
# Model fingerprint: 0x87526db6
# Variable types: 0 continuous, 88506 integer (88506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 169
# Presolve time: 0.07s
# Presolved: 596 rows, 88506 columns, 177012 nonzeros
# Variable types: 0 continuous, 88506 integer (88506 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 296
#
# Root relaxation: objective 1.173000e+03, 1435 iterations, 0.06 seconds (0.13 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 47
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1173.00000    0    -          - 1173.00000      -     -    3s
#      0     0 1173.00000    0   48          - 1173.00000      -     -    3s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 266
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 244
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 230
#      0     0 1173.00000    0   48          - 1173.00000      -     -    6s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 26
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 26
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 11
#      0     0 1173.00000    0    -          - 1173.00000      -     -    8s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 79
#      0     0 1173.00000    0    -          - 1173.00000      -     -   10s
#      0     0 1173.00000    0   22          - 1173.00000      -     -   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 89
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 264
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 76
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 70
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 22
#      0     2 1173.00000    0    8          - 1173.00000      -     -   20s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 20
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 68
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#      3     0 1173.00000    1    -          - 1173.00000      -   2.3   25s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 52
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 50
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 144
#      7     0 1173.00000    1    -          - 1173.00000      -  12.0   33s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 78
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 126
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 126
#      9     0 1173.00000    1    -          - 1173.00000      -  16.2   36s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 124
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 20
# 	Found a subset which violate a SEC (flow = 0.833 < 1)
# 	Set size: 113
# 	Found a subset which violate a SEC (flow = 0.167 < 1)
# 	Set size: 51
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 106
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 108
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.125 < 1)
# 	Set size: 18
# 	Found a subset which violate a SEC (flow = 0.875 < 1)
# 	Set size: 95
# 	Found a subset which violate a SEC (flow = 0.125 < 1)
# 	Set size: 31
#     13     4 1173.00000    2   42          - 1173.00000      -  16.6   42s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 18
# 	Found a subset which violate a SEC (flow = 0.600 < 1)
# 	Set size: 76
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 66
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 72
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 169
# Separation round!
#     16     8 1173.00000    3   26          - 1173.00000      -  22.5   47s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 206
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 117
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 56
#     18     9 1173.00000    2   31          - 1173.00000      -  20.7   50s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 58
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 48
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 114
#     21     7 1173.00000    4    -          - 1173.00000      -  19.0   55s
# Separation round!
# Interrupt request received
#
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 37
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 112
# Separation round!
# *   26     7               3    1173.0000000 1173.00000  0.00%  18.2   61s
#
# Cutting planes:
#   Lazy constraints: 49
#
# Explored 29 nodes (7696 simplex iterations) in 61.16 seconds (2.34 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1173
#
# Solve interrupted
# Best objective 1.173000000000e+03, best bound 1.173000000000e+03, gap 0.0000%
#
# User-callback calls 444, time in user-callback 59.99 sec
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/rossfleming/Documents/GitHub/tsp_project/master file.ipynb Cell 12 line 2
#      <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X14sZmlsZQ%3D%3D?line=21'>22</a> i_frac = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
#      <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X14sZmlsZQ%3D%3D?line=22'>23</a> s_frac = TspFractionalBCSolver(instance=i_frac, cardinality=None)
# ---> <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X14sZmlsZQ%3D%3D?line=23'>24</a> solution = s_frac.solve()
#      <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X14sZmlsZQ%3D%3D?line=25'>26</a> time_list_frac.append(s_frac._model.Runtime)
#      <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X14sZmlsZQ%3D%3D?line=26'>27</a> objective_list_frac.append(s_frac._model.ObjVal)
#
# /Users/rossfleming/Documents/GitHub/tsp_project/master file.ipynb Cell 12 line 2
#     <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X14sZmlsZQ%3D%3D?line=228'>229</a> self._model.optimize(lambda _, where: self.__separate(where))
#     <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X14sZmlsZQ%3D%3D?line=230'>231</a> if self._model.Status != GRB.OPTIMAL:
# --> <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X14sZmlsZQ%3D%3D?line=231'>232</a>     raise RuntimeError(f"Could not find the optimal solution. Gurobi status = {self._model.Status}")
#     <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X14sZmlsZQ%3D%3D?line=233'>234</a> return TspSolution(
#     <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X14sZmlsZQ%3D%3D?line=234'>235</a>     instance=self._instance,
#     <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X14sZmlsZQ%3D%3D?line=235'>236</a>     tour=self.__tour_staring_at(0),
#     <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X14sZmlsZQ%3D%3D?line=236'>237</a>     cost=self._model.ObjVal
#     <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X14sZmlsZQ%3D%3D?line=237'>238</a> )
#
# RuntimeError: Could not find the optimal solution. Gurobi status = 11

# %% [markdown]
# # Graphing

# %%
# Plotting the graph
plt.figure(figsize=(10, 6))
plt.plot(vertices_list, time_list_int, marker='o', label = 'Integer Model')
plt.plot(vertices_list, time_list_frac, marker='x', label = 'Fractional Model')
plt.xlabel('Number of Vertices')
plt.ylabel('Computation Time (seconds)')
#plt.title('Computation Time vs Number of Vertices in TSP')
plt.legend()
plt.grid(True)
plt.show()


for i in range(len(objective_list_frac)):
        assert objective_list_frac[i]==objective_list_int[i]

# %% [markdown]
# # Question 2
# ## Integer Implementation

# %%
# Output time and objective value for different number of vertices
time_list_none = time_list_int
time_list_2 = list()
time_list_3 = list()
objective_list_none = objective_list_int
objective_list_2 = list()
objective_list_3 = list()
nrows_list_none = nrows_list_int
nrows_list_2 = list()
nrows_list_3 = list()

for vert in vertices_list:
    filtered_vertices = vert
    filtered_cost = {(i, j): cost_val for (i, j), cost_val in cost.items() if i < filtered_vertices and j < filtered_vertices}

    i_2 = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s_2 = TspIntegerBCSolver(instance=i_2, cardinality=2.2)
    solution = s_2.solve()

    time_list_2.append(s_2._model.Runtime)
    objective_list_2.append(s_2._model.ObjVal)
    nrows_list_2.append(s_2._model.NumConstrs)
    
    i_3 = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s_3 = TspFractionalBCSolver(instance=i_3, cardinality=2.3)
    solution = s_3.solve()

    time_list_3.append(s_3._model.Runtime)
    objective_list_3.append(s_3._model.ObjVal)
# Out:
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 552 rows, 506 columns and 2024 nonzeros
# Model fingerprint: 0xb009aa87
# Variable types: 0 continuous, 506 integer (506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 253 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 299 rows, 506 columns, 1518 nonzeros
# Variable types: 0 continuous, 506 integer (506 binary)
#
# Root relaxation: objective 1.920000e+02, 67 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  192.00000    0    -          -  192.00000      -     -    0s
# *    0     0               0     192.0000000  192.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 7
#
# Explored 1 nodes (68 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 192
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.920000000000e+02, best bound 1.920000000000e+02, gap 0.0000%
#
# User-callback calls 143, time in user-callback 0.01 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 46 rows, 506 columns and 1012 nonzeros
# Model fingerprint: 0xd3a534b7
# Variable types: 0 continuous, 506 integer (506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Presolve time: 0.00s
# Presolved: 46 rows, 506 columns, 1012 nonzeros
# Variable types: 0 continuous, 506 integer (506 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
#
# Root relaxation: objective 1.920000e+02, 55 iterations, 0.00 seconds (0.00 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  192.00000    0    -          -  192.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     0  192.00000    0    -          -  192.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     0  192.00000    0    -          -  192.00000      -     -    0s
# Separation round!
# *    0     0               0     192.0000000  192.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 4
#
# Explored 1 nodes (64 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 192
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.920000000000e+02, best bound 1.920000000000e+02, gap 0.0000%
#
# User-callback calls 112, time in user-callback 0.09 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2352 rows, 2256 columns and 9024 nonzeros
# Model fingerprint: 0xbb283011
# Variable types: 0 continuous, 2256 integer (2256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 1128 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 1224 rows, 2256 columns, 6768 nonzeros
# Variable types: 0 continuous, 2256 integer (2256 binary)
#
# Root relaxation: objective 3.410000e+02, 198 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  341.00000    0    -          -  341.00000      -     -    0s
#      0     0  341.00000    0    -          -  341.00000      -     -    0s
#      0     0  341.00000    0   10          -  341.00000      -     -    0s
# H    0     0                     473.0000000  341.00000  27.9%     -    0s
# H    0     0                     363.0000000  341.00000  6.06%     -    0s
#      0     0  341.00000    0   16  363.00000  341.00000  6.06%     -    0s
#      0     0  341.00000    0    -  363.00000  341.00000  6.06%     -    0s
#      0     0  341.00000    0    8  363.00000  341.00000  6.06%     -    0s
# H    0     0                     341.0000000  341.00000  0.00%     -    0s
#      0     0  341.00000    0    8  341.00000  341.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 23
#
# Explored 1 nodes (382 simplex iterations) in 0.11 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 341 363 473
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.410000000000e+02, best bound 3.410000000000e+02, gap 0.0000%
#
# User-callback calls 185, time in user-callback 0.05 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 96 rows, 2256 columns and 4512 nonzeros
# Model fingerprint: 0x9924bbf8
# Variable types: 0 continuous, 2256 integer (2256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 35
# Presolve time: 0.00s
# Presolved: 96 rows, 2256 columns, 4512 nonzeros
# Variable types: 0 continuous, 2256 integer (2256 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 46
#
# Root relaxation: objective 3.410000e+02, 190 iterations, 0.00 seconds (0.00 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 20
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  341.00000    0    -          -  341.00000      -     -    0s
#      0     0  341.00000    0   16          -  341.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 23
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 37
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 40
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 37
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 18
#      0     0  341.00000    0    -          -  341.00000      -     -    0s
#      0     0  341.00000    0   12          -  341.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 13
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 29
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 34
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 16
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# *    0     0               0     341.0000000  341.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 22
#
# Explored 1 nodes (693 simplex iterations) in 0.68 seconds (0.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 341
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.410000000000e+02, best bound 3.410000000000e+02, gap 0.0000%
#
# User-callback calls 165, time in user-callback 0.63 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5402 rows, 5256 columns and 21024 nonzeros
# Model fingerprint: 0x145bbeba
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 2628 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 2774 rows, 5256 columns, 15768 nonzeros
# Variable types: 0 continuous, 5256 integer (5256 binary)
#
# Root relaxation: objective 4.740000e+02, 303 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  474.00000    0    -          -  474.00000      -     -    0s
#      0     0  474.00000    0   20          -  474.00000      -     -    0s
#      0     0  474.00000    0   22          -  474.00000      -     -    0s
# H    0     0                     474.0000000  474.00000  0.00%     -    0s
#      0     0  474.00000    0   22  474.00000  474.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Lazy constraints: 34
#
# Explored 1 nodes (316 simplex iterations) in 0.21 seconds (0.11 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 474
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.740000000000e+02, best bound 4.740000000000e+02, gap 0.0000%
#
# User-callback calls 191, time in user-callback 0.12 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 146 rows, 5256 columns and 10512 nonzeros
# Model fingerprint: 0xa95e0496
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 35
# Presolve time: 0.01s
# Presolved: 146 rows, 5256 columns, 10512 nonzeros
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 71
#
# Root relaxation: objective 4.710000e+02, 282 iterations, 0.00 seconds (0.00 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 45
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  471.00000    0    -          -  471.00000      -     -    0s
#      0     0  471.00000    0   48          -  471.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 64
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 31
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 42
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 43
#      0     0  471.00000    0    -          -  471.00000      -     -    0s
#      0     0  471.00000    0   48          -  471.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 40
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 5
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 28
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 36
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 49
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 8
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# *    0     0               0     474.0000000  474.00000  0.00%     -    1s
#
# Cutting planes:
#   Lazy constraints: 24
#
# Explored 1 nodes (291 simplex iterations) in 1.62 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 474
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.740000000000e+02, best bound 4.740000000000e+02, gap 0.0000%
#
# User-callback calls 179, time in user-callback 1.55 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 9702 rows, 9506 columns and 38024 nonzeros
# Model fingerprint: 0x70ea0c9b
# Variable types: 0 continuous, 9506 integer (9506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 4753 rows and 0 columns
# Presolve time: 0.03s
# Presolved: 4949 rows, 9506 columns, 28518 nonzeros
# Variable types: 0 continuous, 9506 integer (9506 binary)
#
# Root relaxation: objective 7.550000e+02, 526 iterations, 0.01 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  755.00000    0    -          -  755.00000      -     -    0s
#      0     0  755.00000    0    -          -  755.00000      -     -    0s
#      0     0  755.00000    0   18          -  755.00000      -     -    0s
#      0     0  755.00000    0   43          -  755.00000      -     -    0s
# H    0     0                     755.0000000  755.00000  0.00%     -    0s
#      0     0  755.00000    0   43  755.00000  755.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Lazy constraints: 40
#
# Explored 1 nodes (548 simplex iterations) in 0.46 seconds (0.22 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 755
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.550000000000e+02, best bound 7.550000000000e+02, gap 0.0000%
#
# User-callback calls 217, time in user-callback 0.26 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 196 rows, 9506 columns and 19012 nonzeros
# Model fingerprint: 0x72dbade5
# Variable types: 0 continuous, 9506 integer (9506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Presolve time: 0.01s
# Presolved: 196 rows, 9506 columns, 19012 nonzeros
# Variable types: 0 continuous, 9506 integer (9506 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 96
#
# Root relaxation: objective 7.550000e+02, 600 iterations, 0.01 seconds (0.01 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 78
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  755.00000    0    -          -  755.00000      -     -    0s
#      0     0  755.00000    0   44          -  755.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 74
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 74
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 11
# 	Found a subset which violate a SEC (flow = 0.125 < 1)
# 	Set size: 20
#      0     0  755.00000    0    -          -  755.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 16
#      0     0  755.00000    0    -          -  755.00000      -     -    0s
#      0     0  755.00000    0   18          -  755.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 36
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 72
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 79
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 74
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 68
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 84
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# *    0     0               0     755.0000000  755.00000  0.00%     -    1s
#
# Cutting planes:
#   Lazy constraints: 19
#
# Explored 1 nodes (2275 simplex iterations) in 1.91 seconds (0.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 755
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.550000000000e+02, best bound 7.550000000000e+02, gap 0.0000%
#
# User-callback calls 205, time in user-callback 1.77 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 15252 rows, 15006 columns and 60024 nonzeros
# Model fingerprint: 0x394f57ed
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 7503 rows and 0 columns
# Presolve time: 0.05s
# Presolved: 7749 rows, 15006 columns, 45018 nonzeros
# Variable types: 0 continuous, 15006 integer (15006 binary)
#
# Root relaxation: objective 9.590000e+02, 682 iterations, 0.01 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  959.00000    0    -          -  959.00000      -     -    0s
# *    0     0               0     959.0000000  959.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 32
#
# Explored 1 nodes (688 simplex iterations) in 0.25 seconds (0.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 959
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.590000000000e+02, best bound 9.590000000000e+02, gap 0.0000%
#
# User-callback calls 169, time in user-callback 0.17 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 246 rows, 15006 columns and 30012 nonzeros
# Model fingerprint: 0x3ba73385
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 56
# Presolve time: 0.01s
# Presolved: 246 rows, 15006 columns, 30012 nonzeros
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 121
#
# Root relaxation: objective 9.590000e+02, 765 iterations, 0.01 seconds (0.02 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 56
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  959.00000    0    -          -  959.00000      -     -    0s
#      0     0  959.00000    0   46          -  959.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 53
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 32
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.625 < 1)
# 	Set size: 26
# 	Found a subset which violate a SEC (flow = 0.375 < 1)
# 	Set size: 15
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 19
#      0     0  959.00000    0    -          -  959.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 34
#      0     0  959.00000    0    -          -  959.00000      -     -    1s
#      0     0  959.00000    0   20          -  959.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 17
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 21
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 88
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 81
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 84
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 65
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 65
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 100
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 15
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     2  959.00000    0    8          -  959.00000      -     -    3s
# Separation round!
# Separation round!
# *    1     0               1     959.0000000  959.00000  0.00%   7.0    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = -0.000 < 1)
# 	Set size: 10
#
# Cutting planes:
#   Lazy constraints: 25
#
# Explored 3 nodes (2923 simplex iterations) in 4.35 seconds (0.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 959
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.590000000000e+02, best bound 9.590000000000e+02, gap 0.0000%
#
# User-callback calls 244, time in user-callback 4.09 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 22052 rows, 21756 columns and 87024 nonzeros
# Model fingerprint: 0xac00860c
# Variable types: 0 continuous, 21756 integer (21756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 10878 rows and 0 columns
# Presolve time: 0.07s
# Presolved: 11174 rows, 21756 columns, 65268 nonzeros
# Variable types: 0 continuous, 21756 integer (21756 binary)
#
# Root relaxation: objective 9.440000e+02, 800 iterations, 0.02 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  944.00000    0    -          -  944.00000      -     -    0s
#      0     0  944.00000    0   46          -  944.00000      -     -    0s
# *    0     0               0     944.0000000  944.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Lazy constraints: 53
#
# Explored 1 nodes (809 simplex iterations) in 0.87 seconds (0.34 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 944
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.440000000000e+02, best bound 9.440000000000e+02, gap 0.0000%
#
# User-callback calls 236, time in user-callback 0.64 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 296 rows, 21756 columns and 43512 nonzeros
# Model fingerprint: 0x950ea869
# Variable types: 0 continuous, 21756 integer (21756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 57
# Presolve time: 0.02s
# Presolved: 296 rows, 21756 columns, 43512 nonzeros
# Variable types: 0 continuous, 21756 integer (21756 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 146
#
# Root relaxation: objective 9.440000e+02, 1038 iterations, 0.02 seconds (0.05 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 65
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  944.00000    0    -          -  944.00000      -     -    0s
#      0     0  944.00000    0   34          -  944.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 71
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 109
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 55
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 5
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 32
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 11
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 7
#      0     0  944.00000    0    -          -  944.00000      -     -    1s
#      0     0  944.00000    0    8          -  944.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 39
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 42
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 38
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 61
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 91
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 46
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 50
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 74
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 123
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 124
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 63
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 61
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 17
#      0     2  944.00000    0    8          -  944.00000      -     -    5s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 12
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 15
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 15
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 10
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 22
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 10
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 54
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 143
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 8
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 13
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 15
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 54
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 99
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 57
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 15
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
# Separation round!
# Separation round!
# *   15     4               2     944.0000000  944.00000  0.00%   7.7   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 46
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 49
#
# Cutting planes:
#   Lazy constraints: 47
#
# Explored 21 nodes (3672 simplex iterations) in 12.65 seconds (0.74 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 944
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.440000000000e+02, best bound 9.440000000000e+02, gap 0.0000%
#
# User-callback calls 343, time in user-callback 12.22 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 30102 rows, 29756 columns and 119024 nonzeros
# Model fingerprint: 0xa9e213cb
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 14878 rows and 0 columns
# Presolve time: 0.11s
# Presolved: 15224 rows, 29756 columns, 89268 nonzeros
# Variable types: 0 continuous, 29756 integer (29756 binary)
#
# Root relaxation: objective 9.080000e+02, 862 iterations, 0.03 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  908.00000    0    -          -  908.00000      -     -    0s
#      0     0  914.00000    0   32          -  914.00000      -     -    0s
#      0     0  914.00000    0    -          -  914.00000      -     -    1s
#      0     0  914.00000    0    8          -  914.00000      -     -    1s
# H    0     0                     914.0000000  914.00000  0.00%     -    1s
#      0     0  914.00000    0    8  914.00000  914.00000  0.00%     -    1s
#
# Cutting planes:
#   Lazy constraints: 70
#
# Explored 1 nodes (1644 simplex iterations) in 1.55 seconds (0.57 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 914
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.140000000000e+02, best bound 9.140000000000e+02, gap 0.0000%
#
# User-callback calls 267, time in user-callback 1.18 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 346 rows, 29756 columns and 59512 nonzeros
# Model fingerprint: 0xdbe6f12a
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 122
# Presolve time: 0.03s
# Presolved: 346 rows, 29756 columns, 59512 nonzeros
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 171
#
# Root relaxation: objective 9.080000e+02, 1113 iterations, 0.03 seconds (0.06 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 84
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  908.00000    0    -          -  908.00000      -     -    0s
#      0     0  908.00000    0   44          -  908.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 61
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 37
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 73
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# 	Found a subset which violate a SEC (flow = 0.889 < 1)
# 	Set size: 9
#      0     0  908.00000    0    -          -  908.00000      -     -    3s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
#      0     0  908.00000    0    -          -  908.00000      -     -    3s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 40
#      0     0  908.00000    0    -          -  908.00000      -     -    3s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
#      0     0  908.00000    0    -          -  908.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 41
#      0     0  913.00000    0    -          -  913.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#      0     0  913.00000    0    -          -  913.00000      -     -    5s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39
#      0     0  913.00000    0    -          -  913.00000      -     -    5s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     0  913.00000    0    -          -  913.00000      -     -    6s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39
#      0     0  914.00000    0    -          -  914.00000      -     -    6s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 37
#      0     0  914.00000    0    -          -  914.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     0  914.00000    0    -          -  914.00000      -     -    7s
# Separation round!
# *    0     0               0     914.0000000  914.00000  0.00%     -    8s
#
# Cutting planes:
#   Lazy constraints: 18
#
# Explored 1 nodes (5038 simplex iterations) in 8.10 seconds (0.26 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 914
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.140000000000e+02, best bound 9.140000000000e+02, gap 0.0000%
#
# User-callback calls 209, time in user-callback 7.93 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 39402 rows, 39006 columns and 156024 nonzeros
# Model fingerprint: 0x3b93f1ae
# Variable types: 0 continuous, 39006 integer (39006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 19503 rows and 0 columns
# Presolve time: 0.12s
# Presolved: 19899 rows, 39006 columns, 117018 nonzeros
# Variable types: 0 continuous, 39006 integer (39006 binary)
# Root relaxation presolved: 19948 rows, 39006 columns, 117624 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 9.120000e+02, 2067 iterations, 0.06 seconds (0.10 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  912.00000    0    -          -  912.00000      -     -    0s
#      0     0  917.00000    0    -          -  917.00000      -     -    1s
#      0     0  917.00000    0   32          -  917.00000      -     -    1s
#      0     0  917.00000    0    -          -  917.00000      -     -    1s
# *    0     0               0     917.0000000  917.00000  0.00%     -    1s
#
# Cutting planes:
#   Lazy constraints: 64
#
# Explored 1 nodes (3297 simplex iterations) in 1.73 seconds (0.74 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 917
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.170000000000e+02, best bound 9.170000000000e+02, gap 0.0000%
#
# User-callback calls 284, time in user-callback 1.26 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 396 rows, 39006 columns and 78012 nonzeros
# Model fingerprint: 0x4ec014e8
# Variable types: 0 continuous, 39006 integer (39006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
# Presolve time: 0.03s
# Presolved: 396 rows, 39006 columns, 78012 nonzeros
# Variable types: 0 continuous, 39006 integer (39006 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 196
#
# Root relaxation: objective 9.120000e+02, 1084 iterations, 0.03 seconds (0.07 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 41
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  912.00000    0    -          -  912.00000      -     -    1s
#      0     0  912.00000    0   52          -  912.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 172
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 50
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 123
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 35
# 	Found a subset which violate a SEC (flow = 0.125 < 1)
# 	Set size: 5
# 	Found a subset which violate a SEC (flow = 0.875 < 1)
# 	Set size: 8
# 	Found a subset which violate a SEC (flow = 0.125 < 1)
# 	Set size: 7
#      0     0  912.00000    0    -          -  912.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 62
#      0     0  912.00000    0    -          -  912.00000      -     -    4s
#      0     0  912.00000    0   20          -  912.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 21
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# *    0     0               0     917.0000000  917.00000  0.00%     -    8s
#
# Cutting planes:
#   Lazy constraints: 16
#
# Explored 1 nodes (4711 simplex iterations) in 8.94 seconds (0.60 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 917
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.170000000000e+02, best bound 9.170000000000e+02, gap 0.0000%
#
# User-callback calls 302, time in user-callback 8.53 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 49952 rows, 49506 columns and 198024 nonzeros
# Model fingerprint: 0x2f1b9a6b
# Variable types: 0 continuous, 49506 integer (49506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 24753 rows and 0 columns
# Presolve time: 0.16s
# Presolved: 25199 rows, 49506 columns, 148518 nonzeros
# Variable types: 0 continuous, 49506 integer (49506 binary)
# Root relaxation presolved: 25255 rows, 49506 columns, 149184 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 8.050000e+02, 3274 iterations, 0.07 seconds (0.15 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  805.00000    0    -          -  805.00000      -     -    1s
#      0     0  805.00000    0   18          -  805.00000      -     -    1s
# H    0     0                    1147.0000000  805.00000  29.8%     -    1s
# H    0     0                    1077.0000000  805.00000  25.3%     -    1s
#      0     0  805.00000    0    - 1077.00000  805.00000  25.3%     -    1s
#      0     0  805.00000    0   28 1077.00000  805.00000  25.3%     -    2s
#      0     2  805.00000    0    8 1077.00000  805.00000  25.3%     -    4s
# *    1     0               1     805.0000000  805.00000  0.00%   1.0    4s
#
# Cutting planes:
#   Lazy constraints: 93
#
# Explored 3 nodes (5080 simplex iterations) in 4.10 seconds (1.64 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 805 1077 1147
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.050000000000e+02, best bound 8.050000000000e+02, gap 0.0000%
#
# User-callback calls 520, time in user-callback 3.11 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 446 rows, 49506 columns and 99012 nonzeros
# Model fingerprint: 0x72ee0acb
# Variable types: 0 continuous, 49506 integer (49506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 76
# Presolve time: 0.04s
# Presolved: 446 rows, 49506 columns, 99012 nonzeros
# Variable types: 0 continuous, 49506 integer (49506 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 221
#
# Root relaxation: objective 8.050000e+02, 1036 iterations, 0.03 seconds (0.07 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 209
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  805.00000    0    -          -  805.00000      -     -    1s
#      0     0  805.00000    0   22          -  805.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 211
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 219
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 130
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 32
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 186
#      0     0  805.00000    0    -          -  805.00000      -     -    4s
#      0     0  805.00000    0   14          -  805.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 61
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 93
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 181
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 94
#      0     0  805.00000    0   14          -  805.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 38
# Separation round!
# ...
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 111
# Separation round!
# *    0     0               0    1072.0000000 1072.00000  0.00%     -   40s
#
# Cutting planes:
#   Lazy constraints: 40
#
# Explored 1 nodes (5792 simplex iterations) in 40.86 seconds (1.60 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1072
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.072000000000e+03, best bound 1.072000000000e+03, gap 0.0000%
#
# User-callback calls 465, time in user-callback 39.77 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 89102 rows, 88506 columns and 354024 nonzeros
# Model fingerprint: 0x5a0cee95
# Variable types: 0 continuous, 88506 integer (88506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 44253 rows and 0 columns
# Presolve time: 0.28s
# Presolved: 44849 rows, 88506 columns, 265518 nonzeros
# Variable types: 0 continuous, 88506 integer (88506 binary)
# Root relaxation presolved: 44923 rows, 88506 columns, 266424 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.173000e+03, 3000 iterations, 0.11 seconds (0.23 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1173.00000    0    -          - 1173.00000      -     -    2s
#      0     0 1173.00000    0   16          - 1173.00000      -     -    2s
# H    0     0                    1421.0000000 1173.00000  17.5%     -    2s
#      0     0 1173.00000    0    - 1421.00000 1173.00000  17.5%     -    4s
# *    0     0               0    1173.0000000 1173.00000  0.00%     -    4s
#
# Cutting planes:
#   Lazy constraints: 90
#
# Explored 1 nodes (6329 simplex iterations) in 4.51 seconds (1.75 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1173 1421
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.173000000000e+03, best bound 1.173000000000e+03, gap 0.0000%
#
# User-callback calls 435, time in user-callback 3.62 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 596 rows, 88506 columns and 177012 nonzeros
# Model fingerprint: 0x87526db6
# Variable types: 0 continuous, 88506 integer (88506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 169
# Presolve time: 0.07s
# Presolved: 596 rows, 88506 columns, 177012 nonzeros
# Variable types: 0 continuous, 88506 integer (88506 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 296
#
# Root relaxation: objective 1.173000e+03, 1435 iterations, 0.06 seconds (0.13 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 47
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1173.00000    0    -          - 1173.00000      -     -    3s
#      0     0 1173.00000    0   48          - 1173.00000      -     -    3s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 266
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 244
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 230
#      0     0 1173.00000    0   48          - 1173.00000      -     -    6s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 26
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 26
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 11
#      0     0 1173.00000    0    -          - 1173.00000      -     -    8s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 79
#      0     0 1173.00000    0    -          - 1173.00000      -     -   10s
#      0     0 1173.00000    0   22          - 1173.00000      -     -   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 89
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 264
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 76
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 70
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 22
#      0     2 1173.00000    0    8          - 1173.00000      -     -   20s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 20
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 68
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#      3     0 1173.00000    1    -          - 1173.00000      -   2.3   26s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 52
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      5     0 1173.00000    1    -          - 1173.00000      -   1.8   30s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 50
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 144
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 78
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 126
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 126
#      9     0 1173.00000    1    -          - 1173.00000      -  16.2   36s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 124
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 20
# 	Found a subset which violate a SEC (flow = 0.833 < 1)
# 	Set size: 113
# 	Found a subset which violate a SEC (flow = 0.167 < 1)
# 	Set size: 51
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 106
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 108
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.125 < 1)
# 	Set size: 18
# 	Found a subset which violate a SEC (flow = 0.875 < 1)
# 	Set size: 95
# 	Found a subset which violate a SEC (flow = 0.125 < 1)
# 	Set size: 31
#     13     4 1173.00000    2   42          - 1173.00000      -  16.6   43s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 18
# 	Found a subset which violate a SEC (flow = 0.600 < 1)
# 	Set size: 76
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 66
#     14     4 1173.00000    1   26          - 1173.00000      -  23.1   45s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 72
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 169
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 206
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 117
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 56
#     18     9 1173.00000    2   31          - 1173.00000      -  20.7   51s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 58
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 48
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 114
#     21     7 1173.00000    4    -          - 1173.00000      -  19.0   57s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 37
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 115
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 54
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 37
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 112
# Separation round!
# Separation round!
# *   26     7               3    1173.0000000 1173.00000  0.00%  18.2   68s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 97
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 145
#
# Cutting planes:
#   Lazy constraints: 54
#
# Explored 29 nodes (7696 simplex iterations) in 71.35 seconds (2.34 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1173
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.173000000000e+03, best bound 1.173000000000e+03, gap 0.0000%
#
# User-callback calls 451, time in user-callback 70.12 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 104652 rows, 104006 columns and 416024 nonzeros
# Model fingerprint: 0x9be21f22
# Variable types: 0 continuous, 104006 integer (104006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 52003 rows and 0 columns
# Presolve time: 0.35s
# Presolved: 52649 rows, 104006 columns, 312018 nonzeros
# Variable types: 0 continuous, 104006 integer (104006 binary)
# Root relaxation presolved: 52730 rows, 104006 columns, 312984 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.326000e+03, 4245 iterations, 0.16 seconds (0.34 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1326.00000    0    -          - 1326.00000      -     -    2s
#      0     0 1326.00000    0    -          - 1326.00000      -     -    3s
#      0     0 1326.00000    0   24          - 1326.00000      -     -    3s
# H    0     0                    1326.0000000 1326.00000  0.00%     -    4s
#
# Cutting planes:
#   Lazy constraints: 92
#
# Explored 1 nodes (4303 simplex iterations) in 4.76 seconds (1.52 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1326
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.326000000000e+03, best bound 1.326000000000e+03, gap 0.0000%
#
# User-callback calls 420, time in user-callback 3.99 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 646 rows, 104006 columns and 208012 nonzeros
# Model fingerprint: 0x6de01d01
# Variable types: 0 continuous, 104006 integer (104006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 245
# Presolve time: 0.09s
# Presolved: 646 rows, 104006 columns, 208012 nonzeros
# Variable types: 0 continuous, 104006 integer (104006 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 321
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity      0.0000000e+00      2s
#        1        855   2.5000000e+08   1.2350000e+02      2s
#        2       1423   2.3800001e+08   2.4050000e+02      2s
#        3       1713   2.1800003e+08   3.4500000e+02      2s
#        4       1963   2.1000003e+08   4.4600001e+02      2s
#        5       2200   2.0200005e+08   5.4199971e+02      2s
#        6       2435   1.9400006e+08   6.3899962e+02      2s
#        7       2680   1.7600012e+08   7.1649980e+02      2s
#        8       2926   1.6800014e+08   7.9249965e+02      2s
#        9       3199   1.5800017e+08   8.5799896e+02      2s
#       10       3460   1.4600021e+08   9.1099943e+02      2s
#       11       3774   1.1400035e+08   9.2949914e+02      2s
#       12       4089   9.8000406e+07   9.4849910e+02      2s
#       13       4481   8.4000463e+07   9.8399966e+02      2s
#       14       4751   7.6000509e+07   1.0009993e+03      2s
#       15       5067   6.4000573e+07   1.0104987e+03      2s
#       16       5428   5.8000597e+07   1.0234985e+03      2s
#       17       5803   5.4000614e+07   1.0419983e+03      2s
#       18       6097   5.0000640e+07   1.0579977e+03      2s
#       19       6737   2.4000866e+07   1.0414981e+03      2s
#       20       7176   1.8000896e+07   1.0404978e+03      2s
#       21       7683   1.4000926e+07   1.0474980e+03      2s
#       22       8067   1.2000947e+07   1.0534981e+03      2s
#       23       8555   1.0000969e+07   1.0469984e+03      2s
#       24       8933   1.0000958e+07   1.0519984e+03      2s
#       25       9366   2.0010540e+06   1.0529984e+03      2s
#       26       9753   2.0010540e+06   1.0549984e+03      2s
#       27      10135   1.0810005e+03   1.0566072e+03      2s
#
# Sifting complete
#
#
# Root relaxation: objective 1.326000e+03, 10527 iterations, 0.13 seconds (0.18 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 23
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1326.00000    0    -          - 1326.00000      -     -    4s
#      0     0 1326.00000    0   22          - 1326.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 304
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 226
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 269
#      0     0 1326.00000    0   22          - 1326.00000      -     -    8s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 87
#      0     0 1326.00000    0   22          - 1326.00000      -     -   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 269
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
#      0     0 1326.00000    0    -          - 1326.00000      -     -   14s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     0 1326.00000    0    -          - 1326.00000      -     -   16s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
#      0     0 1326.00000    0    -          - 1326.00000      -     -   18s
# Separation round!
# *    0     0               0    1326.0000000 1326.00000  0.00%     -   21s
#
# Cutting planes:
#   Lazy constraints: 9
#
# Explored 1 nodes (15932 simplex iterations) in 21.38 seconds (0.78 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1326
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.326000000000e+03, best bound 1.326000000000e+03, gap 0.0000%
#
# User-callback calls 370, time in user-callback 20.78 sec

# %%
# Plotting the graph
plt.figure(figsize=(10, 6))
plt.plot(vertices_list, time_list_none, marker='o', label = "No Additional Contraints")
plt.plot(vertices_list, time_list_2, marker='x', label = "Cardinality 2 SEC")
plt.plot(vertices_list, time_list_3, marker='s', label = "Cardinality 3 SEC")
plt.xlabel('Number of Vertices')
plt.ylabel('Computation Time (seconds)')
#plt.title('Computation Time vs Number of Vertices in TSP')
plt.legend()
plt.grid(True)
plt.show()


for i in range(len(objective_list_none)):
        
        assert objective_list_none[i]==objective_list_2[i]

# %% [markdown]
# ## Q2 Fractional

# %%
time_list_none_f = time_list_frac
time_list_2_f = list()
time_list_3_f = list()
objective_list_none_f = objective_list_frac
objective_list_2_f = list()
objective_list_3_f = list()
nrows_list_none_f = nrows_list_frac
nrows_list_2_f = list()
nrows_list_3_f = list()

for vert in vertices_list:
    filtered_vertices = vert
    filtered_cost = {(i, j): cost_val for (i, j), cost_val in cost.items() if i < filtered_vertices and j < filtered_vertices}

    i_2 = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s_2 = TspFractionalBCSolver(instance=i_2, cardinality=2.2)
    solution = s_2.solve()

    time_list_2_f.append(s_2._model.Runtime)
    objective_list_2_f.append(s_2._model.ObjVal)
    nrows_list_2_f.append(s_2._model.NumConstrs)
    
    i_3 = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s_3 = TspFractionalBCSolver(instance=i_3, cardinality=2.3)
    solution = s_3.solve()

    time_list_3_f.append(s_3._model.Runtime)
    objective_list_3_f.append(s_3._model.ObjVal)
# Out:
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 552 rows, 506 columns and 2024 nonzeros
# Model fingerprint: 0xb009aa87
# Variable types: 0 continuous, 506 integer (506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Presolve removed 253 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 299 rows, 506 columns, 1518 nonzeros
# Variable types: 0 continuous, 506 integer (506 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 19
#
# Root relaxation: objective 1.920000e+02, 66 iterations, 0.00 seconds (0.00 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  192.00000    0    -          -  192.00000      -     -    0s
# Separation round!
# *    0     0               0     192.0000000  192.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 2
#
# Explored 1 nodes (69 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 192
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.920000000000e+02, best bound 1.920000000000e+02, gap 0.0000%
#
# User-callback calls 143, time in user-callback 0.04 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 11178 rows, 506 columns and 33902 nonzeros
# Model fingerprint: 0xc1811a43
# Variable types: 0 continuous, 506 integer (506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# Found heuristic solution: objective 407.0000000
# Presolve removed 7337 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 3841 rows, 506 columns, 12144 nonzeros
# Variable types: 0 continuous, 506 integer (506 binary)
# Root relaxation presolved: 3841 rows, 506 columns, 12144 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 1.920000e+02, 49 iterations, 0.01 seconds (0.01 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 8
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  192.00000    0    -  407.00000  192.00000  52.8%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#      0     0  192.00000    0    -  407.00000  192.00000  52.8%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#      0     0  192.00000    0    -  407.00000  192.00000  52.8%     -    0s
# Separation round!
# *    0     0               0     192.0000000  192.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 3
#
# Explored 1 nodes (55 simplex iterations) in 0.09 seconds (0.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 192 407
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.920000000000e+02, best bound 1.920000000000e+02, gap 0.0000%
#
# User-callback calls 160, time in user-callback 0.06 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2352 rows, 2256 columns and 9024 nonzeros
# Model fingerprint: 0xbb283011
# Variable types: 0 continuous, 2256 integer (2256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 35
# Presolve removed 1128 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 1224 rows, 2256 columns, 6768 nonzeros
# Variable types: 0 continuous, 2256 integer (2256 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 44
#
# Root relaxation: objective 3.410000e+02, 214 iterations, 0.00 seconds (0.00 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  341.00000    0    -          -  341.00000      -     -    0s
#      0     0  341.00000    0   14          -  341.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 44
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 36
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
#      0     0  341.00000    0   22          -  341.00000      -     -    0s
# Separation round!
# H    0     0                     341.0000000  341.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Lazy constraints: 6
#
# Explored 1 nodes (221 simplex iterations) in 0.28 seconds (0.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 341
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.410000000000e+02, best bound 3.410000000000e+02, gap 0.0000%
#
# User-callback calls 168, time in user-callback 0.23 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 106128 rows, 2256 columns and 320352 nonzeros
# Model fingerprint: 0x2fcb9854
# Variable types: 0 continuous, 2256 integer (2256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 35
# Presolve removed 70312 rows and 0 columns
# Presolve time: 0.17s
# Presolved: 35816 rows, 2256 columns, 110544 nonzeros
# Variable types: 0 continuous, 2256 integer (2256 binary)
# Separation round!
# Found heuristic solution: objective 871.0000000
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 44
# Root relaxation presolved: 35817 rows, 2256 columns, 110556 nonzeros
#
#
# Root relaxation: objective 3.410000e+02, 188 iterations, 0.04 seconds (0.05 work units)
# Separation round!
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     341.0000000  341.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 1
#
# Explored 1 nodes (188 simplex iterations) in 0.36 seconds (0.58 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 341 871
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.410000000000e+02, best bound 3.410000000000e+02, gap 0.0000%
#
# User-callback calls 233, time in user-callback 0.11 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5402 rows, 5256 columns and 21024 nonzeros
# Model fingerprint: 0x145bbeba
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 35
# Presolve removed 2628 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 2774 rows, 5256 columns, 15768 nonzeros
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 67
#
# Root relaxation: objective 4.740000e+02, 311 iterations, 0.00 seconds (0.01 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 23
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  474.00000    0    -          -  474.00000      -     -    0s
#      0     0  474.00000    0    8          -  474.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 20
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 16
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 70
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 51
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 63
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 34
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 3
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 21
#      0     0  474.00000    0   33          -  474.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 58
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.714 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 54
#      0     0  474.00000    0    -          -  474.00000      -     -    0s
#      0     0  474.00000    0   16          -  474.00000      -     -    0s
# Separation round!
# Separation round!
# H    0     0                     474.0000000  474.00000  0.00%     -    1s
#      0     0  474.00000    0   16  474.00000  474.00000  0.00%     -    1s
#
# Cutting planes:
#   Lazy constraints: 13
#
# Explored 1 nodes (481 simplex iterations) in 1.12 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 474
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.740000000000e+02, best bound 4.740000000000e+02, gap 0.0000%
#
# User-callback calls 218, time in user-callback 1.00 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 378578 rows, 5256 columns and 1140552 nonzeros
# Model fingerprint: 0xe76d9a0c
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 35
# Presolve removed 251412 rows and 0 columns
# Presolve time: 0.85s
# Presolved: 127166 rows, 5256 columns, 388944 nonzeros
# Variable types: 0 continuous, 5256 integer (5256 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 69
# Root relaxation presolved: 127168 rows, 5256 columns, 388998 nonzeros
#
#
# Root relaxation: objective 4.740000e+02, 336 iterations, 0.13 seconds (0.18 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  474.00000    0    -          -  474.00000      -     -    1s
#      0     0  474.00000    0   20          -  474.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 40
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 56
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 9
#      0     0  474.00000    0    -          -  474.00000      -     -    2s
#      0     0  474.00000    0   28          -  474.00000      -     -    2s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 10
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 6
#      0     0  474.00000    0    8          -  474.00000      -     -    2s
# Separation round!
# H    0     0                     474.0000000  474.00000  0.00%     -    2s
#
# Cutting planes:
#   MIR: 1
#   Lazy constraints: 10
#
# Explored 1 nodes (345 simplex iterations) in 2.74 seconds (3.56 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 474
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.740000000000e+02, best bound 4.740000000000e+02, gap 0.0000%
#
# User-callback calls 584, time in user-callback 0.61 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 9702 rows, 9506 columns and 38024 nonzeros
# Model fingerprint: 0x70ea0c9b
# Variable types: 0 continuous, 9506 integer (9506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Presolve removed 4753 rows and 0 columns
# Presolve time: 0.03s
# Presolved: 4949 rows, 9506 columns, 28518 nonzeros
# Variable types: 0 continuous, 9506 integer (9506 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 92
#
# Root relaxation: objective 7.550000e+02, 516 iterations, 0.01 seconds (0.02 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  755.00000    0    -          -  755.00000      -     -    0s
#      0     0  755.00000    0   28          -  755.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 31
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 88
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 55
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 85
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 3
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 3
#      0     0  755.00000    0   38          -  755.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 55
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.833 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 20
#      0     0  755.00000    0    -          -  755.00000      -     -    1s
#      0     0  755.00000    0   16          -  755.00000      -     -    1s
# Separation round!
# Separation round!
# H    0     0                     755.0000000  755.00000  0.00%     -    1s
#      0     0  755.00000    0   16  755.00000  755.00000  0.00%     -    1s
#
# Cutting planes:
#   Lazy constraints: 10
#
# Explored 1 nodes (902 simplex iterations) in 1.64 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 755
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.550000000000e+02, best bound 7.550000000000e+02, gap 0.0000%
#
# User-callback calls 223, time in user-callback 1.44 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 922278 rows, 9506 columns and 2775752 nonzeros
# Model fingerprint: 0x340cde1d
# Variable types: 0 continuous, 9506 integer (9506 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Presolve removed 613137 rows and 0 columns
# Presolve time: 1.91s
# Presolved: 309141 rows, 9506 columns, 941094 nonzeros
# Variable types: 0 continuous, 9506 integer (9506 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 76
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 92
# Root relaxation presolved: 309143 rows, 9506 columns, 941586 nonzeros
#
#
# Root relaxation: objective 7.550000e+02, 609 iterations, 0.37 seconds (0.55 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 80
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  755.00000    0    -          -  755.00000      -     -    3s
#      0     0  755.00000    0   32          -  755.00000      -     -    3s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 77
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 56
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 29
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 89
#      0     0  755.00000    0    -          -  755.00000      -     -    5s
#      0     0  755.00000    0   44          -  755.00000      -     -    5s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 11
#      0     0  755.00000    0    -          -  755.00000      -     -    6s
#      0     0  755.00000    0   12          -  755.00000      -     -    6s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 69
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 49
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 64
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 13
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 16
#      0     0  755.00000    0    -          -  755.00000      -     -    7s
#      0     0  755.00000    0   20          -  755.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 75
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 8
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 46
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 37
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 92
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 13
# Separation round!
# H    0     0                     755.0000000  755.00000  0.00%     -    9s
#
# Cutting planes:
#   Lazy constraints: 20
#
# Explored 1 nodes (1849 simplex iterations) in 9.03 seconds (11.55 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 755
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.550000000000e+02, best bound 7.550000000000e+02, gap 0.0000%
#
# User-callback calls 1360, time in user-callback 1.84 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 15252 rows, 15006 columns and 60024 nonzeros
# Model fingerprint: 0x394f57ed
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 56
# Presolve removed 7503 rows and 0 columns
# Presolve time: 0.05s
# Presolved: 7749 rows, 15006 columns, 45018 nonzeros
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 119
#
# Root relaxation: objective 9.590000e+02, 701 iterations, 0.01 seconds (0.02 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 36
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  959.00000    0    -          -  959.00000      -     -    0s
#      0     0  959.00000    0   42          -  959.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 76
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 41
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# Separation round!
# H    0     0                     959.0000000  959.00000  0.00%     -    1s
#
# Cutting planes:
#   Lazy constraints: 5
#
# Explored 1 nodes (1768 simplex iterations) in 1.32 seconds (0.24 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 959
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.590000000000e+02, best bound 9.590000000000e+02, gap 0.0000%
#
# User-callback calls 193, time in user-callback 1.20 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1830978 rows, 15006 columns and 5507202 nonzeros
# Model fingerprint: 0xaf2b8f60
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 56
# Presolve removed 1217987 rows and 0 columns
# Presolve time: 4.33s
# Presolved: 612991 rows, 15006 columns, 1860744 nonzeros
# Variable types: 0 continuous, 15006 integer (15006 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 117
# Root relaxation presolved: 612993 rows, 15006 columns, 1860930 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.6280000e+01   2.334912e+01   2.144907e+08      7s
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      691    9.5900000e+02   0.000000e+00   0.000000e+00      7s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 7s
#
#       96 PPushes remaining with PInf 0.0000000e+00                 7s
#        0 PPushes remaining with PInf 0.0000000e+00                 7s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      7s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      791    9.5900000e+02   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 9.590000e+02, 791 iterations, 1.55 seconds (1.88 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 47
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  959.00000    0    -          -  959.00000      -     -    7s
#      0     0  959.00000    0   34          -  959.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 48
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 74
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 33
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 73
#      0     0  959.00000    0   34          -  959.00000      -     -   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.625 < 1)
# 	Set size: 30
# 	Found a subset which violate a SEC (flow = 0.375 < 1)
# 	Set size: 21
#      0     0  959.00000    0    -          -  959.00000      -     -   12s
#      0     0  959.00000    0   28          -  959.00000      -     -   12s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 8
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 25
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 95
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 29
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 77
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
#      0     0  959.00000    0   28          -  959.00000      -     -   15s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 103
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 45
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 72
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 65
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 108
# Separation round!
# H    0     0                     959.0000000  959.00000  0.00%     -   19s
#
# Cutting planes:
#   Lazy constraints: 22
#
# Explored 1 nodes (1544 simplex iterations) in 19.10 seconds (24.33 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 959
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.590000000000e+02, best bound 9.590000000000e+02, gap 0.0000%
#
# User-callback calls 2284, time in user-callback 3.42 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 22052 rows, 21756 columns and 87024 nonzeros
# Model fingerprint: 0xac00860c
# Variable types: 0 continuous, 21756 integer (21756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 57
# Presolve removed 10878 rows and 0 columns
# Presolve time: 0.07s
# Presolved: 11174 rows, 21756 columns, 65268 nonzeros
# Variable types: 0 continuous, 21756 integer (21756 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 144
#
# Root relaxation: objective 9.440000e+02, 833 iterations, 0.02 seconds (0.04 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 113
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  944.00000    0    -          -  944.00000      -     -    0s
#      0     0  944.00000    0   46          -  944.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 33
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 94
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 98
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.714 < 1)
# 	Set size: 35
# 	Found a subset which violate a SEC (flow = 0.714 < 1)
# 	Set size: 46
# 	Found a subset which violate a SEC (flow = 0.429 < 1)
# 	Set size: 38
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 67
#      0     0  944.00000    0    -          -  944.00000      -     -    2s
#      0     0  944.00000    0   28          -  944.00000      -     -    2s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 32
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 35
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 111
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 75
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 57
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
# Separation round!
# *    0     0               0     944.0000000  944.00000  0.00%     -    4s
#
# Cutting planes:
#   Lazy constraints: 17
#
# Explored 1 nodes (1579 simplex iterations) in 4.48 seconds (0.76 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 944
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.440000000000e+02, best bound 9.440000000000e+02, gap 0.0000%
#
# User-callback calls 352, time in user-callback 3.95 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3198428 rows, 21756 columns and 9616152 nonzeros
# Model fingerprint: 0xd42086f4
# Variable types: 0 continuous, 21756 integer (21756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 57
# Presolve removed 2128462 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 2128462 rows and 0 columns
# Presolve time: 9.70s
# Presolved: 1069966 rows, 21756 columns, 3241644 nonzeros
# Variable types: 0 continuous, 21756 integer (21756 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 68
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 144
# Root relaxation presolved: 1069968 rows, 21756 columns, 3246212 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root relaxation presolved: 1069967 rows, 21756 columns, 3246065 nonzeros
#
# Concurrent spin time: 0.47s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: objective 9.440000e+02, 826 iterations, 2.63 seconds (1.93 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 23
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  944.00000    0    -          -  944.00000      -     -   15s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
#      0     0  944.00000    0    -          -  944.00000      -     -   15s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 18
#      0     0  944.00000    0    -          -  944.00000      -     -   16s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
#      0     0  944.00000    0    -          -  944.00000      -     -   16s
#      0     0  944.00000    0   16          -  944.00000      -     -   17s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 48
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 121
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 78
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 83
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 83
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 76
#      0     0  944.00000    0    -          -  944.00000      -     -   26s
#      0     0  944.00000    0   57          -  944.00000      -     -   26s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.462 < 1)
# 	Set size: 5
#      0     0  944.00000    0    -          -  944.00000      -     -   28s
#      0     0  944.00000    0   14          -  944.00000      -     -   29s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 67
# Separation round!
# H    0     0                     944.0000000  944.00000  0.00%     -   30s
#
# Cutting planes:
#   Lazy constraints: 12
#
# Explored 1 nodes (1595 simplex iterations) in 30.46 seconds (33.04 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 944
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.440000000000e+02, best bound 9.440000000000e+02, gap 0.0000%
#
# User-callback calls 3334, time in user-callback 4.42 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 30102 rows, 29756 columns and 119024 nonzeros
# Model fingerprint: 0xa9e213cb
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 122
# Presolve removed 14878 rows and 0 columns
# Presolve time: 0.10s
# Presolved: 15224 rows, 29756 columns, 89268 nonzeros
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 167
#
# Root relaxation: objective 9.080000e+02, 978 iterations, 0.03 seconds (0.07 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 109
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  908.00000    0    -          -  908.00000      -     -    0s
#      0     0  908.00000    0   34          -  908.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 8
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 129
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 160
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 35
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 36
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 28
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 107
#      0     0  908.00000    0    -          -  908.00000      -     -    3s
#      0     0  908.00000    0   14          -  908.00000      -     -    3s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 96
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 40
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 99
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 45
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 58
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 127
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 121
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 95
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 42
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 22
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 65
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 81
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 14
#      0     2  908.00000    0    8          -  908.00000      -     -    8s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
# Separation round!
# 	Found a subset which violate a SEC (flow = -0.000 < 1)
# 	Set size: 8
#      3     0  908.00000    1    -          -  908.00000      -  10.3   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 142
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 75
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 132
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 72
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#     14     6  914.00000    1    -          -  914.00000      -  16.8   15s
# Separation round!
# Separation round!
# Separation round!
# Separation round!
# *   17     6               3     914.0000000  914.00000  0.00%  16.2   17s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 134
# Separation round!
#
# Cutting planes:
#   Lazy constraints: 35
#
# Explored 20 nodes (2011 simplex iterations) in 18.10 seconds (1.57 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 914
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.140000000000e+02, best bound 9.140000000000e+02, gap 0.0000%
#
# User-callback calls 456, time in user-callback 17.13 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5118378 rows, 29756 columns and 15383852 nonzeros
# Model fingerprint: 0xb74ba7a6
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 122
# Presolve removed 3407062 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 3407062 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 3407062 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 3407062 rows and 0 columns
# Presolve time: 15.90s
# Presolved: 1711316 rows, 29756 columns, 5177544 nonzeros
# Variable types: 0 continuous, 29756 integer (29756 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 67
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 169
# Root relaxation presolved: 1711318 rows, 29756 columns, 5181978 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
#
# Barrier performed 0 iterations in 24.55 seconds (36.94 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.53s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      650    9.1333333e+02   0.000000e+00   0.000000e+00     25s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        4 DPushes remaining with DInf 0.0000000e+00                25s
#        0 DPushes remaining with DInf 0.0000000e+00                25s
#
#      130 PPushes remaining with PInf 0.0000000e+00                25s
#        0 PPushes remaining with PInf 0.0000000e+00                25s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.8817842e-16     25s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      784    9.1333333e+02   0.000000e+00   0.000000e+00     26s
#
# Root relaxation: objective 9.133333e+02, 784 iterations, 5.56 seconds (5.21 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  913.33333    0    8          -  913.33333      -     -   25s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 168
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 122
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 167
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 41
# Separation round!
# H    0     0                     924.0000000  913.33333  1.15%     -   32s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 41
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 44
#      0     0  914.00000    0   18  924.00000  914.00000  1.08%     -   35s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 58
#      0     0  914.00000    0    8  924.00000  914.00000  1.08%     -   39s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 137
#      0     0  914.00000    0    -  924.00000  914.00000  1.08%     -   39s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 107
#      0     0  914.00000    0    -  924.00000  914.00000  1.08%     -   39s
#      0     0  914.00000    0   16  924.00000  914.00000  1.08%     -   39s
# Separation round!
# H    0     0                     914.0000000  914.00000  0.00%     -   40s
#      0     0  914.00000    0   16  914.00000  914.00000  0.00%     -   40s
#
# Cutting planes:
#   Lazy constraints: 2
#
# Explored 1 nodes (2018 simplex iterations) in 40.30 seconds (52.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 914 924
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.140000000000e+02, best bound 9.140000000000e+02, gap 0.0000%
#
# User-callback calls 4900, time in user-callback 4.50 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 39402 rows, 39006 columns and 156024 nonzeros
# Model fingerprint: 0x3b93f1ae
# Variable types: 0 continuous, 39006 integer (39006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
# Presolve removed 19503 rows and 0 columns
# Presolve time: 0.13s
# Presolved: 19899 rows, 39006 columns, 117018 nonzeros
# Variable types: 0 continuous, 39006 integer (39006 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 192
# Root relaxation presolved: 19900 rows, 39006 columns, 117048 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 9.120000e+02, 2814 iterations, 0.10 seconds (0.12 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 93
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  912.00000    0    -          -  912.00000      -     -    1s
#      0     0  912.00000    0   26          -  912.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 75
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 35
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 93
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 63
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 16
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 26
#      0     0  912.00000    0    -          -  912.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 16
#      0     0  912.00000    0    -          -  912.00000      -     -    5s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 80
#      0     0  912.00000    0    -          -  912.00000      -     -    5s
#      0     0  912.00000    0   28          -  912.00000      -     -    5s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 131
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 120
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 26
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 177
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 77
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 23
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 33
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 13
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 103
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 95
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# ...
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 146
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 143
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# *    0     0               0     923.0000000  923.00000  0.00%     -   25s
#
# Cutting planes:
#   Lazy constraints: 28
#
# Explored 1 nodes (6757 simplex iterations) in 25.62 seconds (3.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 923
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.230000000000e+02, best bound 9.230000000000e+02, gap 0.0000%
#
# User-callback calls 792, time in user-callback 23.80 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 15130728 rows, 61256 columns and 45451952 nonzeros
# Model fingerprint: 0xa1990ad9
# Variable types: 0 continuous, 61256 integer (61256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 199
# Presolve removed 0 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 16s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 22s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 40s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 46s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 50s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 55s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 60s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 66s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 72s) ...
# Presolve removed 10076612 rows and 0 columns (presolve time = 75s) ...
# Presolve removed 10076612 rows and 0 columns
# Presolve time: 77.60s
# Presolved: 5054116 rows, 61256 columns, 15252744 nonzeros
# Variable types: 0 continuous, 61256 integer (61256 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 103
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 244
# Root relaxation presolved: 5054118 rows, 61256 columns, 15263262 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Concurrent spin time: 0.19s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      902    9.2300000e+02   0.000000e+00   0.000000e+00    105s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#       13 DPushes remaining with DInf 0.0000000e+00               107s
#        0 DPushes remaining with DInf 0.0000000e+00               107s
#
#      290 PPushes remaining with PInf 0.0000000e+00               107s
#        0 PPushes remaining with PInf 0.0000000e+00               108s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00    108s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1196    9.2300000e+02   0.000000e+00   0.000000e+00    108s
#
# Root relaxation: objective 9.230000e+02, 1196 iterations, 17.37 seconds (15.49 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 28
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  923.00000    0    -          -  923.00000      -     -  110s
#      0     0  923.00000    0   30          -  923.00000      -     -  112s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 209
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 83
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 198
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.600 < 1)
# 	Set size: 21
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 7
#      0     0  923.00000    0    -          -  923.00000      -     -  171s
#      0     0  923.00000    0    8          -  923.00000      -     -  175s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 155
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 158
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 194
#      0     0  923.00000    0    8          -  923.00000      -     -  180s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 98
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 87
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 205
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 157
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 49
#      0     0  923.00000    0    8          -  923.00000      -     -  186s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 53
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 198
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 161
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 181
#      0     0  923.00000    0    8          -  923.00000      -     -  190s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 151
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 73
#      0     0  923.00000    0    8          -  923.00000      -     -  213s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 206
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 199
#      0     0  923.00000    0    8          -  923.00000      -     -  215s
# Separation round!
# H    0     0                     923.0000000  923.00000  0.00%     -  217s
#
# Cutting planes:
#   Lazy constraints: 24
#
# Explored 1 nodes (2460 simplex iterations) in 217.74 seconds (193.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 923
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.230000000000e+02, best bound 9.230000000000e+02, gap 0.0000%
#
# User-callback calls 16606, time in user-callback 20.06 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 74802 rows, 74256 columns and 297024 nonzeros
# Model fingerprint: 0x75d9b87b
# Variable types: 0 continuous, 74256 integer (74256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 203
# Presolve removed 37128 rows and 0 columns
# Presolve time: 0.25s
# Presolved: 37674 rows, 74256 columns, 222768 nonzeros
# Variable types: 0 continuous, 74256 integer (74256 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 267
# Root relaxation presolved: 37675 rows, 74256 columns, 222798 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.02s
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 1.072000e+03, 4456 iterations, 0.21 seconds (0.26 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 114
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1072.00000    0    -          - 1072.00000      -     -    3s
#      0     0 1072.00000    0   46          - 1072.00000      -     -    3s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 118
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 186
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 145
#      0     0 1072.00000    0   46          - 1072.00000      -     -    6s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 245
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.889 < 1)
# 	Set size: 110
# 	Found a subset which violate a SEC (flow = 0.111 < 1)
# 	Set size: 10
#      0     0 1072.00000    0    -          - 1072.00000      -     -    8s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 75
#      0     0 1072.00000    0    -          - 1072.00000      -     -   10s
#      0     0 1072.00000    0   14          - 1072.00000      -     -   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 215
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 53
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 238
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 123
#      0     0 1072.00000    0   14          - 1072.00000      -     -   16s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 90
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 14
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 69
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 94
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 121
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 54
#      0     2 1072.00000    0    8          - 1072.00000      -     -   24s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 42
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 16
#      1     2 1072.00000    1   10          - 1072.00000      -  71.0   26s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 96
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 84
#      4     1 1072.00000    1    -          - 1072.00000      -  50.5   30s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 232
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 232
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 233
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 33
#      9     4 1072.00000    2    8          - 1072.00000      -  50.7   36s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 55
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 117
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 50
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 194
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 28
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 5
#     12     4 1072.00000    3   14          - 1072.00000      -  41.8   41s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 38
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 28
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 49
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 165
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 209
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 166
# Separation round!
# Separation round!
# *   17     6               4    1072.0000000 1072.00000  0.00%  39.1   50s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 112
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 88
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
#     20     6     cutoff    2      1072.00000 1072.00000  0.00%  35.8   55s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 40
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 249
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 40
# Separation round!
#
# Cutting planes:
#   Lazy constraints: 47
#
# Explored 24 nodes (8982 simplex iterations) in 59.12 seconds (4.67 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1072
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.072000000000e+03, best bound 1.072000000000e+03, gap 0.0000%
#
# User-callback calls 818, time in user-callback 56.27 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 20198178 rows, 74256 columns and 60667152 nonzeros
# Model fingerprint: 0xd2eb040e
# Variable types: 0 continuous, 74256 integer (74256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 203
# Presolve removed 0 rows and 0 columns (presolve time = 6s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 11s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 27s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 36s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 40s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 45s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 50s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 55s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 60s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 66s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 70s) ...
# Presolve removed 13452712 rows and 0 columns (presolve time = 75s) ...
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.figure(figsize=(10, 6))
plt.plot(vertices_list, time_list_none_f, marker='o', label = "No Additional Contraints")
plt.plot(vertices_list, time_list_2_f, marker='x', label = "Cardinality 2 SEC")
plt.plot(vertices_list, time_list_3_f, marker='s', label = "Cardinality 3 SEC")
plt.xlabel('Number of Vertices')
plt.ylabel('Computation Time (seconds)')
#plt.title('Computation Time vs Number of Vertices in TSP')
plt.legend()
plt.grid(True)
plt.show()



for i in range(len(objective_list_none_f)):
        
        assert objective_list_none_f[i]==objective_list_2_f[i]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/rossfleming/Documents/GitHub/tsp_project/master file.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(10, 6))
#       <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X45sZmlsZQ%3D%3D?line=1'>2</a> plt.plot(vertices_list, time_list_none_f, marker='o', label = "No Additional Contraints")
#       <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X45sZmlsZQ%3D%3D?line=2'>3</a> plt.plot(vertices_list, time_list_2_f, marker='x', label = "Cardinality 2 SEC")
#
# NameError: name 'plt' is not defined

# %%
# Check how many times cardinality constraints where violated
for entry in s.lazy_constraints_added:
    subtour = entry['subtour']
    constraint = entry['constraint']
    
    # Check if the subtour length is exactly 2
    if len(subtour) == 2:
        # The subtour contains exactly two vertices i and j
        i, j = subtour
        # The corresponding constraint is for i to j and j to i
        print(f"Lazy constraint for subtour {subtour}")
# Out:
# Lazy constraint for subtour [35, 264]
# Lazy constraint for subtour [0, 322]
# Lazy constraint for subtour [1, 321]
# Lazy constraint for subtour [2, 320]
# Lazy constraint for subtour [3, 319]
# Lazy constraint for subtour [4, 318]
# Lazy constraint for subtour [5, 317]
# Lazy constraint for subtour [6, 316]
# Lazy constraint for subtour [7, 315]
# Lazy constraint for subtour [8, 314]
# Lazy constraint for subtour [9, 313]
# Lazy constraint for subtour [10, 312]
# Lazy constraint for subtour [11, 311]
# Lazy constraint for subtour [12, 310]
# Lazy constraint for subtour [13, 309]
# Lazy constraint for subtour [14, 308]
# Lazy constraint for subtour [15, 307]
# Lazy constraint for subtour [16, 306]
# Lazy constraint for subtour [17, 305]
# Lazy constraint for subtour [18, 304]
# Lazy constraint for subtour [19, 303]
# Lazy constraint for subtour [20, 302]
# Lazy constraint for subtour [21, 301]
# Lazy constraint for subtour [22, 300]
# Lazy constraint for subtour [23, 299]
# Lazy constraint for subtour [24, 298]
# Lazy constraint for subtour [25, 297]
# Lazy constraint for subtour [26, 296]
# Lazy constraint for subtour [27, 295]
# Lazy constraint for subtour [28, 294]
# Lazy constraint for subtour [29, 293]
# Lazy constraint for subtour [30, 292]
# Lazy constraint for subtour [31, 291]
# Lazy constraint for subtour [32, 290]
# Lazy constraint for subtour [33, 289]
# Lazy constraint for subtour [34, 288]
# Lazy constraint for subtour [35, 287]
# Lazy constraint for subtour [36, 286]
# Lazy constraint for subtour [37, 285]
# Lazy constraint for subtour [38, 284]
# Lazy constraint for subtour [39, 283]
# Lazy constraint for subtour [40, 282]
# Lazy constraint for subtour [41, 281]
# Lazy constraint for subtour [42, 280]
# Lazy constraint for subtour [43, 279]
# Lazy constraint for subtour [44, 278]
# Lazy constraint for subtour [45, 277]
# Lazy constraint for subtour [46, 276]
# Lazy constraint for subtour [47, 275]
# Lazy constraint for subtour [48, 274]
# Lazy constraint for subtour [49, 273]
# Lazy constraint for subtour [50, 272]
# Lazy constraint for subtour [51, 271]
# Lazy constraint for subtour [52, 270]
# Lazy constraint for subtour [53, 269]
# Lazy constraint for subtour [54, 268]
# Lazy constraint for subtour [55, 267]
# Lazy constraint for subtour [56, 266]
# Lazy constraint for subtour [57, 265]
# Lazy constraint for subtour [58, 264]
# Lazy constraint for subtour [59, 263]
# Lazy constraint for subtour [60, 262]
# Lazy constraint for subtour [61, 261]
# Lazy constraint for subtour [62, 260]
# Lazy constraint for subtour [63, 259]
# Lazy constraint for subtour [64, 258]
# Lazy constraint for subtour [65, 257]
# Lazy constraint for subtour [66, 256]
# Lazy constraint for subtour [67, 255]
# Lazy constraint for subtour [68, 254]
# Lazy constraint for subtour [69, 253]
# Lazy constraint for subtour [70, 252]
# Lazy constraint for subtour [71, 251]
# Lazy constraint for subtour [72, 250]
# Lazy constraint for subtour [73, 249]
# Lazy constraint for subtour [74, 248]
# Lazy constraint for subtour [75, 247]
# Lazy constraint for subtour [76, 246]
# Lazy constraint for subtour [77, 245]
# Lazy constraint for subtour [78, 244]
# Lazy constraint for subtour [79, 243]
# Lazy constraint for subtour [80, 242]
# Lazy constraint for subtour [81, 241]
# Lazy constraint for subtour [82, 240]
# Lazy constraint for subtour [83, 239]
# Lazy constraint for subtour [84, 238]
# Lazy constraint for subtour [85, 237]
# Lazy constraint for subtour [86, 236]
# Lazy constraint for subtour [87, 235]
# Lazy constraint for subtour [88, 234]
# Lazy constraint for subtour [89, 233]
# Lazy constraint for subtour [90, 232]
# Lazy constraint for subtour [91, 231]
# Lazy constraint for subtour [92, 230]
# Lazy constraint for subtour [93, 229]
# Lazy constraint for subtour [94, 228]
# Lazy constraint for subtour [95, 227]
# Lazy constraint for subtour [96, 226]
# Lazy constraint for subtour [97, 225]
# Lazy constraint for subtour [98, 224]
# Lazy constraint for subtour [99, 223]
# Lazy constraint for subtour [100, 222]
# Lazy constraint for subtour [101, 221]
# Lazy constraint for subtour [102, 220]
# Lazy constraint for subtour [103, 219]
# Lazy constraint for subtour [104, 218]
# Lazy constraint for subtour [105, 217]
# Lazy constraint for subtour [106, 216]
# Lazy constraint for subtour [107, 215]
# Lazy constraint for subtour [108, 214]
# Lazy constraint for subtour [109, 213]
# Lazy constraint for subtour [110, 212]
# Lazy constraint for subtour [111, 211]
# Lazy constraint for subtour [112, 210]
# Lazy constraint for subtour [113, 209]
# Lazy constraint for subtour [114, 208]
# Lazy constraint for subtour [115, 207]
# Lazy constraint for subtour [116, 206]
# Lazy constraint for subtour [117, 205]
# Lazy constraint for subtour [118, 204]
# Lazy constraint for subtour [119, 203]
# Lazy constraint for subtour [120, 202]
# Lazy constraint for subtour [121, 201]
# Lazy constraint for subtour [122, 200]
# Lazy constraint for subtour [123, 199]
# Lazy constraint for subtour [124, 198]
# Lazy constraint for subtour [125, 197]
# Lazy constraint for subtour [126, 196]
# Lazy constraint for subtour [127, 195]
# Lazy constraint for subtour [128, 194]
# Lazy constraint for subtour [129, 193]
# Lazy constraint for subtour [130, 192]
# Lazy constraint for subtour [131, 191]
# Lazy constraint for subtour [132, 190]
# Lazy constraint for subtour [133, 189]
# Lazy constraint for subtour [134, 188]
# Lazy constraint for subtour [135, 187]
# Lazy constraint for subtour [136, 186]
# Lazy constraint for subtour [137, 185]
# Lazy constraint for subtour [138, 184]
# Lazy constraint for subtour [139, 183]
# Lazy constraint for subtour [140, 182]
# Lazy constraint for subtour [141, 181]
# Lazy constraint for subtour [142, 180]
# Lazy constraint for subtour [143, 179]
# Lazy constraint for subtour [144, 178]
# Lazy constraint for subtour [145, 177]
# Lazy constraint for subtour [146, 176]
# Lazy constraint for subtour [147, 175]
# Lazy constraint for subtour [148, 174]
# Lazy constraint for subtour [149, 173]
# Lazy constraint for subtour [150, 172]
# Lazy constraint for subtour [151, 171]
# Lazy constraint for subtour [152, 170]
# Lazy constraint for subtour [153, 169]
# Lazy constraint for subtour [154, 168]
# Lazy constraint for subtour [155, 167]
# Lazy constraint for subtour [156, 166]
# Lazy constraint for subtour [157, 165]
# Lazy constraint for subtour [158, 164]
# Lazy constraint for subtour [159, 163]
# Lazy constraint for subtour [14, 235]
# Lazy constraint for subtour [18, 211]
# Lazy constraint for subtour [25, 300]
# Lazy constraint for subtour [6, 98]

# %%
# Check how many times cardinality constraints where violated
for entry in s.lazy_constraints_added:
    subtour = entry['subtour']
    constraint = entry['constraint']
    

    # Check if the subtour length is exactly 2
    if len(subtour) == 3:
        # The subtour contains exactly two vertices i and j
        i, j, k = subtour
        # The corresponding constraint is for i to j and j to i
        print(f"Lazy constraint for subtour {subtour}")
# Out:
# Lazy constraint for subtour [45, 88, 110]
# Lazy constraint for subtour [162, 195, 275]
# Lazy constraint for subtour [160, 161, 162]
# Lazy constraint for subtour [0, 317, 316]
# Lazy constraint for subtour [1, 308, 306]

# %% [markdown]
# # Question 3

# %% [markdown]
# ## Integer

# %%
# Load data set 1
tsp_loader = TspDataLoader()
n_vertices, cost, closest_vertices_array = tsp_loader.load_problem('rbg443.atsp')
i = TspInstance(n_vertices=n_vertices, cost=cost, closest_vertices_array=closest_vertices_array)
solver = TspIntegerBCSolver(instance=i, cardinality=None)
solution = solver.solve()
solver._model.Runtime
# Out:
# 196249
# EXPLICIT
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 886 rows, 195806 columns and 391612 nonzeros
# Model fingerprint: 0xf767418b
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.17s
# Presolved: 886 rows, 195806 columns, 391612 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity      0.0000000e+00      5s
#        1       1027   3.3000000e+08   1.4219039e-01      5s
#        2       2524   2.0600028e+08   2.5568452e-01      5s
#        3       3572   1.8600044e+08   5.2890655e-01      5s
#        4       4747   1.5600073e+08   5.4835000e-01      5s
#        5       5818   1.5000079e+08   6.3555867e-01      5s
#        6       6953   1.0400133e+08   9.4306010e+01      5s
#        7       8126   5.4001953e+07   8.9322049e+01      5s
#        8       9365   2.6002333e+07   8.7376135e+01      5s
#        9      10531   2.7581215e+03   8.7695513e+01      5s
#       10      11619   2.7581214e+03   8.7972592e+01      5s
#       11      12801   2.7581214e+03   8.8144064e+01      5s
#       12      14070   2.7371237e+03   8.8484330e+01      5s
#       13      15250   2.7371237e+03   8.8648074e+01      5s
#       14      16632   2.7241258e+03   8.9605263e+01      5s
#       15      18027   2.7141261e+03   9.1897003e+01      5s
#       16      19560   2.7131252e+03   9.4098532e+01      5s
#       17      21168   2.7131243e+03   1.8774188e+03      5s
#       18      22508   2.7131241e+03   2.5327374e+03      5s
#
# Sifting complete
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    23644    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.720000e+03, 23644 iterations, 0.51 seconds (0.65 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0  103          - 2720.00000      -     -    6s
#      0     0 2720.00000    0  103          - 2720.00000      -     -   11s
#      0     0 2720.00000    0  103          - 2720.00000      -     -   15s
#      0     0 2720.00000    0    -          - 2720.00000      -     -   16s
#      0     0 2720.00000    0   14          - 2720.00000      -     -   17s
# H    0     0                    2720.0000000 2720.00000  0.00%     -   17s
#      0     0 2720.00000    0   14 2720.00000 2720.00000  0.00%     -   17s
#
# Cutting planes:
#   Lazy constraints: 254
#
# Explored 1 nodes (25485 simplex iterations) in 17.36 seconds (3.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 613, time in user-callback 15.26 sec
# 17.365794897079468

# %%
No_cardinality = solver._model.Runtime

# %%
# Looping through different cardinality constraints
pairs = [(3.2, 3), (3.2, 4), (3.2, 5), (3.3, 4), (3.3, 5), (3.4, 5)]
solve_time_q3 = list()

for cardinality, l in pairs:
    solver = TspIntegerBCSolver(instance=i, cardinality=cardinality, l=l)
    solution = solver.solve()
    solve_time_q3.append( solver._model.Runtime)
# Out:
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2215 rows, 195806 columns and 394270 nonzeros
# Model fingerprint: 0x5c03eefe
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 14 rows and 0 columns
# Presolve time: 0.21s
# Presolved: 2201 rows, 195806 columns, 394242 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 2420 rows, 195806 columns, 394704 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 11061 iterations, 0.18 seconds (0.26 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   33          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   33          - 2720.00000      -     -   11s
#      0     0 2720.00000    0    -          - 2720.00000      -     -   16s
# *    0     0               0    2720.0000000 2720.00000  0.00%     -   17s
#
# Cutting planes:
#   Lazy constraints: 240
#
# Explored 1 nodes (47671 simplex iterations) in 17.46 seconds (4.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 528, time in user-callback 15.35 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2658 rows, 195806 columns and 395156 nonzeros
# Model fingerprint: 0x87b8bbaf
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 24 rows and 0 columns
# Presolve time: 0.21s
# Presolved: 2634 rows, 195806 columns, 395108 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 2851 rows, 195806 columns, 395586 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 10389 iterations, 0.18 seconds (0.27 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   35          - 2720.00000      -     -    6s
# H    0     0                    2720.0000000 2720.00000  0.00%     -    9s
#
# Cutting planes:
#   Lazy constraints: 229
#
# Explored 1 nodes (10585 simplex iterations) in 9.78 seconds (1.56 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 373, time in user-callback 8.91 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3101 rows, 195806 columns and 396042 nonzeros
# Model fingerprint: 0xc52dd3a8
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 38 rows and 0 columns
# Presolve time: 0.21s
# Presolved: 3063 rows, 195806 columns, 395966 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 3278 rows, 195806 columns, 396460 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 11326 iterations, 0.19 seconds (0.28 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   56          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   56          - 2720.00000      -     -   10s
# H    0     0                    2720.0000000 2720.00000  0.00%     -   11s
#      0     0 2720.00000    0   56 2720.00000 2720.00000  0.00%     -   11s
#
# Cutting planes:
#   Lazy constraints: 229
#
# Explored 1 nodes (11344 simplex iterations) in 11.23 seconds (1.52 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 444, time in user-callback 10.29 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 7974 rows, 195806 columns and 411104 nonzeros
# Model fingerprint: 0x67fa220d
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 98 rows and 0 columns
# Presolve time: 0.21s
# Presolved: 7876 rows, 195806 columns, 410834 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 8093 rows, 195806 columns, 411312 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 9957 iterations, 0.21 seconds (0.35 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   49          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   49          - 2720.00000      -     -   11s
#      0     0 2720.00000    0    -          - 2720.00000      -     -   15s
#      0     0 2720.00000    0   12          - 2720.00000      -     -   15s
# H    0     0                    2720.0000000 2720.00000  0.00%     -   19s
#      0     0 2720.00000    0   12 2720.00000 2720.00000  0.00%     -   19s
#
# Cutting planes:
#   Lazy constraints: 245
#
# Explored 1 nodes (28452 simplex iterations) in 19.39 seconds (4.71 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 739, time in user-callback 16.67 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 11961 rows, 195806 columns and 422622 nonzeros
# Model fingerprint: 0xf1b179a0
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 196 rows and 0 columns
# Presolve time: 0.23s
# Presolved: 11765 rows, 195806 columns, 422072 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 11980 rows, 195806 columns, 422566 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.7390000e+03   1.000000e+00   2.914933e+06      5s
#     8713    2.7200000e+03   0.000000e+00   0.000000e+00      5s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 8713 iterations, 0.21 seconds (0.34 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   48          - 2720.00000      -     -    7s
#      0     0 2720.00000    0   48          - 2720.00000      -     -   12s
#      0     0 2720.00000    0    -          - 2720.00000      -     -   16s
# *    0     0               0    2720.0000000 2720.00000  0.00%     -   16s
#
# Cutting planes:
#   Lazy constraints: 243
#
# Explored 1 nodes (29341 simplex iterations) in 16.65 seconds (4.74 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 566, time in user-callback 14.18 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38541 rows, 195806 columns and 528942 nonzeros
# Model fingerprint: 0xeb48c79c
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 700 rows and 0 columns
# Presolve time: 0.30s
# Presolved: 37841 rows, 195806 columns, 526376 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 38056 rows, 195806 columns, 526870 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.59s
#
# Barrier performed 0 iterations in 5.68 seconds (1.64 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.56s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 4748 iterations, 0.84 seconds (0.60 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    7s
#      0     0 2720.00000    0   30          - 2720.00000      -     -    7s
#      0     0 2720.00000    0   30          - 2720.00000      -     -   12s
#      0     0 2720.00000    0    -          - 2720.00000      -     -   14s
# *    0     0               0    2720.0000000 2720.00000  0.00%     -   15s
#
# Cutting planes:
#   Lazy constraints: 228
#
# Explored 1 nodes (33615 simplex iterations) in 15.11 seconds (5.41 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 676, time in user-callback 12.02 sec

# %%
# Convert pairs to string format for labeling
pairs_2 = [(2, 3), (2, 4), (2, 5), (3, 4), (3, 5), (4, 5)]
pair_labels = [f"({card}, {l})" for card, l in pairs_2]

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(pair_labels, solve_time_q3, color='skyblue')
plt.hlines(No_cardinality, xmin=-0.5, xmax=len(pair_labels)-0.5, colors='red', label='No added constraints')
plt.xlabel('K, L Pairs')
plt.ylabel('Solve Time (Seconds)')
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.legend()
plt.show()

# %% [markdown]
# # Fractional

# %%
# Looping through different cardinality constraints
pairs = [(3.2, 3), (3.2, 4), (3.2, 5), (3.3, 4), (3.3, 5), (3.4, 5)]
solve_time_q3_frac = list()

for cardinality, l in pairs:
    solver = TspFractionalBCSolver(instance=i, cardinality=cardinality, l=l)
    solution = solver.solve()
    solve_time_q3_frac.append(solver._model.Runtime)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/rossfleming/Documents/GitHub/tsp_project/master file.ipynb Cell 30 line 6
#       <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=2'>3</a> solve_time_q3_frac = list()
#       <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=4'>5</a> for cardinality, l in pairs:
# ----> <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=5'>6</a>     solver = TspFractionalBCSolver(instance=i, cardinality=cardinality, l=l)
#       <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=6'>7</a>     solution = solver.solve()
#       <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=7'>8</a>     solve_time_q3_frac.append(solver._model.Runtime)
#
# /Users/rossfleming/Documents/GitHub/tsp_project/master file.ipynb Cell 30 line 3
#      <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=30'>31</a> self.cardinality = cardinality  # Store the cardinality parameter
#      <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=31'>32</a> self.__build_graph()
# ---> <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=32'>33</a> self.__build_model()
#      <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=33'>34</a> self._L = l
#
# /Users/rossfleming/Documents/GitHub/tsp_project/master file.ipynb Cell 30 line 6
#      <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=60'>61</a> if self.cardinality == 3.2 or self.cardinality == 3.3 or self.cardinality ==3.4:
#      <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=61'>62</a>
#      <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=62'>63</a>     # Add custom constraints for the closest l vertices
#      <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=63'>64</a>     for i in self._V:
#      <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=64'>65</a>
#      <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=65'>66</a>         # Retrieve the l closest vertices to vertex i
# ---> <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=66'>67</a>         closest_vertices = self._instance.closest_vertices_array[i][:self._L]
#      <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=68'>69</a>         # Add constraints for each of the closest vertices
#      <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X56sZmlsZQ%3D%3D?line=69'>70</a>         for j in closest_vertices:
#
# AttributeError: 'TspFractionalBCSolver' object has no attribute '_L'

# %%
# Convert pairs to string format for labeling
pairs_2 = [(2, 3), (2, 4), (2, 5), (3, 4), (3, 5), (4, 5)]
pair_labels = [f"({card}, {l})" for card, l in pairs_2]

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(pair_labels, solve_time_q3_frac, color='skyblue')
plt.xlabel('K, L Pairs')
plt.ylabel('Solve Time (Seconds)')
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.show()
