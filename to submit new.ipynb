# %% [markdown]
# # Set up

# %%
from typing import Dict, Tuple, List
from math import sqrt
from dataclasses import dataclass
from gurobipy import Model, GRB, tupledict, LinExpr, GurobiError
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

import numpy as np
import os
import re

from itertools import combinations

from graph_tool import Graph, EdgePropertyMap
from graph_tool.generation import complete_graph
from graph_tool.flow import boykov_kolmogorov_max_flow, min_st_cut

# %% [markdown]
# # Define classes

# %% [markdown]
# ## Data loader

# %%
class TspDataLoader:
    """ Class to load and process data for TSP instances. """

    def __init__(self, dir='data'):
        self.dir = dir

    def load_problem(self, problem):
        """ Load a TSP problem and return its vertices count and cost matrix. """
        file_name = "data/"+problem

        # Read file content
        with open(file_name, 'r') as file:
            content = file.read()

        problem_type = problem.split('.')[-1]

        n = int(re.search(r'\d+', problem).group())
        # 64 is actually 65 
        if n == 64:
            n = 65

        # Process the file content
        data_lines = content.split('\n')

        try:
            start_index = data_lines.index('EDGE_WEIGHT_SECTION')
        except:
            start_index = data_lines.index('NODE_COORD_SECTION')
            
        # Extract the data lines after 'EDGE_WEIGHT_SECTION'
        edge_weight_lines = data_lines[start_index + 1:][:-2]

        # Parse the distance matrix (lines are not rows)
        if problem_type == 'atsp':
            distance_matrix = [list(map(int, line.split())) for line in edge_weight_lines if line.strip()]

            def flatten(l):
                return [item for sublist in l for item in sublist]

            distance_list = flatten(distance_matrix)
            print(len(distance_list))

            my_matrix = np.array(distance_list).reshape((n, n))
            my_matrix.shape
        else:
            try:
                print('has_index')
                ys = [ float(line.split(' ')[3])  for line in edge_weight_lines if line.strip()]
                xs = [ float(line.split(' ')[2])  for line in edge_weight_lines if line.strip()]
            except:
                ys = [ float(line.split(' ')[2])  for line in edge_weight_lines if line.strip()]
                xs = [ float(line.split(' ')[1])  for line in edge_weight_lines if line.strip()]

        for line in data_lines:
            if 'EDGE_WEIGHT_TYPE' in line:
                weight_type = line.split(':')[1].strip()
        print(weight_type)

        V = range(n)
        if problem_type == 'atsp':
            cost = {
                (i, j): my_matrix[i,j]
                for i in V for j in V if i != j
            }
        else:
            if weight_type == 'GEO':
                cost = {
                    (i, j): haversine_distance((xs[i], ys[i]), (xs[j], ys[j]))
                    for i in V for j in V if i != j
                }
            else:
                cost = {
                    (i, j): math.sqrt((xs[i] - xs[j]) ** 2 + (ys[i] - ys[j]) ** 2)
                    for i in V for j in V if i != j
                }

        # Initialize an array to store the 5 closest vertices for each vertex
        closest_vertices_array = []

        # For each vertex, find the 5 closest vertices and add to the array
        for i in V:
            sorted_vertices = sorted(V, key=lambda j: cost[i, j] if i != j else float('inf'))
            closest_vertices_array.append(sorted_vertices[1:6])  # Skip the first one (itself) and take the next five

        return n, cost, closest_vertices_array

# %% [markdown]
# ## Integer solver

# %%
class TspInstance:
    """ An instance of the Travelling Salesman Problem. """

    def __init__(self, n_vertices, cost, closest_vertices_array = None, x=None, y=None):
        """
        Initialize a TSP instance.

        Parameters
        ----------
        n_vertices : int
            Number of vertices in the graph.
        cost : dict[tuple[int, int], float]
            Dictionary with arcs as key, and their corresponding costs as values.
        x : list[float], optional
            X coordinates of the vertices (for plotting).
        y : list[float], optional
            Y coordinates of the vertices (for plotting).
        """
        self.n_vertices = n_vertices
        self.cost = cost
        self.closest_vertices_array = closest_vertices_array if closest_vertices_array is not None else []
        self.x = x if x is not None else []
        self.y = y if y is not None else []
        
@dataclass
class TspSolution:
    """ Solution to an instance of the Travelling Salesman Problem.

        Attributes
        ----------
        instance: TspInstance
            Reference to the TSP instance being solved.
        tour: List[int]
            Ordered list of vertices visited (without repeating the first one).
        cost: float
            Travel cost of the tour.
    """

    instance: TspInstance
    tour: List[int]
    cost: float
    lazy_constraints_added: List[dict]
    model_metrics: Dict

    def plot(self) -> Tuple[Figure, plt.Axes]:
        """ Plots the solution of the TSP.
        
            Vertices are black dots, the solution is represented by red lines.

            Returns
            -------
            A tuple with the figure and axes object from matplotlib.    
        """

        xy = [(self.instance.x[i], self.instance.y[i]) for i in self.tour + [self.tour[0]]]

        fig, ax = plt.subplots(figsize=(10, 10))
        ax.scatter(self.instance.x, self.instance.y, color='black')
        
        for pt1, pt2 in zip(xy[1:], xy[:-1]):
            x1, y1 = pt1
            x2, y2 = pt2
            ax.plot([x1, x2], [y1, y2], color='red')

        ax.set_title(f"TSP Solution. Num vertices: {self.instance.n_vertices}. Tour cost: {self.cost:.2f}.")
        ax.set_axis_off()

        return fig, ax
    
class TspIntegerBCSolver:
    """ 
    Solver for the Travelling Salesman Problem using the branch-and-cut algorithm.

    This solver applies the Dantzig-Fulkerson-Johnson (DFJ) formulation of the TSP
    and focuses on separating subtour elimination constraints (SECs) only on integer solutions.

    Attributes:
    _instance : TspInstance
        The instance of the TSP to be solved.
    _V : List[int]
        List of vertex indices in the TSP instance.
    _A : List[Tuple[int, int]]
        List of arcs (edges between pairs of vertices) in the TSP instance.
    _model : Model
        The Gurobi model for the TSP instance.
    _x : tupledict
        Gurobi variables representing whether an arc is included in the tour.
    """

    def __init__(self, instance: TspInstance, cardinality=None, l = None):
        """
        Initializes the solver with a TSP instance and builds the model.

        Parameters:
        instance (TspInstance): The TSP instance to be solved.
        """
        # Store the TSP instance and create lists of vertices and arcs
        self._instance = instance
        self._V = list(range(self._instance.n_vertices))
        self._A = list(self._instance.cost.keys())
        self.lazy_constraints_added = []  # Initialize an empty list to store lazy constraints
        self.cardinality = cardinality  # Store the cardinality parameter
        self._L = l  # Contraint to be added for l closest vertices


        # Build the optimization model
        self.__build_model()


    def __build_model(self):
        """ 
        Builds the initial DFJ model for the TSP without subtour elimination constraints (SECs).
        """
        # Initialize the Gurobi model
        self._model = Model()
        
        # Set the time limit for the solver (in seconds)
        self._model.setParam(GRB.Param.TimeLimit, 300)  # 300 seconds = 5 minutes

        # Add variables representing whether each arc is included in the tour
        self._x = self._model.addVars(self._A, obj=self._instance.cost, vtype=GRB.BINARY, name='x')

    

        # Add constraints to ensure exactly one outgoing and one incoming arc for each vertex
        self._model.addConstrs((self._x.sum(i, '*') == 1 for i in self._V), name='outgoing')
        self._model.addConstrs((self._x.sum('*', i) == 1 for i in self._V), name='incoming')

        # Question 2: Add constraints to ensure x(i,j) + x(j,k)  <= 1
        if self.cardinality == 2.2 or self.cardinality == 2.3:
            self._model.addConstrs((self._x[i, j] + self._x[j, i] <= 1 
                                    for i in self._V 
                                    for j in self._V 
                                    if i < j), name='cardinality two')

        # Question 2: Add constraints to ensure x(i,j) + x(j,k) +x(k,i) <= 2
        if self.cardinality == 2.3:
            self._model.addConstrs((self._x[i, j] + self._x[j, k] + self._x[k, i] <= 2 
                                    for i in self._V 
                                    for j in self._V 
                                    for k in self._V 
                                    if i < j and j < k), name='cardinality three')

        # Question 3 constraints of the type (2,L) 
        if self.cardinality == 3.2 or self.cardinality == 3.3 or self.cardinality ==3.4:

            # Add custom constraints for the closest l vertices
            for i in self._V:

                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]

                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    self._model.addConstr(self._x[i, j] + self._x[j, i] <= 1, name=f'closest_constraint_{i}_{j}')

        # Question 3 constraints of the type (3,L)
        if self.cardinality == 3.3 or self.cardinality == 3.4:
            # Add custom constraints for the closest l vertices
            for i in self._V:
                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]

                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    for k in closest_vertices:
                        if j < k :
                            self._model.addConstr(self._x[i, j] + self._x[j, k] + self._x[k, i] <= 2, name=f'closest_constraint_{i}_{j}_{k}')

        # Question 3 constraints of the type (4,L) 
        if self.cardinality ==3.4:

            # Add custom constraints for the closest l vertices
            for i in self._V:

                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]

                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    for k in closest_vertices:
                        for z in closest_vertices:
                            if j < k and k < z:  # Enforce ordering to prevent duplicates
                                self._model.addConstr(self._x[i, j] + self._x[j, k] + self._x[k, z] + self._x[z, i] <= 3, name=f'closest_constraint_{i}_{j}_{k}_{z}')



    def __next_vertex(self, i: int) -> int:
        """
        Finds the next vertex in the current solution, starting from vertex i.

        Parameters:
        i (int): The starting vertex index.

        Returns:
        int: The index of the next vertex in the tour.
        """
        # Ensure the vertex index is valid
        assert 0 <= i < self._instance.n_vertices

        # Loop through all vertices to find the next one in the tour
        for j in self._V:
            if i != j:
                try:
                    # Inside a callback, retrieve the solution using cbGetSolution
                    val = self._model.cbGetSolution(self._x[i, j])
                except:
                    # Otherwise, access the variable's value directly
                    val = self._x[i, j].X

                # If the arc is part of the solution, return the next vertex
                if val > 0.5:
                    return j

        # If no successor is found, raise an error
        assert False, f"Vertex {j} has no successor?!"

    def __tour_staring_at(self, i: int) -> List[int]:
        """
        Constructs a tour (or subtour) starting at vertex i based on the current solution.

        Parameters:
        i (int): The starting vertex index.

        Returns:
        List[int]: A list of vertex indices representing the tour.
        """
        # Ensure the vertex index is valid
        assert 0 <= i < self._instance.n_vertices

        # Initialize the tour with the starting vertex
        tour = [i]
        current = self.__next_vertex(i)

        # Continue adding vertices to the tour until it loops back to the start
        while current != i:
            tour.append(current)
            current = self.__next_vertex(current)

        return tour

    def __add_sec_for(self, S: List[int]) -> None:
        """
        Adds a subtour elimination constraint (SEC) for the vertices in set S.

        Parameters:
        S (List[int]): A list of vertex indices forming a subtour.
        """
        # Ensure the subtour has a valid number of vertices
        assert 0 < len(S) < self._instance.n_vertices
   
        # Record the constraint information
        constraint_info = {
            'subtour': S,
            'constraint': sum(self._x[i, j] for (i, j) in self._A if i in S and j not in S) >= 1
        }

        self.lazy_constraints_added.append(constraint_info)
        
        # Add the actual lazy constraint to the model
        self._model.cbLazy(sum(self._x[i, j] for (i, j) in self._A if i in S and j not in S) >= 1)

    def __separate(self, where: int) -> None:
        """ Separates eventual violated SECs. """

        if where != GRB.Callback.MIPSOL:
            return
        
        # Set of vertices not yet placed in a tour
        remaining = set(self._V)

        while len(remaining) > 0:
            # Get any vertex in set `remaining`
            current = next(iter(remaining))

            # Get the subtour which includes the vertex
            subtour = self.__tour_staring_at(current)

            # If the tour visits all vertices, nothing to do
            if len(subtour) == self._instance.n_vertices:
                return

            # Otherwise, it's a subtour => Add a SEC
            self.__add_sec_for(subtour)

            # Update set `remaining`
            remaining -= set(subtour)

    def solve(self) -> TspSolution:
        """ Solves the TSP DFJ model and returns the solution.
        
            It throws a RuntimeError if Gurobi cannot solve the model to optimality.

            Returns
            -------
            A TspSolution object with details about the solution.
        """

        # We must set this parameter to use callbacks
        self._model.setParam(GRB.Param.LazyConstraints, 1)

        # Gurobi always passes two parameters to the callback: `model` and `where`
        self._model.optimize(lambda _, where: self.__separate(where))


        if self._model.Status != GRB.OPTIMAL:
            return "Solution not found"
        #    raise RuntimeError(f"Could not find the optimal solution. Gurobi status = {self._model.Status}")

        model_metrics = {} 
        for metric in ["NumVars", "ObjVal", "ObjBound", "IterCount", "SolCount", "NodeCount", "Runtime"]:
            model_metrics[metric] = self._model.getAttr(metric)

        return TspSolution(
            instance=self._instance,
            tour=self.__tour_staring_at(0),
            cost=self._model.ObjVal,
            model_metrics=model_metrics,
            lazy_constraints_added=self.lazy_constraints_added
        )

# %% [markdown]
# # Fractional solver

# %%
class TspFractionalBCSolver:
    """ Solver for the Travelling Salesman Problem.
    
        It uses the branch-and-cut algorithm applied to the "DFJ" formulation.
        Subtour elimination constraints are separated on integer and
        fractional solutions alike.
    """

    _EPS: float = 1e-6

    _instance: TspInstance
    _V: List[int]
    _A: List[Tuple[int, int]]
    _g: Graph
    _cap: EdgePropertyMap
    _model: Model
    _x: tupledict
    _L: int

    def __init__(self, instance: TspInstance, cardinality=None, l = None):
        """ Initialises the solver and builds the model.
        
            Parameters
            ----------
            instance: TspInstance
                The TSP instance.
        """
        self._L = l  # Contraint to be added for l closest vertices
        self._instance = instance
        self._V = list(range(self._instance.n_vertices))
        self._A = list(self._instance.cost.keys())
        self.lazy_constraints_added = []  # Initialize an empty list to store lazy constraints
        self.cardinality = cardinality  # Store the cardinality parameter
        self.__build_graph()
        self.__build_model()


    def __build_graph(self) -> None:
        """ Builds the graph for cut separation. """
        self._g = complete_graph(N=self._instance.n_vertices, self_loops=False, directed=True)
        self._cap = self._g.new_edge_property(value_type='double')
        self._g.edge_properties['cap'] = self._cap       

    def __build_model(self) -> None:
        """ Builds the DFJ model without SECs. """
         
        self._model = Model()
        # Set the time limit for the solver (in seconds)
        self._model.setParam(GRB.Param.TimeLimit, 300)  # 300 seconds = 5 minutes
        self._x = self._model.addVars(self._A, obj=self._instance.cost, vtype=GRB.BINARY, name='x')
        self._model.addConstrs((self._x.sum(i, '*') == 1 for i in self._V), name='outgoing')
        self._model.addConstrs((self._x.sum('*', i) == 1 for i in self._V), name='incoming')

        # Question 2: Add constraints to ensure x(i,j) + x(j,k)  <= 1
        if self.cardinality == 2.2 or self.cardinality == 2.3:
            self._model.addConstrs((self._x[i, j] + self._x[j, i] <= 1 
                                    for i in self._V 
                                    for j in self._V 
                                    if i < j), name='cardinality two')

        # Question 2: Add constraints to ensure x(i,j) + x(j,k) +x(k,i) <= 2
        if self.cardinality == 2.3:
            self._model.addConstrs((self._x[i, j] + self._x[j, k] + self._x[k, i] <= 2 
                                    for i in self._V 
                                    for j in self._V 
                                    for k in self._V 
                                    if i < j and j < k), name='cardinality three')
            
        # Question 3 constraints of the type (2,L) 
        if self.cardinality == 3.2 or self.cardinality == 3.3 or self.cardinality ==3.4:

            # Add custom constraints for the closest l vertices
            for i in self._V:

                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]


                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    self._model.addConstr(self._x[i, j] + self._x[j, i] <= 1, name=f'closest_constraint_{i}_{j}')

        # Question 3 constraints of the type (3,L)
        if self.cardinality == 3.3 or self.cardinality == 3.4:
            # Add custom constraints for the closest l vertices
            for i in self._V:
                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]

                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    for k in closest_vertices:
                        if j < k :
                            self._model.addConstr(self._x[i, j] + self._x[j, k] + self._x[k, i] <= 2, name=f'closest_constraint_{i}_{j}_{k}')

        # Question 3 constraints of the type (4,L) 
        if self.cardinality ==3.4:

            # Add custom constraints for the closest l vertices
            for i in self._V:

                # Retrieve the l closest vertices to vertex i
                closest_vertices = self._instance.closest_vertices_array[i][:self._L]

                # Add constraints for each of the closest vertices
                for j in closest_vertices:
                    for k in closest_vertices:
                        for z in closest_vertices:
                            if j < k and k < z:  # Enforce ordering to prevent duplicates
                                self._model.addConstr(self._x[i, j] + self._x[j, k] + self._x[k, z] + self._x[z, i] <= 3, name=f'closest_constraint_{i}_{j}_{k}_{z}')

    def __next_vertex(self, i: int) -> int:
        """ Gets the vertex visited immediately after i in the current TSP solution.

            This is the (only) vertex j such that x[i,j] == 1. This function works both
            when inside a callback (when the value of x must be retrieved via cbGetSolution)
            and after the optimisation is over (when the value of X can be accessed via X).
        """

        assert 0 <= i < self._instance.n_vertices

        for j in self._V:
            if i != j:
                try:
                    # If inside a call-back, we use cbGetSolution
                    val = self._model.cbGetSolution(self._x[i, j])
                except:
                    # Otherwise we use .X
                    val = self._x[i, j].X

                if val > 0.5:
                    return j

        assert False, f"Vertex {j} has no successor?!"

    def __tour_staring_at(self, i: int) -> List[int]:
        """ Gives the (sub)tour starting at a given vertex i in the current TSP solution. """

        assert 0 <= i < self._instance.n_vertices

        tour = [i]
        current = self.__next_vertex(i)

        while current != i:
            tour.append(current)
            current = self.__next_vertex(current)

        return tour

    def __add_sec_for(self, S: List[int]) -> None:
        """ Adds a Subtour Elimination Constraint for set S. """

        assert 0 < len(S) < self._instance.n_vertices

        self._model.cbLazy(sum(self._x[i, j] for (i, j) in self._A if i in S and j not in S) >= 1)

        # Record the constraint information
        constraint_info = {
            'subtour': S,
            'constraint': sum(self._x[i, j] for (i, j) in self._A if i in S and j not in S) >= 1
        }

        self.lazy_constraints_added.append(constraint_info)

    def __set_capacity(self) -> None:
        """ Sets graph capacity based on current solution. """

        for e in self._g.edges():
            i, j = e.source(), e.target()

            try: # If we are in MIPSOL
                xval = self._model.cbGetSolution(self._x[i,j])
            except: # If we are in MIPNODE
                xval = self._model.cbGetNodeRel(self._x[i,j])

            self._cap[e] = xval

    def __separate(self, where: int) -> None:
        """ Separates eventual violated SECs. """

        if where not in [GRB.Callback.MIPSOL, GRB.Callback.MIPNODE]:
            return

        # In MIPNODE, we must ensure that we have the optimal solution to the
        # linear relaxation at that node. Otherwise we are not "authorised"
        # to call cbGetNodeRel. See:
        # https://www.gurobi.com/documentation/9.1/refman/py_model_cbgetnoderel.html
        if where == GRB.Callback.MIPNODE and self._model.cbGet(GRB.Callback.MIPNODE_STATUS) != GRB.OPTIMAL:
            return
        
        self.__set_capacity()

        source = self._g.vertex(0)
        already_added = set()

        print('Separation round!')

        for i in range(1, self._instance.n_vertices):
            if i in already_added:
                continue

            target = self._g.vertex(i)
            residual = boykov_kolmogorov_max_flow(
                g=self._g, source=source, target=target,
                capacity=self._cap
            )
            
            flow = residual.copy()
            flow.a = self._cap.a - residual.a

            total_flow = sum(flow[a] for a in target.in_edges())

            if total_flow < 1 - self._EPS: # Avoid numerical issues
                print(f"\tFound a subset which violate a SEC (flow = {total_flow:.3f} < 1)")
                
                cut = min_st_cut(g=self._g, source=source,capacity=self._cap, residual=residual)

                assert cut[source] == True
                assert cut[target] == False

                subtour = [j for j in self._V if cut[self._g.vertex(j)] == False]

                assert len(subtour) < self._instance.n_vertices

                print(f"\tSet size: {len(subtour)}")

                self.__add_sec_for(subtour)

                already_added = already_added.union(subtour)

    def solve(self) -> TspSolution:
        """ Solves the TSP DFJ model and returns the solution.
        
            It throws a RuntimeError if Gurobi cannot solve the model to optimality.

            Returns
            -------
            A TspSolution object with details about the solution.
        """

        # We must set this parameter to use callbacks
        self._model.setParam(GRB.Param.LazyConstraints, 1)

        # Gurobi always passes two parameters to the callback: `model` and `where`
        self._model.optimize(lambda _, where: self.__separate(where))

        if self._model.Status != GRB.OPTIMAL:
            return "Solution not found"
        #    raise RuntimeError(f"Could not find the optimal solution. Gurobi status = {self._model.Status}")

        model_metrics = {} 
        for metric in ["NumVars", "ObjVal", "ObjBound", "IterCount", "SolCount", "NodeCount", "Runtime"]:
            model_metrics[metric] = self._model.getAttr(metric)

        return TspSolution(
            instance=self._instance,
            tour=self.__tour_staring_at(0),
            cost=self._model.ObjVal,
            model_metrics=model_metrics,
            lazy_constraints_added=self.lazy_constraints_added
        )

# %% [markdown]
# # Question 1

# %%
# Load data set 1
tsp_loader = TspDataLoader()
#n_vertices, cost, closest_vertices_array = tsp_loader.load_problem('rbg323.atsp')
#vertices_list = range(23, 324, 50)

n_vertices, cost, closest_vertices_array = tsp_loader.load_problem('rbg443.atsp')
vertices_list = range(43, 444, 50)
# Out:
# 196249
# EXPLICIT

# %% [markdown]
# ### Solve with interger method

# %%
# interger
from tqdm import tqdm

# Output time and objective value for different number of vertices



# Integer
time_list, objective_list, nrows_list, sol_list, iter_list, nvars_list = list(), list(), list(), list(), list(), list()
for vert in tqdm(vertices_list):
    filtered_vertices = vert
    filtered_cost = {(i, j): cost_val for (i, j), cost_val in cost.items() if i < filtered_vertices and j < filtered_vertices}

    i = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s = TspIntegerBCSolver(instance=i, cardinality=None)
    sol = s.solve()

    time_list.append(s._model.Runtime)
    objective_list.append(s._model.ObjVal)
    nrows_list.append(s._model.NumConstrs)
    sol_list.append(sol.model_metrics['SolCount'])
    iter_list.append(sol.model_metrics['IterCount'])
    nvars_list.append(sol.model_metrics['NumVars'])

time_list_int, objective_list_int, nrows_list_int, sol_list_int, iter_list_int, nvars_list_int = time_list, objective_list, nrows_list, sol_list, iter_list, nvars_list

print("INTEGER FINISHED!!!")
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 86 rows, 1806 columns and 3612 nonzeros
# Model fingerprint: 0xfc6fed70
# Variable types: 0 continuous, 1806 integer (1806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 86 rows, 1806 columns, 3612 nonzeros
# Variable types: 0 continuous, 1806 integer (1806 binary)
#
# Root relaxation: objective 3.970000e+02, 187 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  397.00000    0    -          -  397.00000      -     -    0s
#      0     0  398.00000    0    -          -  398.00000      -     -    0s
#      0     0  398.00000    0   16          -  398.00000      -     -    0s
# H    0     0                     412.0000000  398.00000  3.40%     -    0s
# H    0     0                     408.0000000  398.00000  2.45%     -    0s
#      0     0  398.00000    0    -  408.00000  398.00000  2.45%     -    0s
#      0     0  398.00000    0    8  408.00000  398.00000  2.45%     -    0s
# H    0     0                     398.0000000  398.00000  0.00%     -    0s
#      0     0  398.00000    0    8  398.00000  398.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 41
#
# Explored 1 nodes (365 simplex iterations) in 0.15 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 398 408 412
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.980000000000e+02, best bound 3.980000000000e+02, gap 0.0000%
#
# User-callback calls 152, time in user-callback 0.09 sec
#  11%|█         | 1/9 [00:00<00:01,  4.74it/s]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 186 rows, 8556 columns and 17112 nonzeros
# Model fingerprint: 0x6fbb80bc
# Variable types: 0 continuous, 8556 integer (8556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.02s
# Presolved: 186 rows, 8556 columns, 17112 nonzeros
# Variable types: 0 continuous, 8556 integer (8556 binary)
#
# Root relaxation: objective 5.640000e+02, 462 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  564.00000    0    -          -  564.00000      -     -    0s
# *    0     0               0     564.0000000  564.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 49
#
# Explored 1 nodes (475 simplex iterations) in 0.27 seconds (0.04 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 564
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.640000000000e+02, best bound 5.640000000000e+02, gap 0.0000%
#
# User-callback calls 125, time in user-callback 0.21 sec
#  22%|██▏       | 2/9 [00:00<00:02,  3.01it/s]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 286 rows, 20306 columns and 40612 nonzeros
# Model fingerprint: 0xe8480751
# Variable types: 0 continuous, 20306 integer (20306 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.04s
# Presolved: 286 rows, 20306 columns, 40612 nonzeros
# Variable types: 0 continuous, 20306 integer (20306 binary)
#
# Root relaxation: objective 9.070000e+02, 868 iterations, 0.03 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  907.00000    0    -          -  907.00000      -     -    0s
#      0     0  907.00000    0   52          -  907.00000      -     -    0s
#      0     0  907.00000    0    -          -  907.00000      -     -    1s
#      0     0  907.00000    0   25          -  907.00000      -     -    1s
# H    0     0                     907.0000000  907.00000  0.00%     -    4s
#
# Cutting planes:
#   Lazy constraints: 133
#
# Explored 1 nodes (3720 simplex iterations) in 4.19 seconds (0.50 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 907
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.070000000000e+02, best bound 9.070000000000e+02, gap 0.0000%
#
# User-callback calls 335, time in user-callback 3.45 sec
#  33%|███▎      | 3/9 [00:05<00:13,  2.21s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 386 rows, 37056 columns and 74112 nonzeros
# Model fingerprint: 0xd887c2f1
# Variable types: 0 continuous, 37056 integer (37056 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.07s
# Presolved: 386 rows, 37056 columns, 74112 nonzeros
# Variable types: 0 continuous, 37056 integer (37056 binary)
#
# Root relaxation: objective 1.196000e+03, 1278 iterations, 0.06 seconds (0.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1196.00000    0    -          - 1196.00000      -     -    1s
#      0     0 1196.00000    0   18          - 1196.00000      -     -    1s
#      0     0 1196.00000    0    -          - 1196.00000      -     -    3s
#      0     0 1196.00000    0    -          - 1196.00000      -     -    3s
#      0     0 1196.00000    0   10          - 1196.00000      -     -    3s
# H    0     0                    1196.0000000 1196.00000  0.00%     -    3s
#      0     0 1196.00000    0   10 1196.00000 1196.00000  0.00%     -    4s
#
# Cutting planes:
#   Lazy constraints: 111
#
# Explored 1 nodes (8973 simplex iterations) in 4.02 seconds (0.41 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1196
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.196000000000e+03, best bound 1.196000000000e+03, gap 0.0000%
#
# User-callback calls 263, time in user-callback 3.41 sec
#  44%|████▍     | 4/9 [00:09<00:15,  3.14s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 486 rows, 58806 columns and 117612 nonzeros
# Model fingerprint: 0x6da57d8e
# Variable types: 0 continuous, 58806 integer (58806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.16s
# Presolved: 486 rows, 58806 columns, 117612 nonzeros
# Variable types: 0 continuous, 58806 integer (58806 binary)
#
# Root relaxation: objective 1.645000e+03, 1654 iterations, 0.10 seconds (0.10 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1645.00000    0    -          - 1645.00000      -     -    3s
#      0     0 1645.00000    0   97          - 1645.00000      -     -    3s
#      0     0 1645.00000    0   97          - 1645.00000      -     -    5s
#      0     0 1645.00000    0    -          - 1645.00000      -     -    6s
#      0     0 1645.00000    0    -          - 1645.00000      -     -    7s
#      0     0 1645.00000    0   15          - 1645.00000      -     -    7s
# H    0     0                    1645.0000000 1645.00000  0.00%     -    9s
#      0     0 1645.00000    0   15 1645.00000 1645.00000  0.00%     -    9s
#
# Cutting planes:
#   Lazy constraints: 145
#
# Explored 1 nodes (13792 simplex iterations) in 9.56 seconds (0.78 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1645
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.645000000000e+03, best bound 1.645000000000e+03, gap 0.0000%
#
# User-callback calls 381, time in user-callback 8.32 sec
#  56%|█████▌    | 5/9 [00:20<00:23,  5.80s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 586 rows, 85556 columns and 171112 nonzeros
# Model fingerprint: 0x4931b378
# Variable types: 0 continuous, 85556 integer (85556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.18s
# Presolved: 586 rows, 85556 columns, 171112 nonzeros
# Variable types: 0 continuous, 85556 integer (85556 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.860000e+02   0.000000e+00      5s
#     1759    1.8070000e+03   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 1.807000e+03, 1759 iterations, 0.55 seconds (0.15 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1807.00000    0    -          - 1807.00000      -     -    7s
#      0     0 1807.00000    0    -          - 1807.00000      -     -    8s
#      0     0 1807.00000    0   50          - 1807.00000      -     -    8s
#      0     0 1807.00000    0   50          - 1807.00000      -     -   13s
#      0     0 1807.00000    0   50          - 1807.00000      -     -   15s
#      0     0 1807.00000    0   69          - 1807.00000      -     -   15s
# *    0     0               0    1807.0000000 1807.00000  0.00%     -   16s
#
# Cutting planes:
#   MIR: 1
#   Lazy constraints: 173
#
# Explored 1 nodes (12784 simplex iterations) in 16.23 seconds (0.92 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1807
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.807000000000e+03, best bound 1.807000000000e+03, gap 0.0000%
#
# User-callback calls 444, time in user-callback 14.04 sec
#  67%|██████▋   | 6/9 [00:38<00:29,  9.93s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 686 rows, 117306 columns and 234612 nonzeros
# Model fingerprint: 0x14b563ff
# Variable types: 0 continuous, 117306 integer (117306 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.22s
# Presolved: 686 rows, 117306 columns, 234612 nonzeros
# Variable types: 0 continuous, 117306 integer (117306 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.860000e+02   0.000000e+00      7s
#     2521    2.0710000e+03   0.000000e+00   0.000000e+00      8s
#
# Root relaxation: objective 2.071000e+03, 2521 iterations, 0.41 seconds (0.37 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2071.00000    0    -          - 2071.00000      -     -    9s
#      0     0 2071.00000    0   48          - 2071.00000      -     -   10s
#      0     0 2071.00000    0   48          - 2071.00000      -     -   15s
#      0     0 2071.00000    0    -          - 2071.00000      -     -   17s
#      0     0 2071.00000    0    -          - 2071.00000      -     -   19s
# *    0     0               0    2071.0000000 2071.00000  0.00%     -   19s
#
# Cutting planes:
#   Lazy constraints: 192
#
# Explored 1 nodes (20397 simplex iterations) in 19.70 seconds (1.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2071
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.071000000000e+03, best bound 2.071000000000e+03, gap 0.0000%
#
# User-callback calls 483, time in user-callback 17.55 sec
#  78%|███████▊  | 7/9 [00:59<00:27, 13.78s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 786 rows, 154056 columns and 308112 nonzeros
# Model fingerprint: 0x2d4a9105
# Variable types: 0 continuous, 154056 integer (154056 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.35s
# Presolved: 786 rows, 154056 columns, 308112 nonzeros
# Variable types: 0 continuous, 154056 integer (154056 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.860000e+02   0.000000e+00     15s
#     1186    8.9100004e+02   5.650000e+02   0.000000e+00     15s
#     3069    2.3830000e+03   0.000000e+00   0.000000e+00     15s
#
# Root relaxation: objective 2.383000e+03, 3069 iterations, 0.68 seconds (0.42 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2383.00000    0    -          - 2383.00000      -     -   17s
#      0     0 2383.00000    0   64          - 2383.00000      -     -   18s
# H    0     0                    2384.0000000 2383.00000  0.04%     -   24s
#      0     0 2383.00000    0   64 2384.00000 2383.00000  0.04%     -   29s
#      0     0 2383.00000    0    - 2384.00000 2383.00000  0.04%     -   32s
#      0     0 2383.00000    0   16 2384.00000 2383.00000  0.04%     -   32s
#      0     0 2383.00000    0   16 2384.00000 2383.00000  0.04%     -   35s
#      0     0 2383.00000    0   16 2384.00000 2383.00000  0.04%     -   42s
#      0     0 2383.00000    0   16 2384.00000 2383.00000  0.04%     -   46s
# H    0     0                    2383.0000000 2383.00000  0.00%     -   59s
#
# Cutting planes:
#   Lazy constraints: 254
#
# Explored 1 nodes (45017 simplex iterations) in 59.08 seconds (3.38 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2383 2384
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.383000000000e+03, best bound 2.383000000000e+03, gap 0.0000%
#
# User-callback calls 777, time in user-callback 53.14 sec
#  89%|████████▉ | 8/9 [02:09<00:31, 31.55s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 886 rows, 195806 columns and 391612 nonzeros
# Model fingerprint: 0xf767418b
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.39s
# Presolved: 886 rows, 195806 columns, 391612 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   8.860000e+02   0.000000e+00     27s
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity      0.0000000e+00     27s
#        1       1027   3.3000000e+08   1.4219039e-01     27s
#        2       2524   2.0600028e+08   2.5568452e-01     27s
#        3       3572   1.8600044e+08   5.2890655e-01     27s
#        4       4747   1.5600073e+08   5.4835000e-01     27s
#        5       5818   1.5000079e+08   6.3555867e-01     27s
#        6       6953   1.0400133e+08   9.4306010e+01     27s
#        7       8126   5.4001953e+07   8.9322049e+01     27s
#        8       9365   2.6002333e+07   8.7376135e+01     27s
#        9      10531   2.7581215e+03   8.7695513e+01     27s
#       10      11619   2.7581214e+03   8.7972592e+01     27s
#       11      12801   2.7581214e+03   8.8144064e+01     27s
#       12      14070   2.7371237e+03   8.8484330e+01     27s
#       13      15250   2.7371237e+03   8.8648074e+01     27s
#       14      16632   2.7241258e+03   8.9605263e+01     27s
#       15      18027   2.7141261e+03   9.1897003e+01     27s
#       16      19560   2.7131252e+03   9.4098532e+01     27s
#       17      21168   2.7131243e+03   1.8774188e+03     27s
#       18      22508   2.7131241e+03   2.5327374e+03     27s
#
# Sifting complete
#
#    23644    2.7200000e+03   0.000000e+00   0.000000e+00     28s
#
# Root relaxation: objective 2.720000e+03, 23644 iterations, 0.97 seconds (0.65 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -   31s
#      0     0 2720.00000    0  103          - 2720.00000      -     -   31s
#      0     0 2720.00000    0  103          - 2720.00000      -     -   41s
#      0     0 2720.00000    0  103          - 2720.00000      -     -   45s
#      0     0 2720.00000    0    -          - 2720.00000      -     -   51s
#      0     0 2720.00000    0   14          - 2720.00000      -     -   52s
# H    0     0                    2720.0000000 2720.00000  0.00%     -   53s
#      0     0 2720.00000    0   14 2720.00000 2720.00000  0.00%     -   53s
#
# Cutting planes:
#   Lazy constraints: 254
#
# Explored 1 nodes (25485 simplex iterations) in 53.18 seconds (3.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 950, time in user-callback 48.67 sec
# 100%|██████████| 9/9 [03:05<00:00, 20.63s/it]
# INTEGER FINISHED!!!

# %% [markdown]
# ### Solve with fractional method

# %%
# Fractional
time_list, objective_list, nrows_list, sol_list, iter_list, nvars_list = list(), list(), list(), list(), list(), list()

for vert in tqdm(vertices_list):
    filtered_vertices = vert
    filtered_cost = {(i, j): cost_val for (i, j), cost_val in cost.items() if i < filtered_vertices and j < filtered_vertices}

    i = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s = TspFractionalBCSolver(instance=i, cardinality=None)
    sol = s.solve()

    if sol == 'Solution not found':
        time_list.append(300)
        objective_list.append(0)
        nrows_list.append(0)
        sol_list.append(0)
        iter_list.append(0)
        nvars_list.append(0)
        
    else :
        time_list.append(s._model.Runtime)
        objective_list.append(s._model.ObjVal)
        nrows_list.append(s._model.NumConstrs)
        sol_list.append(sol.model_metrics['SolCount'])
        iter_list.append(sol.model_metrics['IterCount'])
        nvars_list.append(sol.model_metrics['NumVars'])

time_list_frac, objective_list_frac, nrows_list_frac, sol_list_frac, iter_list_frac, nvars_list_frac = time_list, objective_list, nrows_list, sol_list, iter_list, nvars_list
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 86 rows, 1806 columns and 3612 nonzeros
# Model fingerprint: 0xfc6fed70
# Variable types: 0 continuous, 1806 integer (1806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 30
# Presolve time: 0.00s
# Presolved: 86 rows, 1806 columns, 3612 nonzeros
# Variable types: 0 continuous, 1806 integer (1806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 41
#
# Root relaxation: objective 3.970000e+02, 170 iterations, 0.00 seconds (0.00 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 8
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  397.00000    0    -          -  397.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#      0     0  397.00000    0    -          -  397.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#      0     0  397.00000    0    -          -  397.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     0  397.00000    0    -          -  397.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#      0     0  398.00000    0    -          -  398.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#      0     0  398.00000    0    -          -  398.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
#      0     0  398.00000    0    -          -  398.00000      -     -    0s
# Separation round!
# *    0     0               0     398.0000000  398.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 8
#
# Explored 1 nodes (179 simplex iterations) in 0.75 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 398
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.980000000000e+02, best bound 3.980000000000e+02, gap 0.0000%
#
# User-callback calls 130, time in user-callback 0.70 sec
#  11%|█         | 1/9 [00:01<00:08,  1.08s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 186 rows, 8556 columns and 17112 nonzeros
# Model fingerprint: 0x6fbb80bc
# Variable types: 0 continuous, 8556 integer (8556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
# Presolve time: 0.02s
# Presolved: 186 rows, 8556 columns, 17112 nonzeros
# Variable types: 0 continuous, 8556 integer (8556 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 91
#
# Root relaxation: objective 5.640000e+02, 444 iterations, 0.01 seconds (0.01 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 73
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  564.00000    0    -          -  564.00000      -     -    0s
#      0     0  564.00000    0   20          -  564.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 76
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 54
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 69
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 46
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 14
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 15
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 60
#      0     0  564.00000    0    -          -  564.00000      -     -    1s
#      0     0  564.00000    0   28          -  564.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 45
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 21
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 58
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 26
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 76
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 64
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 22
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# *    0     0               0     564.0000000  564.00000  0.00%     -    4s
#
# Cutting planes:
#   Lazy constraints: 18
#
# Explored 1 nodes (1017 simplex iterations) in 4.19 seconds (0.12 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 564
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.640000000000e+02, best bound 5.640000000000e+02, gap 0.0000%
#
# User-callback calls 233, time in user-callback 3.94 sec
#  22%|██▏       | 2/9 [00:05<00:21,  3.04s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 286 rows, 20306 columns and 40612 nonzeros
# Model fingerprint: 0xe8480751
# Variable types: 0 continuous, 20306 integer (20306 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 51
# Presolve time: 0.03s
# Presolved: 286 rows, 20306 columns, 40612 nonzeros
# Variable types: 0 continuous, 20306 integer (20306 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 141
#
# Root relaxation: objective 9.070000e+02, 981 iterations, 0.04 seconds (0.05 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 97
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  907.00000    0    -          -  907.00000      -     -    1s
#      0     0  907.00000    0   42          -  907.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 67
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 98
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 52
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.833 < 1)
# 	Set size: 53
# 	Found a subset which violate a SEC (flow = 0.833 < 1)
# 	Set size: 15
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 65
#      0     0  907.00000    0    -          -  907.00000      -     -    4s
#      0     0  907.00000    0   22          -  907.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 28
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 18
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 58
#      0     0  907.00000    0   22          -  907.00000      -     -    6s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 46
# Separation round!
# H    0     0                     907.0000000  907.00000  0.00%     -    8s
#
# Cutting planes:
#   Lazy constraints: 14
#
# Explored 1 nodes (3120 simplex iterations) in 8.51 seconds (0.34 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 907
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.070000000000e+02, best bound 9.070000000000e+02, gap 0.0000%
#
# User-callback calls 346, time in user-callback 8.01 sec
#  33%|███▎      | 3/9 [00:14<00:34,  5.68s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 386 rows, 37056 columns and 74112 nonzeros
# Model fingerprint: 0xd887c2f1
# Variable types: 0 continuous, 37056 integer (37056 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 158
# Presolve time: 0.07s
# Presolved: 386 rows, 37056 columns, 74112 nonzeros
# Variable types: 0 continuous, 37056 integer (37056 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 191
#
# Root relaxation: objective 1.196000e+03, 1171 iterations, 0.10 seconds (0.05 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 162
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1196.00000    0    -          - 1196.00000      -     -    2s
#      0     0 1196.00000    0   66          - 1196.00000      -     -    2s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 121
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 62
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 79
#      0     0 1196.00000    0   66          - 1196.00000      -     -    6s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 163
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.889 < 1)
# 	Set size: 95
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 56
# 	Found a subset which violate a SEC (flow = 0.444 < 1)
# 	Set size: 23
#      0     0 1196.00000    0    -          - 1196.00000      -     -    8s
#      0     0 1196.00000    0    8          - 1196.00000      -     -    8s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 51
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 102
#      0     0 1196.00000    0    8          - 1196.00000      -     -   13s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 107
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 136
#      0     0 1196.00000    0    8          - 1196.00000      -     -   15s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 113
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 52
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 18
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 44
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 150
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 68
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 55
#      0     2 1196.00000    0    8          - 1196.00000      -     -   24s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 20
#      1     2 1196.00000    1    -          - 1196.00000      -  30.0   25s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 20
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 44
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 30
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 22
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 35
#      4     5 1196.00000    2   26          - 1196.00000      -  44.0   30s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 27
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 52
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 45
# 	Found a subset which violate a SEC (flow = -0.000 < 1)
# 	Set size: 58
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 52
# 	Found a subset which violate a SEC (flow = -0.000 < 1)
# 	Set size: 65
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 68
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 67
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 17
#     11     4 1196.00000    1    -          - 1196.00000      -  26.3   42s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 33
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 41
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 32
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 42
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 41
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#     15     7 1196.00000    3   22          - 1196.00000      -  24.5   48s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 14
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 17
#     16     0 1196.00000    1    -          - 1196.00000      -  24.8   50s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 30
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 56
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 33
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 30
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 72
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 37
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 45
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 17
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 103
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 52
#     23     0 1196.00000    1    -          - 1196.00000      -  22.4   61s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 62
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 65
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 81
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 84
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 62
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# 	Found a subset which violate a SEC (flow = -0.000 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 58
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 41
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
#     30     2 1196.00000    1    -          - 1196.00000      -  19.0   71s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 42
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 52
#     33     5 1196.00000    3    -          - 1196.00000      -  19.3   76s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 40
# Separation round!
# Separation round!
# *   35     2               4    1196.0000000 1196.00000  0.00%  20.0   80s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
#
# Cutting planes:
#   Lazy constraints: 81
#
# Explored 37 nodes (7771 simplex iterations) in 82.39 seconds (1.55 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1196
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.196000000000e+03, best bound 1.196000000000e+03, gap 0.0000%
#
# User-callback calls 621, time in user-callback 80.14 sec
#  44%|████▍     | 4/9 [01:37<03:00, 36.17s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 486 rows, 58806 columns and 117612 nonzeros
# Model fingerprint: 0x6da57d8e
# Variable types: 0 continuous, 58806 integer (58806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Presolve time: 0.09s
# Presolved: 486 rows, 58806 columns, 117612 nonzeros
# Variable types: 0 continuous, 58806 integer (58806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 241
#
# Root relaxation: objective 1.645000e+03, 1522 iterations, 0.09 seconds (0.10 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 74
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1645.00000    0    -          - 1645.00000      -     -    4s
#      0     0 1645.00000    0   28          - 1645.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 48
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 67
#      0     0 1645.00000    0   28          - 1645.00000      -     -   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 120
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 51
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 55
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 42
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 35
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 57
#      0     0 1645.00000    0    -          - 1645.00000      -     -   16s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 123
#      0     0 1645.00000    0    -          - 1645.00000      -     -   17s
#      0     0 1645.00000    0   16          - 1645.00000      -     -   17s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 49
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 116
#      0     0 1645.00000    0   16          - 1645.00000      -     -   21s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 184
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 104
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 104
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
#      0     2 1645.00000    0    8          - 1645.00000      -     -   30s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 10
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 89
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 15
#      3     0 1645.00000    1    -          - 1645.00000      -   6.0   38s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 79
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 94
# Separation round!
# Separation round!
# *    5     2               1    1645.0000000 1645.00000  0.00%   5.2   46s
# Separation round!
#
# Cutting planes:
#   Lazy constraints: 25
#
# Explored 7 nodes (9642 simplex iterations) in 49.10 seconds (1.51 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1645
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.645000000000e+03, best bound 1.645000000000e+03, gap 0.0000%
#
# User-callback calls 543, time in user-callback 47.47 sec
#  56%|█████▌    | 5/9 [02:27<02:44, 41.11s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 586 rows, 85556 columns and 171112 nonzeros
# Model fingerprint: 0x4931b378
# Variable types: 0 continuous, 85556 integer (85556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 119
# Presolve time: 0.12s
# Presolved: 586 rows, 85556 columns, 171112 nonzeros
# Variable types: 0 continuous, 85556 integer (85556 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 291
#
# Root relaxation: objective 1.807000e+03, 2075 iterations, 0.14 seconds (0.18 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 88
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1807.00000    0    -          - 1807.00000      -     -    7s
#      0     0 1807.00000    0   58          - 1807.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 195
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 120
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 84
#      0     0 1807.00000    0   58          - 1807.00000      -     -   15s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 60
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.111 < 1)
# 	Set size: 5
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 47
# 	Found a subset which violate a SEC (flow = 0.222 < 1)
# 	Set size: 36
# 	Found a subset which violate a SEC (flow = 0.111 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.889 < 1)
# 	Set size: 17
#      0     0 1807.00000    0    -          - 1807.00000      -     -   21s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 280
#      0     0 1807.00000    0    -          - 1807.00000      -     -   23s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39
#      0     0 1807.00000    0    -          - 1807.00000      -     -   27s
#      0     0 1807.00000    0   14          - 1807.00000      -     -   27s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 179
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 62
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 288
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 138
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 157
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 95
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 88
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 111
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 52
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 183
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 20
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 18
# Separation round!
# *    0     0               0    1807.0000000 1807.00000  0.00%     -   78s
#
# Cutting planes:
#   Lazy constraints: 27
#
# Explored 1 nodes (14346 simplex iterations) in 78.39 seconds (3.45 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1807
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.807000000000e+03, best bound 1.807000000000e+03, gap 0.0000%
#
# User-callback calls 651, time in user-callback 74.35 sec
#  67%|██████▋   | 6/9 [03:46<02:42, 54.15s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 686 rows, 117306 columns and 234612 nonzeros
# Model fingerprint: 0x14b563ff
# Variable types: 0 continuous, 117306 integer (117306 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 195
# Presolve time: 0.19s
# Presolved: 686 rows, 117306 columns, 234612 nonzeros
# Variable types: 0 continuous, 117306 integer (117306 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 341
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.860000e+02   0.000000e+00      6s
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity      0.0000000e+00      6s
#        1       1045   2.1400000e+08   1.0500000e+02      6s
#        2       1449   2.1000000e+08   2.0900000e+02      6s
#        3       1755   2.0400001e+08   3.0950000e+02      6s
#        4       1960   1.9800002e+08   4.0250000e+02      6s
#        5       2179   1.9400002e+08   5.9050001e+02      6s
#        6       2398   1.9000003e+08   6.8549945e+02      6s
#        7       2605   1.8600004e+08   7.7050001e+02      6s
#        8       2826   1.8400004e+08   8.6250002e+02      6s
#        9       3027   1.8200005e+08   9.5350003e+02      6s
#       10       3246   1.7400009e+08   1.0295000e+03      6s
#       11       3443   1.6600013e+08   1.1004987e+03      6s
#       12       3638   1.6200014e+08   1.1749988e+03      6s
#       13       3853   1.5800016e+08   1.2399983e+03      6s
#       14       4138   1.5400017e+08   1.3094996e+03      6s
#       15       4651   1.4200026e+08   1.3724984e+03      6s
#       16       5211   1.3400031e+08   1.4394974e+03      6s
#       17       5646   1.3200033e+08   1.4964975e+03      6s
#       18       6209   1.2400039e+08   1.6104976e+03      6s
#       19       6627   1.2200040e+08   1.6609976e+03      6s
#       20       7189   1.2200039e+08   1.7219995e+03      6s
#       21       7911   1.2000042e+08   1.7589998e+03      6s
#       22       8742   8.8000762e+07   1.8029955e+03      6s
#       23       9123   3.4001395e+07   1.6950203e+03      6s
#       24       9514   1.8464893e+03   1.6950423e+03      6s
#       25      10350   1.8444904e+03   1.6951028e+03      6s
#       26      10789   1.8434908e+03   1.7698468e+03      6s
#       27      11200   1.8434908e+03   1.8534934e+03      6s
#
# Sifting complete
#
#    11533    2.0710000e+03   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 2.071000e+03, 11533 iterations, 0.48 seconds (0.40 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 100
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2071.00000    0    -          - 2071.00000      -     -   11s
#      0     0 2071.00000    0   46          - 2071.00000      -     -   11s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 249
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 142
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 301
#      0     0 2071.00000    0   46          - 2071.00000      -     -   21s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 102
#      0     0 2071.00000    0   46          - 2071.00000      -     -   25s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.571 < 1)
# 	Set size: 73
# 	Found a subset which violate a SEC (flow = 0.571 < 1)
# 	Set size: 29
#      0     0 2071.00000    0    -          - 2071.00000      -     -   32s
#      0     0 2071.00000    0    8          - 2071.00000      -     -   32s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 78
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 105
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 113
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 80
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#      0     0 2071.00000    0    8          - 2071.00000      -     -   43s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 327
#      0     0 2071.00000    0    8          - 2071.00000      -     -   45s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 76
#      0     0 2071.00000    0    8          - 2071.00000      -     -   50s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#      0     0 2071.00000    0    8          - 2071.00000      -     -   55s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 266
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 34
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 29
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 272
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 205
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 341
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 196
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 62
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 56
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 249
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 100
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 174
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 58
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 31
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 266
#      0     2 2071.00000    0    8          - 2071.00000      -     -  100s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 117
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 126
#      1     4 2071.00000    1   12          - 2071.00000      -   148  107s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 108
#      3     6 2071.00000    2    -          - 2071.00000      -  71.0  122s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 115
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
#      5     7 2071.00000    2   12          - 2071.00000      -  51.0  138s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 169
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 22
#      7     4 2071.00000    2   10          - 2071.00000      -  40.7  152s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 130
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 194
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 73
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 246
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 99
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 22
#     12     8 2071.00000    3   21          - 2071.00000      -  54.7  182s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 46
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 147
#     14     9 2071.00000    3    -          - 2071.00000      -  48.0  197s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 112
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 55
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 28
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 195
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 82
#     18    13 2071.00000    3    8          - 2071.00000      -  37.6  230s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#     19    13 2071.00000    4   12          - 2071.00000      -  35.9  239s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#     20    13 2071.00000    3   14          - 2071.00000      -  35.1  251s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 236
#     22     5 2071.00000    3    -          - 2071.00000      -  37.3  267s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 47
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 279
#     24     7 2071.00000    3    -          - 2071.00000      -  44.5  278s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 129
#     25     8 2071.00000    3    -          - 2071.00000      -  49.0  284s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 98
#     26     9 2071.00000    4    -          - 2071.00000      -  58.6  291s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 154
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 23
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 260
#
# Cutting planes:
#   Lazy constraints: 62
#
# Explored 30 nodes (23673 simplex iterations) in 307.70 seconds (6.56 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 2.071000000000e+03, gap -
#
# User-callback calls 1181, time in user-callback 299.80 sec
#  78%|███████▊  | 7/9 [08:55<04:34, 137.43s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 786 rows, 154056 columns and 308112 nonzeros
# Model fingerprint: 0x2d4a9105
# Variable types: 0 continuous, 154056 integer (154056 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
# Presolve time: 0.27s
# Presolved: 786 rows, 154056 columns, 308112 nonzeros
# Variable types: 0 continuous, 154056 integer (154056 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 391
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.860000e+02   0.000000e+00     11s
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity      0.0000000e+00     11s
#        1        916   3.1800000e+08   1.3861596e-01     11s
#        2       2106   1.8000033e+08   2.3414066e-01     11s
#        3       3098   1.7200039e+08   2.9626145e-01     11s
#        4       4168   1.3600067e+08   3.1880950e-01     11s
#        5       5116   1.3200071e+08   3.5276476e-01     11s
#        6       6163   9.2001172e+07   3.6328437e-01     11s
#        7       7190   3.8001842e+07   3.8509738e-01     11s
#        8       8134   2.6002003e+07   3.9243947e-01     11s
#        9       9072   2.4271304e+03   4.9892262e-01     11s
#       10      10067   2.4271304e+03   8.5684326e-01     11s
#       11      11144   2.4271304e+03   1.0889434e+00     11s
#       12      12180   2.4031313e+03   1.4329815e+00     11s
#       13      13112   2.4031313e+03   1.5748217e+00     11s
#       14      14386   2.3951324e+03   2.1113684e+00     11s
#       15      15506   2.3951320e+03   2.4409025e+00     11s
#       16      16674   2.3891320e+03   3.0247959e+00     11s
#       17      17844   2.3891318e+03   3.5063371e+00     11s
#       18      19307   2.3831274e+03   5.0031869e+00     11s
#       19      20598   2.3831270e+03   1.7880846e+03     11s
#       20      21631   2.3831268e+03   2.2816708e+03     11s
#
# Sifting complete
#
#    22554    2.3830000e+03   0.000000e+00   0.000000e+00     11s
#
# Root relaxation: objective 2.383000e+03, 22554 iterations, 0.77 seconds (0.53 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 165
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2383.00000    0    -          - 2383.00000      -     -   17s
#      0     0 2383.00000    0   86          - 2383.00000      -     -   17s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 242
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 358
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 43
#      0     0 2383.00000    0   86          - 2383.00000      -     -   35s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 16
#      0     0 2383.00000    0    -          - 2383.00000      -     -   46s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 34
#      0     0 2383.00000    0    -          - 2383.00000      -     -   53s
#      0     0 2383.00000    0   18          - 2383.00000      -     -   54s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 23
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 369
#      0     0 2383.00000    0   18          - 2383.00000      -     -   66s
# Separation round!
# H    0     0                    2383.0000000 2383.00000  0.00%     -   75s
#      0     0 2383.00000    0   18 2383.00000 2383.00000  0.00%     -   75s
#
# Cutting planes:
#   Lazy constraints: 9
#
# Explored 1 nodes (41738 simplex iterations) in 75.79 seconds (2.29 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2383
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.383000000000e+03, best bound 2.383000000000e+03, gap 0.0000%
#
# User-callback calls 851, time in user-callback 72.18 sec
#  89%|████████▉ | 8/9 [10:13<01:58, 118.46s/it]
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 886 rows, 195806 columns and 391612 nonzeros
# Model fingerprint: 0xf767418b
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 320
# Presolve time: 0.45s
# Presolved: 886 rows, 195806 columns, 391612 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 441
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   8.860000e+02   0.000000e+00     13s
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity      0.0000000e+00     14s
#        1       1037   3.4800000e+08   1.3686896e-01     14s
#        2       2413   2.0800027e+08   2.5125200e-01     14s
#        3       3524   1.8800041e+08   4.2603779e-01     14s
#        4       4716   1.6000068e+08   4.7433898e-01     14s
#        5       5904   1.2200111e+08   4.9831437e-01     14s
#        6       7074   1.0200135e+08   5.5402702e-01     14s
#        7       8277   5.4001945e+07   5.4108089e-01     14s
#        8       9430   3.6002184e+07   5.3706053e-01     14s
#        9      10490   2.7550858e+03   6.1511813e-01     14s
#       10      11538   2.7550858e+03   1.0174402e+00     14s
#       11      12916   2.7400872e+03   1.3727072e+00     14s
#       12      14132   2.7400872e+03   1.6124254e+00     14s
#       13      15347   2.7400872e+03   2.2661104e+00     14s
#       14      16891   2.7320882e+03   2.6402827e+00     14s
#       15      18166   2.7260886e+03   3.9918886e+00     14s
#       16      19470   2.7200897e+03   5.5868442e+00     14s
#       17      20894   2.7200885e+03   8.7416723e+00     14s
#       18      22190   2.7200878e+03   2.5079780e+03     14s
#
# Sifting complete
#
#    23348    2.7200000e+03   0.000000e+00   0.000000e+00     14s
#
# Root relaxation: objective 2.720000e+03, 23348 iterations, 0.92 seconds (0.63 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 30
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -   25s
#      0     0 2720.00000    0   80          - 2720.00000      -     -   25s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 240
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 352
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 172
#      0     0 2720.00000    0   80          - 2720.00000      -     -   48s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.556 < 1)
# 	Set size: 18
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.111 < 1)
# 	Set size: 3
#      0     0 2720.00000    0    -          - 2720.00000      -     -   60s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 382
#      0     0 2720.00000    0    -          - 2720.00000      -     -   67s
#      0     0 2720.00000    0   18          - 2720.00000      -     -   68s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 81
# Separation round!
# H    0     0                    2720.0000000 2720.00000  0.00%     -   89s
#      0     0 2720.00000    0   18 2720.00000 2720.00000  0.00%     -   89s
#
# Cutting planes:
#   Lazy constraints: 9
#
# Explored 1 nodes (42299 simplex iterations) in 89.35 seconds (2.59 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 811, time in user-callback 85.55 sec
# 100%|██████████| 9/9 [11:44<00:00, 78.33s/it]

# %% [markdown]
# ### Output table

# %%
# !pip install pandas
# !pip install Jinja2
# Out:
# Requirement already satisfied: pandas in /Users/jonnycodd/anaconda3/envs/tsp/lib/python3.11/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in /Users/jonnycodd/anaconda3/envs/tsp/lib/python3.11/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jonnycodd/anaconda3/envs/tsp/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/jonnycodd/anaconda3/envs/tsp/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/jonnycodd/anaconda3/envs/tsp/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/jonnycodd/anaconda3/envs/tsp/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: Jinja2 in /Users/jonnycodd/anaconda3/envs/tsp/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jonnycodd/anaconda3/envs/tsp/lib/python3.11/site-packages (from Jinja2) (2.1.3)

# %%
import pandas as pd


int_df = pd.DataFrame({'time': time_list_int, 'obj': objective_list_int, 'iter': iter_list_int})
int_df['type'] = 'integer'

frac_df = pd.DataFrame({'time': time_list_frac, 'obj': objective_list_frac, 'iter': iter_list_frac})
frac_df['type'] = 'fractional'


pd.concat([int_df, frac_df], axis='rows').to_csv('question 1.csv')

latex_table_temp = pd.concat([int_df, frac_df], axis='rows')
latex_table = latex_table_temp.to_latex(index = False)

# %% [markdown]
# ### Graphing time taken to solve

# %%
# Plotting the graph of computational time
plt.figure(figsize=(10, 6))
plt.plot(vertices_list, time_list_int, marker='o', label = 'Integer Model')
plt.plot(vertices_list, time_list_frac, marker='x', label = 'Fractional Model')
plt.xlabel('Number of Vertices')
plt.ylabel('Computation Time (seconds)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Question 2
# ### Integer Implementation

# %%
# Output time and objective value for different number of vertices
time_list_none = time_list_int
time_list_2 = list()
time_list_3 = list()

objective_list_none = objective_list_int
objective_list_2 = list()
objective_list_3 = list()

iter_list_none = iter_list_int
iter_list_2 = list()
iter_list_3 = list()

# Cardinality 2
for vert in vertices_list:
    filtered_vertices = vert
    filtered_cost = {(i, j): cost_val for (i, j), cost_val in cost.items() if i < filtered_vertices and j < filtered_vertices}

    print(vert)

    i_2 = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s_2 = TspIntegerBCSolver(instance=i_2, cardinality=2.2)
    solution_2 = s_2.solve()

    if solution_2 == 'Solution not found':
        time_list_2.append(300)
        objective_list_2.append(0)
        iter_list_2.append(0)
    else:
        time_list_2.append(s_2._model.Runtime)
        objective_list_2.append(s_2._model.ObjVal)
        iter_list_2.append(solution_2.model_metrics['IterCount'])
# Out:
# 43
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 989 rows, 1806 columns and 5418 nonzeros
# Model fingerprint: 0xa097c942
# Variable types: 0 continuous, 1806 integer (1806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.03s
# Presolved: 989 rows, 1806 columns, 5418 nonzeros
# Variable types: 0 continuous, 1806 integer (1806 binary)
#
# Root relaxation: objective 3.980000e+02, 186 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  398.00000    0    -          -  398.00000      -     -    0s
#      0     0  398.00000    0    -          -  398.00000      -     -    0s
#      0     0  398.00000    0    8          -  398.00000      -     -    0s
# H    0     0                     398.0000000  398.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 17
#
# Explored 1 nodes (193 simplex iterations) in 0.34 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 398
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.980000000000e+02, best bound 3.980000000000e+02, gap 0.0000%
#
# User-callback calls 134, time in user-callback 0.14 sec
# 93
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4464 rows, 8556 columns and 25668 nonzeros
# Model fingerprint: 0x3ebf358a
# Variable types: 0 continuous, 8556 integer (8556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.05s
# Presolved: 4464 rows, 8556 columns, 25668 nonzeros
# Variable types: 0 continuous, 8556 integer (8556 binary)
#
# Root relaxation: objective 5.640000e+02, 378 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  564.00000    0    -          -  564.00000      -     -    0s
#      0     0  564.00000    0   26          -  564.00000      -     -    0s
# H    0     0                     564.0000000  564.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 36
#
# Explored 1 nodes (390 simplex iterations) in 0.52 seconds (0.07 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 564
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.640000000000e+02, best bound 5.640000000000e+02, gap 0.0000%
#
# User-callback calls 152, time in user-callback 0.35 sec
# 143
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 10439 rows, 20306 columns and 60918 nonzeros
# Model fingerprint: 0x0a791aee
# Variable types: 0 continuous, 20306 integer (20306 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.10s
# Presolved: 10439 rows, 20306 columns, 60918 nonzeros
# Variable types: 0 continuous, 20306 integer (20306 binary)
#
# Root relaxation: objective 9.070000e+02, 780 iterations, 0.03 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  907.00000    0    -          -  907.00000      -     -    0s
#      0     0  907.00000    0   68          -  907.00000      -     -    0s
#      0     0  907.00000    0    -          -  907.00000      -     -    1s
#      0     0  907.00000    0   20          -  907.00000      -     -    1s
# H    0     0                     907.0000000  907.00000  0.00%     -    1s
#      0     0  907.00000    0   20  907.00000  907.00000  0.00%     -    1s
#
# Cutting planes:
#   Lazy constraints: 57
#
# Explored 1 nodes (2029 simplex iterations) in 1.77 seconds (0.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 907
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.070000000000e+02, best bound 9.070000000000e+02, gap 0.0000%
#
# User-callback calls 252, time in user-callback 1.18 sec
# 193
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 18914 rows, 37056 columns and 111168 nonzeros
# Model fingerprint: 0x972ede78
# Variable types: 0 continuous, 37056 integer (37056 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.17s
# Presolved: 18914 rows, 37056 columns, 111168 nonzeros
# Variable types: 0 continuous, 37056 integer (37056 binary)
# Root relaxation presolved: 18962 rows, 37056 columns, 111756 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.196000e+03, 1229 iterations, 0.09 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1196.00000    0    -          - 1196.00000      -     -    1s
#      0     0 1196.00000    0    -          - 1196.00000      -     -    2s
#      0     0 1196.00000    0   22          - 1196.00000      -     -    2s
#      0     0 1196.00000    0    -          - 1196.00000      -     -    3s
#      0     0 1196.00000    0   10          - 1196.00000      -     -    4s
#      0     0 1196.00000    0   10          - 1196.00000      -     -    5s
# *    0     0               0    1196.0000000 1196.00000  0.00%     -    7s
#
# Cutting planes:
#   Lazy constraints: 102
#
# Explored 1 nodes (2666 simplex iterations) in 7.87 seconds (1.38 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1196
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.196000000000e+03, best bound 1.196000000000e+03, gap 0.0000%
#
# User-callback calls 611, time in user-callback 6.17 sec
# 243
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 29889 rows, 58806 columns and 176418 nonzeros
# Model fingerprint: 0x63ed7b77
# Variable types: 0 continuous, 58806 integer (58806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.28s
# Presolved: 29889 rows, 58806 columns, 176418 nonzeros
# Variable types: 0 continuous, 58806 integer (58806 binary)
# Root relaxation presolved: 29950 rows, 58806 columns, 177144 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.645000e+03, 1632 iterations, 0.22 seconds (0.15 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1645.00000    0    -          - 1645.00000      -     -    2s
#      0     0 1645.00000    0   39          - 1645.00000      -     -    2s
#      0     0 1645.00000    0   39          - 1645.00000      -     -    5s
#      0     0 1645.00000    0   54          - 1645.00000      -     -    6s
#      0     0 1645.00000    0    -          - 1645.00000      -     -    7s
#      0     0 1645.00000    0    8          - 1645.00000      -     -    7s
# H    0     0                    1645.0000000 1645.00000  0.00%     -    7s
#      0     0 1645.00000    0    8 1645.00000 1645.00000  0.00%     -    7s
#
# Cutting planes:
#   Lazy constraints: 89
#
# Explored 1 nodes (4552 simplex iterations) in 7.73 seconds (1.65 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1645
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.645000000000e+03, best bound 1.645000000000e+03, gap 0.0000%
#
# User-callback calls 434, time in user-callback 5.62 sec
# 293
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 43364 rows, 85556 columns and 256668 nonzeros
# Model fingerprint: 0xe13faf37
# Variable types: 0 continuous, 85556 integer (85556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.41s
# Presolved: 43364 rows, 85556 columns, 256668 nonzeros
# Variable types: 0 continuous, 85556 integer (85556 binary)
# Root relaxation presolved: 43437 rows, 85556 columns, 257556 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.02s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.807000e+03, 3517 iterations, 0.26 seconds (0.25 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1807.00000    0    -          - 1807.00000      -     -    4s
#      0     0 1807.00000    0   30          - 1807.00000      -     -    4s
#      0     0 1807.00000    0   30          - 1807.00000      -     -    7s
#      0     0 1807.00000    0    -          - 1807.00000      -     -    9s
#      0     0 1807.00000    0   14          - 1807.00000      -     -    9s
#      0     0 1807.00000    0   14          - 1807.00000      -     -   10s
# *    0     0               0    1807.0000000 1807.00000  0.00%     -   17s
#
# Cutting planes:
#   Lazy constraints: 119
#
# Explored 1 nodes (6134 simplex iterations) in 17.12 seconds (3.65 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1807
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.807000000000e+03, best bound 1.807000000000e+03, gap 0.0000%
#
# User-callback calls 954, time in user-callback 13.11 sec
# 343
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 59339 rows, 117306 columns and 351918 nonzeros
# Model fingerprint: 0xab1d62d1
# Variable types: 0 continuous, 117306 integer (117306 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.98s
# Presolved: 59339 rows, 117306 columns, 351918 nonzeros
# Variable types: 0 continuous, 117306 integer (117306 binary)
# Root relaxation presolved: 59425 rows, 117306 columns, 352944 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0930000e+03   0.000000e+00   7.093800e+04      9s
#     1848    2.0710000e+03   0.000000e+00   0.000000e+00      9s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.071000e+03, 1848 iterations, 0.32 seconds (0.22 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2071.00000    0    -          - 2071.00000      -     -   10s
# *    0     0               0    2071.0000000 2071.00000  0.00%     -   10s
#
# Cutting planes:
#   Lazy constraints: 89
#
# Explored 1 nodes (1856 simplex iterations) in 10.30 seconds (1.16 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2071
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.071000000000e+03, best bound 2.071000000000e+03, gap 0.0000%
#
# User-callback calls 439, time in user-callback 8.29 sec
# 393
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 77814 rows, 154056 columns and 462168 nonzeros
# Model fingerprint: 0x61b243b2
# Variable types: 0 continuous, 154056 integer (154056 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.81s
# Presolved: 77814 rows, 154056 columns, 462168 nonzeros
# Variable types: 0 continuous, 154056 integer (154056 binary)
# Root relaxation presolved: 77912 rows, 154056 columns, 463356 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4120000e+03   0.000000e+00   1.793000e+05      9s
#     3670    2.3830000e+03   0.000000e+00   0.000000e+00      9s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.383000e+03, 3670 iterations, 0.56 seconds (0.40 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2383.00000    0    -          - 2383.00000      -     -   11s
#      0     0 2383.00000    0    -          - 2383.00000      -     -   13s
#      0     0 2383.00000    0   43          - 2383.00000      -     -   13s
#      0     0 2383.00000    0   43          - 2383.00000      -     -   20s
#      0     0 2383.00000    0    -          - 2383.00000      -     -   24s
#      0     0 2383.00000    0    -          - 2383.00000      -     -   27s
#      0     0 2383.00000    0   21          - 2383.00000      -     -   27s
# H    0     0                    2383.0000000 2383.00000  0.00%     -   30s
#      0     0 2383.00000    0   21 2383.00000 2383.00000  0.00%     -   30s
#
# Cutting planes:
#   Lazy constraints: 123
#
# Explored 1 nodes (9184 simplex iterations) in 30.61 seconds (5.24 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2383
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.383000000000e+03, best bound 2.383000000000e+03, gap 0.0000%
#
# User-callback calls 828, time in user-callback 24.59 sec
# 443
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 98789 rows, 195806 columns and 587418 nonzeros
# Model fingerprint: 0x62ba2287
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 1.66s
# Presolved: 98789 rows, 195806 columns, 587418 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 98900 rows, 195806 columns, 588744 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 5.890e+05
#  Factor NZ  : 8.884e+05 (roughly 130 MB of memory)
#  Factor Ops : 2.348e+08 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.73337820e+05  0.00000000e+00  4.42e+01 0.00e+00  9.83e-01    16s
#    1   2.66997011e+04 -2.96786575e+03  2.81e+00 4.95e-01  1.43e-01    16s
#    2   7.91795617e+03 -5.22017747e+02  5.56e-01 2.66e-01  6.13e-02    16s
#    3   3.68788116e+03  1.38510150e+03  4.02e-02 1.31e-01  2.68e-02    16s
#    4   3.17435347e+03  2.15280822e+03  9.30e-03 4.18e-02  9.38e-03    16s
#    5   2.96842578e+03  2.42182295e+03  4.02e-03 2.20e-02  4.99e-03    17s
#    6   2.84335843e+03  2.56246964e+03  1.71e-03 1.23e-02  2.73e-03    17s
#
# Barrier performed 6 iterations in 16.68 seconds (2.04 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 1.27s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 5509 iterations, 2.05 seconds (0.57 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -   21s
#      0     0 2720.00000    0   10          - 2720.00000      -     -   21s
# H    0     0                    2720.0000000 2720.00000  0.00%     -   30s
#
# Cutting planes:
#   Lazy constraints: 127
#
# Explored 1 nodes (5779 simplex iterations) in 30.24 seconds (3.11 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 834, time in user-callback 24.52 sec

# %%
# Cardinality 3
for vert in vertices_list:
    filtered_vertices = vert
    filtered_cost = {(i, j): cost_val for (i, j), cost_val in cost.items() if i < filtered_vertices and j < filtered_vertices}

    print(vert)
    
    i_3 = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s_3 = TspIntegerBCSolver(instance=i_3, cardinality=2.3)
    solution_3 = s_3.solve()

    if solution_3 == 'Solution not found':
        time_list_3.append(300)
        objective_list_3.append(0)
        iter_list_3.append(0)
    else:
        time_list_3.append(s_3._model.Runtime)
        objective_list_3.append(s_3._model.ObjVal)
        iter_list_3.append(solution_3.model_metrics['IterCount'])
# Out:
# 43
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 13330 rows, 1806 columns and 42441 nonzeros
# Model fingerprint: 0x313eeb62
# Variable types: 0 continuous, 1806 integer (1806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve time: 0.06s
# Presolved: 13330 rows, 1806 columns, 42441 nonzeros
# Variable types: 0 continuous, 1806 integer (1806 binary)
# Found heuristic solution: objective 729.0000000
# Root relaxation presolved: 13334 rows, 1806 columns, 42861 nonzeros
#
#
# Root relaxation: objective 3.980000e+02, 174 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  398.00000    0    -  729.00000  398.00000  45.4%     -    0s
#      0     0  398.00000    0    8  729.00000  398.00000  45.4%     -    0s
# H    0     0                     398.0000000  398.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 5
#
# Explored 1 nodes (348 simplex iterations) in 0.20 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 398 729
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.980000000000e+02, best bound 3.980000000000e+02, gap 0.0000%
#
# User-callback calls 142, time in user-callback 0.04 sec
# 93
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 134230 rows, 8556 columns and 414966 nonzeros
# Model fingerprint: 0xf66c4a40
# Variable types: 0 continuous, 8556 integer (8556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve time: 0.58s
# Presolved: 134230 rows, 8556 columns, 414966 nonzeros
# Variable types: 0 continuous, 8556 integer (8556 binary)
# Found heuristic solution: objective 1631.0000000
# Root relaxation presolved: 134234 rows, 8556 columns, 416082 nonzeros
#
#
# Root relaxation: objective 5.640000e+02, 512 iterations, 0.23 seconds (0.19 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  564.00000    0    - 1631.00000  564.00000  65.4%     -    1s
# *    0     0               0     564.0000000  564.00000  0.00%     -    1s
#
# Cutting planes:
#   Lazy constraints: 5
#
# Explored 1 nodes (520 simplex iterations) in 1.51 seconds (1.39 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 564 1631
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.640000000000e+02, best bound 5.640000000000e+02, gap 0.0000%
#
# User-callback calls 292, time in user-callback 0.17 sec
# 143
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 487630 rows, 20306 columns and 1492491 nonzeros
# Model fingerprint: 0xf11b7ed7
# Variable types: 0 continuous, 20306 integer (20306 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve time: 2.73s
# Presolved: 487630 rows, 20306 columns, 1492491 nonzeros
# Variable types: 0 continuous, 20306 integer (20306 binary)
# Found heuristic solution: objective 2497.0000000
# Root relaxation presolved: 487635 rows, 20306 columns, 1498835 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root relaxation presolved: 487634 rows, 20306 columns, 1498693 nonzeros
#
# Root barrier log...
#
#
# Barrier performed 0 iterations in 8.76 seconds (4.85 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 1.71s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: objective 9.070000e+02, 892 iterations, 3.76 seconds (0.91 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  907.00000    0    - 2497.00000  907.00000  63.7%     -    9s
#      0     0  907.00000    0    - 2497.00000  907.00000  63.7%     -    9s
#      0     0  907.00000    0    - 2497.00000  907.00000  63.7%     -   10s
#      0     0  907.00000    0   23 2497.00000  907.00000  63.7%     -   10s
# H    0     0                     907.0000000  907.00000  0.00%     -   10s
#
# Cutting planes:
#   Lazy constraints: 14
#
# Explored 1 nodes (918 simplex iterations) in 10.79 seconds (5.36 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 907 2497
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.070000000000e+02, best bound 9.070000000000e+02, gap 0.0000%
#
# User-callback calls 742, time in user-callback 1.23 sec
# 193
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1198530 rows, 37056 columns and 3650016 nonzeros
# Model fingerprint: 0x9b599aed
# Variable types: 0 continuous, 37056 integer (37056 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 0 rows and 0 columns (presolve time = 5s) ...
# Presolve time: 5.41s
# Presolved: 1198530 rows, 37056 columns, 3650016 nonzeros
# Variable types: 0 continuous, 37056 integer (37056 binary)
# Found heuristic solution: objective 3136.0000000
# Root relaxation presolved: 1198535 rows, 37056 columns, 3660934 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root relaxation presolved: 1198534 rows, 37056 columns, 3660742 nonzeros
#
# Root barrier log...
#
#
# Barrier performed 0 iterations in 17.01 seconds (11.98 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 1.64s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#
# Root relaxation: objective 1.196000e+03, 1369 iterations, 6.97 seconds (2.13 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1196.00000    0    - 3136.00000 1196.00000  61.9%     -   17s
#      0     0 1196.00000    0    - 3136.00000 1196.00000  61.9%     -   18s
#      0     0 1196.00000    0    - 3136.00000 1196.00000  61.9%     -   19s
#      0     0 1196.00000    0    - 3136.00000 1196.00000  61.9%     -   19s
#      0     0 1196.00000    0   34 3136.00000 1196.00000  61.9%     -   20s
# H    0     0                    1884.0000000 1196.00000  36.5%     -   23s
#      0     0 1196.00000    0    - 1884.00000 1196.00000  36.5%     -   34s
#      0     0 1196.00000    0   14 1884.00000 1196.00000  36.5%     -   36s
# H    0     0                    1196.0000000 1196.00000  0.00%     -   39s
#
# Cutting planes:
#   Lazy constraints: 30
#
# Explored 1 nodes (2854 simplex iterations) in 39.33 seconds (19.99 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1196 1884 3136
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.196000000000e+03, best bound 1.196000000000e+03, gap 0.0000%
#
# User-callback calls 1809, time in user-callback 3.31 sec
# 243
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2391930 rows, 58806 columns and 7262541 nonzeros
# Model fingerprint: 0x639d18a6
# Variable types: 0 continuous, 58806 integer (58806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 0 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 15s) ...
# Presolve time: 18.55s
# Presolved: 2391930 rows, 58806 columns, 7262541 nonzeros
# Variable types: 0 continuous, 58806 integer (58806 binary)
# Found heuristic solution: objective 4144.0000000
# Root relaxation presolved: 2391934 rows, 58806 columns, 7272405 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Concurrent spin time: 0.23s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.645000e+03, 1848 iterations, 21.01 seconds (3.81 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1645.00000    0    - 4144.00000 1645.00000  60.3%     -   54s
#      0     0 1645.00000    0    - 4144.00000 1645.00000  60.3%     -   57s
#      0     0 1645.00000    0    - 4144.00000 1645.00000  60.3%     -   59s
#      0     0 1645.00000    0   57 4144.00000 1645.00000  60.3%     -   62s
#      0     0 1645.00000    0   57 4144.00000 1645.00000  60.3%     -   66s
#      0     0 1645.00000    0   57 4144.00000 1645.00000  60.3%     -   72s
#      0     0 1645.00000    0    - 4144.00000 1645.00000  60.3%     -  111s
#      0     0 1645.00000    0    - 4144.00000 1645.00000  60.3%     -  115s
#      0     0 1645.00000    0   24 4144.00000 1645.00000  60.3%     -  122s
# H    0     0                    1645.0000000 1645.00000  0.00%     -  135s
#
# Cutting planes:
#   Lazy constraints: 29
#
# Explored 1 nodes (4222 simplex iterations) in 135.97 seconds (40.54 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1645 4144
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.645000000000e+03, best bound 1.645000000000e+03, gap 0.0000%
#
# User-callback calls 3378, time in user-callback 9.92 sec
# 293
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4192830 rows, 85556 columns and 12705066 nonzeros
# Model fingerprint: 0x670e6c02
# Variable types: 0 continuous, 85556 integer (85556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 0 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 12s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 20s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 26s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 31s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 40s) ...
# Presolve time: 40.32s
# Presolved: 4192830 rows, 85556 columns, 12705066 nonzeros
# Variable types: 0 continuous, 85556 integer (85556 binary)
# Found heuristic solution: objective 5060.0000000
# Root relaxation presolved: 4192834 rows, 85556 columns, 12723594 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root relaxation presolved: 4192834 rows, 85556 columns, 12723594 nonzeros
#
# Root barrier log...
#
#
# Barrier performed 0 iterations in 114.18 seconds (41.72 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 2.08s
#
# Solved with dual simplex
#
# Root relaxation: objective 1.807000e+03, 2208 iterations, 52.58 seconds (7.56 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1807.00000    0    - 5060.00000 1807.00000  64.3%     -  116s
#      0     0 1807.00000    0    - 5060.00000 1807.00000  64.3%     -  121s
#      0     0 1807.00000    0    - 5060.00000 1807.00000  64.3%     -  125s
#      0     0 1807.00000    0    - 5060.00000 1807.00000  64.3%     -  130s
#      0     0 1807.00000    0   75 5060.00000 1807.00000  64.3%     -  134s
#      0     0 1807.00000    0   75 5060.00000 1807.00000  64.3%     -  138s
#      0     0 1807.00000    0   75 5060.00000 1807.00000  64.3%     -  142s
#      0     0 1807.00000    0   75 5060.00000 1807.00000  64.3%     -  146s
#      0     0 1807.00000    0   75 5060.00000 1807.00000  64.3%     -  152s
#      0     0 1807.00000    0    - 5060.00000 1807.00000  64.3%     -  227s
#      0     0 1807.00000    0   14 5060.00000 1807.00000  64.3%     -  236s
#      0     0 1807.00000    0   14 5060.00000 1807.00000  64.3%     -  279s
#      0     0 1807.00000    0   14 5060.00000 1807.00000  64.3%     -  294s
#
# Cutting planes:
#   Lazy constraints: 60
#
# Explored 1 nodes (6463 simplex iterations) in 300.41 seconds (90.24 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 5060
#
# Time limit reached
# Best objective 5.060000000000e+03, best bound 1.807000000000e+03, gap 64.2885%
#
# User-callback calls 7142, time in user-callback 23.05 sec
# 343
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 6726230 rows, 117306 columns and 20352591 nonzeros
# Model fingerprint: 0x3849083f
# Variable types: 0 continuous, 117306 integer (117306 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 0 rows and 0 columns (presolve time = 7s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 22s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 42s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 47s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 53s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 57s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 60s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 67s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 74s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 79s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 82s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 86s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 91s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 99s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 101s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 105s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 113s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 116s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 120s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 125s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 130s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 137s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 143s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 148s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 152s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 156s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 162s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 169s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 172s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 175s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 182s) ...
# Presolve time: 182.11s
# Presolved: 6726230 rows, 117306 columns, 20352591 nonzeros
# Variable types: 0 continuous, 117306 integer (117306 binary)
# Found heuristic solution: objective 6045.0000000
# Root relaxation presolved: 6726234 rows, 117306 columns, 20381401 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
#
#
# Root relaxation: time limit, 1438 iterations, 80.45 seconds (8.55 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      6045.00000    0.00000   100%     -  301s
#
# Cutting planes:
#   Lazy constraints: 4
#
# Explored 1 nodes (1438 simplex iterations) in 302.12 seconds (63.64 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 6045
#
# Time limit reached
# Best objective 6.045000000000e+03, best bound 0.000000000000e+00, gap 100.0000%
#
# User-callback calls 6528, time in user-callback 4.65 sec
# 393
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 10117130 rows, 154056 columns and 30580116 nonzeros
# Model fingerprint: 0x546a38e1
# Variable types: 0 continuous, 154056 integer (154056 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 0 rows and 0 columns (presolve time = 7s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 16s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 21s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 44s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 46s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 50s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 55s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 63s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 65s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 72s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 75s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 80s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 88s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 91s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 97s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 102s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 108s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 112s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 116s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 122s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 127s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 132s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 135s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 147s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 152s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 157s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 164s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 168s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 172s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 177s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 181s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 187s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 194s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 200s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 207s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 212s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 218s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 224s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 232s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 238s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 246s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 250s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 256s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 262s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 269s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 276s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 281s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 291s) ...
# Presolve time: 294.86s
#
# Explored 0 nodes (0 simplex iterations) in 301.38 seconds (71.76 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound -, gap -
#
# User-callback calls 6435, time in user-callback 3.31 sec
# 443
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14490530 rows, 195806 columns and 43762641 nonzeros
# Model fingerprint: 0xabe8eec8
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 0 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 17s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 23s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 37s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 40s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 46s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 53s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 55s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 60s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 65s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 70s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 75s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 80s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 95s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 100s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 105s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 110s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 115s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 125s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 125s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 131s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 142s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 151s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 161s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 169s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 178s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 192s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 201s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 209s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 211s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 220s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 227s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 234s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 241s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 247s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 250s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 260s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 271s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 276s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 285s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 293s) ...
# Presolve time: 293.27s
#
# Explored 0 nodes (0 simplex iterations) in 305.52 seconds (103.56 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound -, gap -
#
# User-callback calls 9154, time in user-callback 5.04 sec

# %% [markdown]
# ### Output to table

# %%
int_no_cons = pd.DataFrame({'time': time_list_int, 'obj': objective_list_int,  'iter': iter_list_int})
int_no_cons['type'] = 'integer'

int_card_2 = pd.DataFrame({'time': time_list_2, 'obj': objective_list_2, 'iter': iter_list_2})
int_card_2 ['type'] = 'integer'


int_card_3 = pd.DataFrame({'time': time_list_3, 'obj': objective_list_3,  'iter': iter_list_3})
int_card_3 ['type'] = 'integer'


pd.concat([int_no_cons, int_card_2, int_card_3], axis='rows').to_csv('question 2 - int.csv')

latex_table_temp = pd.concat([int_no_cons, int_card_2, int_card_3])
latex_table_2_int = latex_table_temp.to_latex(index = False)

# %% [markdown]
# ### Graph computational time

# %%
# Plotting the graph of computational time
plt.figure(figsize=(10, 6))
plt.plot(vertices_list, time_list_none, marker='o', label = "No Additional Contraints")
plt.plot(vertices_list, time_list_2, marker='x', label = "Cardinality 2 SEC")
plt.plot(vertices_list, time_list_3, marker='s', label = "Cardinality 3 SEC")
plt.xlabel('Number of Vertices')
plt.ylabel('Computation Time (seconds)')
#plt.title('Computation Time vs Number of Vertices in TSP')
plt.legend()
plt.grid(True)
plt.show()


for i in range(len(objective_list_none)):
        
        assert objective_list_none[i]==objective_list_2[i]

# %% [markdown]
# ### Fractional

# %%
time_list_none_f = time_list_frac
time_list_2_f = list()
time_list_3_f = list()

objective_list_none_f = objective_list_frac
objective_list_2_f = list()
objective_list_3_f = list()

iter_list_none_f = iter_list_frac
iter_list_2_f = list()
iter_list_3_f= list()

# Cardinality 2
for vert in vertices_list:
    filtered_vertices = vert
    filtered_cost = {(i, j): cost_val for (i, j), cost_val in cost.items() if i < filtered_vertices and j < filtered_vertices}
    print(vert)

    i_2 = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s_2 = TspFractionalBCSolver(instance=i_2, cardinality=2.2)
    solution_2 = s_2.solve()

    if solution_2 == 'Solution not found':
        time_list_2_f.append(300)
        objective_list_2_f.append(0)
        iter_list_2_f.append(0)
    else:
        time_list_2_f.append(s_2._model.Runtime)
        objective_list_2_f.append(s_2._model.ObjVal)
        iter_list_2_f.append(solution_2.model_metrics['IterCount'])
# Out:
# 43
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 989 rows, 1806 columns and 5418 nonzeros
# Model fingerprint: 0xa097c942
# Variable types: 0 continuous, 1806 integer (1806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 30
# Presolve time: 0.03s
# Presolved: 989 rows, 1806 columns, 5418 nonzeros
# Variable types: 0 continuous, 1806 integer (1806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39
#
# Root relaxation: objective 3.980000e+02, 168 iterations, 0.01 seconds (0.00 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  398.00000    0    -          -  398.00000      -     -    0s
# Separation round!
# *    0     0               0     398.0000000  398.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 2
#
# Explored 1 nodes (171 simplex iterations) in 0.35 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 398
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.980000000000e+02, best bound 3.980000000000e+02, gap 0.0000%
#
# User-callback calls 117, time in user-callback 0.29 sec
# 93
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4464 rows, 8556 columns and 25668 nonzeros
# Model fingerprint: 0x3ebf358a
# Variable types: 0 continuous, 8556 integer (8556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
# Presolve time: 0.05s
# Presolved: 4464 rows, 8556 columns, 25668 nonzeros
# Variable types: 0 continuous, 8556 integer (8556 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 87
#
# Root relaxation: objective 5.640000e+02, 387 iterations, 0.01 seconds (0.01 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 50
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  564.00000    0    -          -  564.00000      -     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
#      0     0  564.00000    0    -          -  564.00000      -     -    1s
#      0     0  564.00000    0   12          -  564.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 31
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 18
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 47
#      0     0  564.00000    0    -          -  564.00000      -     -    2s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 29
#      0     0  564.00000    0    -          -  564.00000      -     -    3s
#      0     0  564.00000    0   14          -  564.00000      -     -    3s
# Separation round!
# Separation round!
# *    0     0               0     564.0000000  564.00000  0.00%     -    3s
#
# Cutting planes:
#   Gomory: 1
#   Lazy constraints: 9
#
# Explored 1 nodes (401 simplex iterations) in 3.88 seconds (0.16 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 564
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.640000000000e+02, best bound 5.640000000000e+02, gap 0.0000%
#
# User-callback calls 234, time in user-callback 3.40 sec
# 143
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 10439 rows, 20306 columns and 60918 nonzeros
# Model fingerprint: 0x0a791aee
# Variable types: 0 continuous, 20306 integer (20306 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 51
# Presolve time: 0.09s
# Presolved: 10439 rows, 20306 columns, 60918 nonzeros
# Variable types: 0 continuous, 20306 integer (20306 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 139
#
# Root relaxation: objective 9.070000e+02, 771 iterations, 0.04 seconds (0.04 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  907.00000    0    -          -  907.00000      -     -    1s
#      0     0  907.00000    0   26          -  907.00000      -     -    1s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 42
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 33
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#      0     0  907.00000    0    -          -  907.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 129
#      0     0  907.00000    0    -          -  907.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 135
#      0     0  907.00000    0    -          -  907.00000      -     -    5s
#      0     0  907.00000    0    8          -  907.00000      -     -    5s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 107
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 62
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 18
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 111
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 73
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 105
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 137
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 92
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 93
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 67
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 61
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 44
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 96
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 38
#      0     2  907.00000    0    8          -  907.00000      -     -   11s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# Separation round!
# *    3     0               2     907.0000000  907.00000  0.00%  54.7   15s
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 35
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 93
#
# Cutting planes:
#   Lazy constraints: 26
#
# Explored 7 nodes (1662 simplex iterations) in 18.35 seconds (0.86 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 907
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.070000000000e+02, best bound 9.070000000000e+02, gap 0.0000%
#
# User-callback calls 488, time in user-callback 17.09 sec
# 193
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 18914 rows, 37056 columns and 111168 nonzeros
# Model fingerprint: 0x972ede78
# Variable types: 0 continuous, 37056 integer (37056 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 158
# Presolve time: 0.18s
# Presolved: 18914 rows, 37056 columns, 111168 nonzeros
# Variable types: 0 continuous, 37056 integer (37056 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 187
# Root relaxation presolved: 18915 rows, 37056 columns, 111198 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 1.196000e+03, 2607 iterations, 0.18 seconds (0.11 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 93
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1196.00000    0    -          - 1196.00000      -     -    2s
#      0     0 1196.00000    0   54          - 1196.00000      -     -    2s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 129
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 97
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 167
#      0     0 1196.00000    0   54          - 1196.00000      -     -    5s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 65
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.231 < 1)
# 	Set size: 33
# 	Found a subset which violate a SEC (flow = 0.462 < 1)
# 	Set size: 34
# 	Found a subset which violate a SEC (flow = 0.231 < 1)
# 	Set size: 27
# 	Found a subset which violate a SEC (flow = 0.077 < 1)
# 	Set size: 8
#      0     0 1196.00000    0    -          - 1196.00000      -     -    8s
#      0     0 1196.00000    0   26          - 1196.00000      -     -    8s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 113
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
#      0     0 1196.00000    0   26          - 1196.00000      -     -   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 28
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 152
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 181
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 8
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 105
# Separation round!
# *    0     0               0    1196.0000000 1196.00000  0.00%     -   17s
#
# Cutting planes:
#   Lazy constraints: 17
#
# Explored 1 nodes (3727 simplex iterations) in 17.14 seconds (0.95 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1196
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.196000000000e+03, best bound 1.196000000000e+03, gap 0.0000%
#
# User-callback calls 492, time in user-callback 15.44 sec
# 243
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 29889 rows, 58806 columns and 176418 nonzeros
# Model fingerprint: 0x63ed7b77
# Variable types: 0 continuous, 58806 integer (58806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Presolve time: 0.27s
# Presolved: 29889 rows, 58806 columns, 176418 nonzeros
# Variable types: 0 continuous, 58806 integer (58806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 239
# Root relaxation presolved: 29890 rows, 58806 columns, 176430 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.02s
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 1.645000e+03, 3354 iterations, 0.30 seconds (0.19 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 240
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1645.00000    0    -          - 1645.00000      -     -    4s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 171
#      0     0 1645.00000    0    -          - 1645.00000      -     -    6s
#      0     0 1645.00000    0   26          - 1645.00000      -     -    6s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 160
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 19
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 101
#      0     0 1645.00000    0   26          - 1645.00000      -     -   11s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 99
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.600 < 1)
# 	Set size: 94
# 	Found a subset which violate a SEC (flow = 0.600 < 1)
# 	Set size: 123
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 80
#      0     0 1645.00000    0    -          - 1645.00000      -     -   17s
#      0     0 1645.00000    0   22          - 1645.00000      -     -   17s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 159
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 62
#      0     0 1645.00000    0   22          - 1645.00000      -     -   24s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 77
# Separation round!
# *    0     0               0    1645.0000000 1645.00000  0.00%     -   28s
#
# Cutting planes:
#   Lazy constraints: 13
#
# Explored 1 nodes (5191 simplex iterations) in 28.35 seconds (1.92 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1645
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.645000000000e+03, best bound 1.645000000000e+03, gap 0.0000%
#
# User-callback calls 775, time in user-callback 25.81 sec
# 293
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 43364 rows, 85556 columns and 256668 nonzeros
# Model fingerprint: 0xe13faf37
# Variable types: 0 continuous, 85556 integer (85556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 72
# Presolve time: 0.39s
# Presolved: 43364 rows, 85556 columns, 256668 nonzeros
# Variable types: 0 continuous, 85556 integer (85556 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 287
# Root relaxation presolved: 43365 rows, 85556 columns, 256698 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3030090e+03   3.469387e+01   5.819215e+08      5s
#     3854    1.8070000e+03   0.000000e+00   0.000000e+00      5s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#     3854    1.8070000e+03   0.000000e+00   0.000000e+00      5s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 6s
#
#      463 PPushes remaining with PInf 0.0000000e+00                 6s
#        0 PPushes remaining with PInf 0.0000000e+00                 6s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      6s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4443    1.8070000e+03   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 1.807000e+03, 4443 iterations, 0.42 seconds (0.29 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 266
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1807.00000    0    -          - 1807.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 271
#      0     0 1807.00000    0    -          - 1807.00000      -     -    9s
#      0     0 1807.00000    0   45          - 1807.00000      -     -    9s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 196
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 264
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 128
#      0     0 1807.00000    0   45          - 1807.00000      -     -   16s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.700 < 1)
# 	Set size: 107
#      0     0 1807.00000    0   38          - 1807.00000      -     -   20s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 44
# Separation round!
# H    0     0                    1807.0000000 1807.00000  0.00%     -   27s
#      0     0 1807.00000    0   38 1807.00000 1807.00000  0.00%     -   27s
#
# Cutting planes:
#   Gomory: 1
#   Lazy constraints: 7
#
# Explored 1 nodes (4510 simplex iterations) in 27.41 seconds (1.52 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1807
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.807000000000e+03, best bound 1.807000000000e+03, gap 0.0000%
#
# User-callback calls 564, time in user-callback 25.26 sec
# 343
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 59339 rows, 117306 columns and 351918 nonzeros
# Model fingerprint: 0xab1d62d1
# Variable types: 0 continuous, 117306 integer (117306 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 195
# Presolve time: 0.57s
# Presolved: 59339 rows, 117306 columns, 351918 nonzeros
# Variable types: 0 continuous, 117306 integer (117306 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 339
# Root relaxation presolved: 59340 rows, 117306 columns, 351930 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.3961560e+03   6.376212e+01   2.016352e+09      7s
#     4093    2.0710000e+03   0.000000e+00   0.000000e+00      7s
# Concurrent spin time: 0.03s
#
# Solved with primal simplex
#     4093    2.0710000e+03   0.000000e+00   0.000000e+00      7s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 8s
#
#      628 PPushes remaining with PInf 0.0000000e+00                 8s
#        0 PPushes remaining with PInf 0.0000000e+00                 8s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      8s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4868    2.0710000e+03   0.000000e+00   0.000000e+00      8s
#
# Root relaxation: objective 2.071000e+03, 4868 iterations, 0.76 seconds (0.39 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 296
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2071.00000    0    -          - 2071.00000      -     -   10s
#      0     0 2071.00000    0   88          - 2071.00000      -     -   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 227
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 277
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 206
#      0     0 2071.00000    0   88          - 2071.00000      -     -   22s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 274
#      0     0 2071.00000    0   88          - 2071.00000      -     -   26s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.154 < 1)
# 	Set size: 34
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 219
#      0     0 2071.00000    0    -          - 2071.00000      -     -   40s
#      0     0 2071.00000    0   62          - 2071.00000      -     -   41s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.533 < 1)
# 	Set size: 122
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 97
# 	Found a subset which violate a SEC (flow = 0.067 < 1)
# 	Set size: 12
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 181
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 160
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 49
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 321
#      0     0 2071.00000    0   62          - 2071.00000      -     -   66s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 321
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 220
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 255
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 82
# Separation round!
# *    0     0               0    2071.0000000 2071.00000  0.00%     -  103s
#
# Cutting planes:
#   Lazy constraints: 21
#
# Explored 1 nodes (8283 simplex iterations) in 103.87 seconds (8.52 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2071
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.071000000000e+03, best bound 2.071000000000e+03, gap 0.0000%
#
# User-callback calls 1408, time in user-callback 93.24 sec
# 393
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 77814 rows, 154056 columns and 462168 nonzeros
# Model fingerprint: 0x61b243b2
# Variable types: 0 continuous, 154056 integer (154056 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
# Presolve time: 0.79s
# Presolved: 77814 rows, 154056 columns, 462168 nonzeros
# Variable types: 0 continuous, 154056 integer (154056 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 387
# Root relaxation presolved: 77815 rows, 154056 columns, 462198 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.2892800e+02   3.974095e+01   1.689784e+09     12s
#     4605    2.3830000e+03   0.000000e+00   0.000000e+00     13s
# Concurrent spin time: 0.06s
#
# Solved with primal simplex
#     4605    2.3830000e+03   0.000000e+00   0.000000e+00     13s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                13s
#
#      815 PPushes remaining with PInf 0.0000000e+00                13s
#        0 PPushes remaining with PInf 0.0000000e+00                13s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00     13s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5587    2.3830000e+03   0.000000e+00   0.000000e+00     13s
#
# Root relaxation: objective 2.383000e+03, 5587 iterations, 0.77 seconds (0.52 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 54
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2383.00000    0    -          - 2383.00000      -     -   20s
#      0     0 2383.00000    0   18          - 2383.00000      -     -   20s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 121
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 319
#      0     0 2383.00000    0   18          - 2383.00000      -     -   49s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 175
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 33
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 186
#      0     0 2383.00000    0    -          - 2383.00000      -     -   63s
#      0     0 2383.00000    0   36          - 2383.00000      -     -   63s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 226
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 34
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 163
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 287
#      0     0 2383.00000    0   36          - 2383.00000      -     -   98s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 375
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 149
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 30
#      0     2 2383.00000    0    8          - 2383.00000      -     -  122s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#      1     0 2383.00000    1    -          - 2383.00000      -   3.0  132s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 125
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
#      3     0 2383.00000    1    -          - 2383.00000      -   2.0  150s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 122
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
#      5     2 2383.00000    1    -          - 2383.00000      -   1.6  169s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
#      6     3 2383.00000    1   26          - 2383.00000      -  30.5  179s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
#      7     0 2383.00000    1    -          - 2383.00000      -  27.9  189s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 177
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 143
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 146
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
#     10     0 2383.00000    1    -          - 2383.00000      -  22.0  216s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 122
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 153
# Separation round!
# Separation round!
# *   13     2               1    2383.0000000 2383.00000  0.00%  17.2  252s
# Separation round!
#     14     2     cutoff    2      2383.00000 2383.00000  0.00%  30.1  262s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 119
#
# Cutting planes:
#   Lazy constraints: 31
#
# Explored 16 nodes (9924 simplex iterations) in 271.20 seconds (14.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2383
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.383000000000e+03, best bound 2.383000000000e+03, gap 0.0000%
#
# User-callback calls 1784, time in user-callback 257.69 sec
# 443
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 98789 rows, 195806 columns and 587418 nonzeros
# Model fingerprint: 0x62ba2287
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 320
# Presolve time: 1.19s
# Presolved: 98789 rows, 195806 columns, 587418 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 439
# Root relaxation presolved: 98790 rows, 195806 columns, 587430 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.04s
#
# Barrier statistics:
#  AA' NZ     : 2.927e+05
#  Factor NZ  : 4.463e+05 (roughly 70 MB of memory)
#  Factor Ops : 9.377e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.49350515e+07 -2.50180078e+03  2.57e+02 0.00e+00  1.89e+03    16s
#    1   5.43483639e+06 -3.33275341e+07  9.49e+01 1.36e-12  6.70e+02    16s
#    2   9.13191413e+05 -4.83907857e+06  1.62e+01 2.73e-12  1.02e+02    16s
#    3   7.96842626e+03 -2.68700902e+05  4.28e-03 2.96e-12  1.09e+00    16s
#    4   7.62450274e+03 -4.71815463e+04  5.09e-04 2.61e-12  2.12e-01    16s
#    5   7.38371639e+03 -2.90945747e+04  8.89e-05 1.71e-12  1.41e-01    16s
#    6   7.06035760e+03 -1.52266032e+04  1.41e-05 1.08e-12  8.62e-02    17s
#
# Barrier performed 6 iterations in 16.58 seconds (2.03 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.93s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5135    2.7200000e+03   0.000000e+00   0.000000e+00     17s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                17s
#
#      936 PPushes remaining with PInf 0.0000000e+00                17s
#        0 PPushes remaining with PInf 0.0000000e+00                17s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00     17s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6223    2.7200000e+03   0.000000e+00   0.000000e+00     17s
#
# Root relaxation: objective 2.720000e+03, 6223 iterations, 1.94 seconds (0.63 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 272
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -   26s
#      0     0 2720.00000    0    8          - 2720.00000      -     -   26s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 43
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 55
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 246
#      0     0 2720.00000    0    8          - 2720.00000      -     -   60s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 300
#      0     0 2720.00000    0    8          - 2720.00000      -     -   68s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 32
#      0     0 2720.00000    0    8          - 2720.00000      -     -   81s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 107
#      0     0 2720.00000    0    8          - 2720.00000      -     -   92s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 362
#      0     0 2720.00000    0    8          - 2720.00000      -     -  100s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 203
#      0     0 2720.00000    0    8          - 2720.00000      -     -  112s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 244
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 62
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 246
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 372
#      0     0 2720.00000    0    -          - 2720.00000      -     -  133s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
#      0     0 2720.00000    0    -          - 2720.00000      -     -  145s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
#      0     0 2720.00000    0    -          - 2720.00000      -     -  158s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
#      0     0 2720.00000    0    -          - 2720.00000      -     -  172s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
#      0     0 2720.00000    0    -          - 2720.00000      -     -  185s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
#      0     0 2720.00000    0    -          - 2720.00000      -     -  197s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#      0     0 2720.00000    0    -          - 2720.00000      -     -  210s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 18
#      0     0 2720.00000    0    -          - 2720.00000      -     -  224s
# Separation round!
# *    0     0               0    2720.0000000 2720.00000  0.00%     -  240s
#
# Cutting planes:
#   Lazy constraints: 20
#
# Explored 1 nodes (12923 simplex iterations) in 240.29 seconds (6.91 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 1345, time in user-callback 229.91 sec

# %%
# Cardinality 3
for vert in vertices_list:
    filtered_vertices = vert
    filtered_cost = {(i, j): cost_val for (i, j), cost_val in cost.items() if i < filtered_vertices and j < filtered_vertices}
    print(vert)
          
    i_3 = TspInstance(n_vertices=filtered_vertices, cost=filtered_cost)
    s_3 = TspFractionalBCSolver(instance=i_3, cardinality=2.3)
    solution_3 = s_3.solve()

    if solution_3 == 'Solution not found':
        time_list_3_f.append(300)
        objective_list_3_f.append(0)
        iter_list_3_f.append(0)
    else:
        time_list_3_f.append(s_3._model.Runtime)
        objective_list_3_f.append(s_3._model.ObjVal)
        iter_list_3_f.append(solution_3.model_metrics['IterCount'])
# Out:
# 43
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 13330 rows, 1806 columns and 42441 nonzeros
# Model fingerprint: 0x313eeb62
# Variable types: 0 continuous, 1806 integer (1806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 30
# Presolve time: 0.07s
# Presolved: 13330 rows, 1806 columns, 42441 nonzeros
# Variable types: 0 continuous, 1806 integer (1806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 18
# Separation round!
# Found heuristic solution: objective 729.0000000
# Root relaxation presolved: 13331 rows, 1806 columns, 42747 nonzeros
#
#
# Root relaxation: objective 3.980000e+02, 177 iterations, 0.04 seconds (0.02 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  398.00000    0    -  729.00000  398.00000  45.4%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
#      0     0  398.00000    0    -  729.00000  398.00000  45.4%     -    0s
#      0     0  398.00000    0   30  729.00000  398.00000  45.4%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 22
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.143 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.857 < 1)
# 	Set size: 5
# 	Found a subset which violate a SEC (flow = 0.857 < 1)
# 	Set size: 5
# Separation round!
# *    0     0               0     398.0000000  398.00000  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 1
#   Zero half: 1
#   Lazy constraints: 7
#
# Explored 1 nodes (189 simplex iterations) in 1.04 seconds (0.16 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 398 729
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.980000000000e+02, best bound 3.980000000000e+02, gap 0.0000%
#
# User-callback calls 197, time in user-callback 0.74 sec
# 93
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 134230 rows, 8556 columns and 414966 nonzeros
# Model fingerprint: 0xf66c4a40
# Variable types: 0 continuous, 8556 integer (8556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
# Presolve time: 0.66s
# Presolved: 134230 rows, 8556 columns, 414966 nonzeros
# Variable types: 0 continuous, 8556 integer (8556 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 29
# Separation round!
# Found heuristic solution: objective 1631.0000000
# Root relaxation presolved: 134231 rows, 8556 columns, 415778 nonzeros
#
#
# Root relaxation: objective 5.640000e+02, 512 iterations, 0.22 seconds (0.19 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 8
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  564.00000    0    - 1631.00000  564.00000  65.4%     -    2s
# Separation round!
# *    0     0               0     564.0000000  564.00000  0.00%     -    2s
#
# Cutting planes:
#   Lazy constraints: 2
#
# Explored 1 nodes (520 simplex iterations) in 2.60 seconds (1.40 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 564 1631
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.640000000000e+02, best bound 5.640000000000e+02, gap 0.0000%
#
# User-callback calls 292, time in user-callback 1.27 sec
# 143
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 487630 rows, 20306 columns and 1492491 nonzeros
# Model fingerprint: 0xf11b7ed7
# Variable types: 0 continuous, 20306 integer (20306 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 51
# Presolve time: 2.47s
# Presolved: 487630 rows, 20306 columns, 1492491 nonzeros
# Variable types: 0 continuous, 20306 integer (20306 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 101
# Separation round!
# Found heuristic solution: objective 2497.0000000
# Root relaxation presolved: 487631 rows, 20306 columns, 1494213 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root relaxation presolved: 487630 rows, 20306 columns, 1494071 nonzeros
#
# Root barrier log...
#
#
# Barrier performed 0 iterations in 11.09 seconds (4.96 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 2.71s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: objective 9.070000e+02, 1167 iterations, 5.08 seconds (1.02 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 104
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  907.00000    0    - 2497.00000  907.00000  63.7%     -   11s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 109
#      0     0  907.00000    0    - 2497.00000  907.00000  63.7%     -   12s
#      0     0  907.00000    0   12 2497.00000  907.00000  63.7%     -   12s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 45
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 60
#      0     0  907.00000    0   12 2497.00000  907.00000  63.7%     -   15s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 16
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 92
#      0     0  907.00000    0    - 2497.00000  907.00000  63.7%     -   19s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 87
#      0     0  907.00000    0    - 2497.00000  907.00000  63.7%     -   20s
#      0     0  907.00000    0   44 2497.00000  907.00000  63.7%     -   21s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 94
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 90
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 14
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 16
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.050 < 1)
# 	Set size: 7
#      0     0  907.00000    0    - 2497.00000  907.00000  63.7%     -   26s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
#      0     0  907.00000    0    - 2497.00000  907.00000  63.7%     -   27s
# Separation round!
# *    0     0               0     907.0000000  907.00000  0.00%     -   28s
#
# Cutting planes:
#   Gomory: 2
#   Lazy constraints: 15
#
# Explored 1 nodes (1824 simplex iterations) in 28.62 seconds (8.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 907 2497
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.070000000000e+02, best bound 9.070000000000e+02, gap 0.0000%
#
# User-callback calls 1103, time in user-callback 10.43 sec
# 193
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1198530 rows, 37056 columns and 3650016 nonzeros
# Model fingerprint: 0x9b599aed
# Variable types: 0 continuous, 37056 integer (37056 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 158
# Presolve removed 0 rows and 0 columns (presolve time = 5s) ...
# Presolve time: 5.81s
# Presolved: 1198530 rows, 37056 columns, 3650016 nonzeros
# Variable types: 0 continuous, 37056 integer (37056 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 141
# Separation round!
# Found heuristic solution: objective 3136.0000000
# Root relaxation presolved: 1198531 rows, 37056 columns, 3652668 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Concurrent spin time: 0.56s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#
# Root relaxation: objective 1.196000e+03, 1244 iterations, 5.38 seconds (1.97 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 143
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1196.00000    0    - 3136.00000 1196.00000  61.9%     -   19s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
#      0     0 1196.00000    0    - 3136.00000 1196.00000  61.9%     -   20s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 57
#      0     0 1196.00000    0    - 3136.00000 1196.00000  61.9%     -   22s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
#      0     0 1196.00000    0    - 3136.00000 1196.00000  61.9%     -   24s
#      0     0 1196.00000    0   12 3136.00000 1196.00000  61.9%     -   25s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 32
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
# Separation round!
# H    0     0                    1884.0000000 1196.00000  36.5%     -   31s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 44
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 83
#      0     0 1196.00000    0    - 1884.00000 1196.00000  36.5%     -   45s
# Separation round!
# *    0     0               0    1196.0000000 1196.00000  0.00%     -   47s
#
# Cutting planes:
#   Lazy constraints: 9
#
# Explored 1 nodes (2685 simplex iterations) in 47.81 seconds (17.72 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1196 1884 3136
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.196000000000e+03, best bound 1.196000000000e+03, gap 0.0000%
#
# User-callback calls 1662, time in user-callback 15.11 sec
# 243
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2391930 rows, 58806 columns and 7262541 nonzeros
# Model fingerprint: 0x639d18a6
# Variable types: 0 continuous, 58806 integer (58806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Presolve removed 0 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 15s) ...
# Presolve time: 16.23s
# Presolved: 2391930 rows, 58806 columns, 7262541 nonzeros
# Variable types: 0 continuous, 58806 integer (58806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 194
# Separation round!
# Found heuristic solution: objective 4144.0000000
# Root relaxation presolved: 2391931 rows, 58806 columns, 7264893 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Concurrent spin time: 1.11s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#
# Root relaxation: objective 1.645000e+03, 1792 iterations, 16.14 seconds (3.73 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 147
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1645.00000    0    - 4144.00000 1645.00000  60.3%     -   51s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 38
#      0     0 1645.00000    0    - 4144.00000 1645.00000  60.3%     -   56s
#      0     0 1645.00000    0   26 4144.00000 1645.00000  60.3%     -   57s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 153
#      0     0 1645.00000    0   26 4144.00000 1645.00000  60.3%     -   62s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 8
#      0     0 1645.00000    0   26 4144.00000 1645.00000  60.3%     -   67s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 52
#      0     0 1645.00000    0   26 4144.00000 1645.00000  60.3%     -   71s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 25
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 3
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 10
#      0     0 1645.00000    0    - 4144.00000 1645.00000  60.3%     -  104s
# Separation round!
# *    0     0               0    1645.0000000 1645.00000  0.00%     -  109s
#
# Cutting planes:
#   Lazy constraints: 9
#
# Explored 1 nodes (3713 simplex iterations) in 109.31 seconds (33.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1645 4144
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.645000000000e+03, best bound 1.645000000000e+03, gap 0.0000%
#
# User-callback calls 3010, time in user-callback 24.51 sec
# 293
# Set parameter TimeLimit to value 300
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4192830 rows, 85556 columns and 12705066 nonzeros
# Model fingerprint: 0x670e6c02
# Variable types: 0 continuous, 85556 integer (85556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 72
# Presolve removed 0 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 12s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 20s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 40s) ...
# Presolve time: 40.22s
# Presolved: 4192830 rows, 85556 columns, 12705066 nonzeros
# Variable types: 0 continuous, 85556 integer (85556 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 233
# Separation round!
# Found heuristic solution: objective 5060.0000000
# Root relaxation presolved: 4192831 rows, 85556 columns, 12708606 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root relaxation presolved: 4192831 rows, 85556 columns, 12708606 nonzeros
#
# Root barrier log...
#
#
# Barrier performed 0 iterations in 136.37 seconds (42.02 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 4.37s
#
# Solved with dual simplex
#
# Root relaxation: objective 1.807000e+03, 2280 iterations, 63.86 seconds (7.87 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 232
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1807.00000    0    - 5060.00000 1807.00000  64.3%     -  140s
#      0     0 1807.00000    0   22 5060.00000 1807.00000  64.3%     -  144s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 145
#      0     0 1807.00000    0   22 5060.00000 1807.00000  64.3%     -  151s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 252
#      0     0 1807.00000    0   22 5060.00000 1807.00000  64.3%     -  157s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 43
#      0     0 1807.00000    0   22 5060.00000 1807.00000  64.3%     -  166s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 69
#      0     0 1807.00000    0   22 5060.00000 1807.00000  64.3%     -  175s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 70
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 157
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 61
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 102

# %% [markdown]
# ### Output to table

# %%
frac_no_cons = pd.DataFrame({'time': time_list_frac, 'obj': objective_list_frac,  'iter': iter_list_frac})
frac_no_cons['type'] = 'integer'

frac_card_2 = pd.DataFrame({'time': time_list_2_f, 'obj': objective_list_2_f, 'iter': iter_list_2_f})
frac_card_2 ['type'] = 'integer'


frac_card_3 = pd.DataFrame({'time': time_list_3_f, 'obj': objective_list_3_f, 'iter': iter_list_3_f})
frac_card_3 ['type'] = 'integer'


pd.concat([frac_no_cons, frac_card_2, frac_card_3], axis='rows').to_csv('question 2 - frac.csv')

latex_table_temp = pd.concat([frac_no_cons, frac_card_2, frac_card_3]
latex_table_2_int = latex_table_temp.to_latex(index = False)

# %% [markdown]
# ### Graph

# %%
plt.figure(figsize=(10, 6))
plt.plot(vertices_list, time_list_none_f, marker='o', label = "No Additional Contraints")
plt.plot(vertices_list, time_list_2_f, marker='x', label = "Cardinality 2 SEC")
plt.plot(vertices_list, time_list_3_f, marker='s', label = "Cardinality 3 SEC")
plt.xlabel('Number of Vertices')
plt.ylabel('Computation Time (seconds)')
#plt.title('Computation Time vs Number of Vertices in TSP')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/rossfleming/Documents/GitHub/tsp_project/master file.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(10, 6))
#       <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X45sZmlsZQ%3D%3D?line=1'>2</a> plt.plot(vertices_list, time_list_none_f, marker='o', label = "No Additional Contraints")
#       <a href='vscode-notebook-cell:/Users/rossfleming/Documents/GitHub/tsp_project/master%20file.ipynb#X45sZmlsZQ%3D%3D?line=2'>3</a> plt.plot(vertices_list, time_list_2_f, marker='x', label = "Cardinality 2 SEC")
#
# NameError: name 'plt' is not defined

# %%
# Check how many times cardinality constraints where violated
for entry in s_2.lazy_constraints_added:
    subtour = entry['subtour']
    constraint = entry['constraint']
    
    # Check if the subtour length is exactly 2
    if len(subtour) == 2:
        # The subtour contains exactly two vertices i and j
        i, j = subtour
        # The corresponding constraint is for i to j and j to i
        print(f"Lazy constraint for subtour {subtour}")

# %%
# Check how many times cardinality constraints where violated
for entry in s.lazy_constraints_added:
    subtour = entry['subtour']
    constraint = entry['constraint']
    

    # Check if the subtour length is exactly 2
    if len(subtour) == 3:
        # The subtour contains exactly two vertices i and j
        i, j, k = subtour
        # The corresponding constraint is for i to j and j to i
        print(f"Lazy constraint for subtour {subtour}")
# Out:
# Lazy constraint for subtour [45, 88, 110]
# Lazy constraint for subtour [162, 195, 275]
# Lazy constraint for subtour [160, 161, 162]
# Lazy constraint for subtour [0, 317, 316]
# Lazy constraint for subtour [1, 308, 306]

# %% [markdown]
# # Question 3

# %% [markdown]
# ## Integer

# %%
i = TspInstance(n_vertices=n_vertices, cost=cost, closest_vertices_array=closest_vertices_array)
solver = TspIntegerBCSolver(instance=i, cardinality=None)
solution = solver.solve()
No_cardinality = solver._model.Runtime

solver = TspFractionalBCSolver(instance=i, cardinality=None)
solution = solver.solve()
No_cardinality_frac = solver._model.Runtime
# Out:
# 196249
# EXPLICIT
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-12
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 886 rows, 195806 columns and 391612 nonzeros
# Model fingerprint: 0xf767418b
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.17s
# Presolved: 886 rows, 195806 columns, 391612 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity      0.0000000e+00      5s
#        1       1027   3.3000000e+08   1.4219039e-01      5s
#        2       2524   2.0600028e+08   2.5568452e-01      5s
#        3       3572   1.8600044e+08   5.2890655e-01      5s
#        4       4747   1.5600073e+08   5.4835000e-01      5s
#        5       5818   1.5000079e+08   6.3555867e-01      5s
#        6       6953   1.0400133e+08   9.4306010e+01      5s
#        7       8126   5.4001953e+07   8.9322049e+01      5s
#        8       9365   2.6002333e+07   8.7376135e+01      5s
#        9      10531   2.7581215e+03   8.7695513e+01      5s
#       10      11619   2.7581214e+03   8.7972592e+01      5s
#       11      12801   2.7581214e+03   8.8144064e+01      5s
#       12      14070   2.7371237e+03   8.8484330e+01      5s
#       13      15250   2.7371237e+03   8.8648074e+01      5s
#       14      16632   2.7241258e+03   8.9605263e+01      5s
#       15      18027   2.7141261e+03   9.1897003e+01      5s
#       16      19560   2.7131252e+03   9.4098532e+01      5s
#       17      21168   2.7131243e+03   1.8774188e+03      5s
#       18      22508   2.7131241e+03   2.5327374e+03      5s
#
# Sifting complete
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    23644    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.720000e+03, 23644 iterations, 0.52 seconds (0.65 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0  103          - 2720.00000      -     -    6s
#      0     0 2720.00000    0  103          - 2720.00000      -     -   11s
#      0     0 2720.00000    0    -          - 2720.00000      -     -   16s
#      0     0 2720.00000    0   14          - 2720.00000      -     -   16s
# H    0     0                    2720.0000000 2720.00000  0.00%     -   17s
#      0     0 2720.00000    0   14 2720.00000 2720.00000  0.00%     -   17s
#
# Cutting planes:
#   Lazy constraints: 254
#
# Explored 1 nodes (25485 simplex iterations) in 17.18 seconds (3.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 607, time in user-callback 15.07 sec
# 17.181227922439575

# %%
# Looping through different cardinality constraints
pairs = [(3.2, 3), (3.2, 4), (3.2, 5), (3.3, 4), (3.3, 5), (3.4, 5)]
solve_time_q3 = list()
iter_q3 = list()
objective_list_q3 = list()


for cardinality, l in pairs:
    solver = TspIntegerBCSolver(instance=i, cardinality=cardinality, l=l)
    solution = solver.solve()

    if solution == 'Solution not found':
        solve_time_q3.append(300)
        iter_q3.append(0)
        objective_list_q3.append(0)

    else:
        solve_time_q3.append(solver._model.Runtime)
        iter_q3.append(solution.model_metrics['IterCount'])
        objective_list_q3.append(solver._model.ObjVal)
# Out:
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2215 rows, 195806 columns and 394270 nonzeros
# Model fingerprint: 0x5c03eefe
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 14 rows and 0 columns
# Presolve time: 0.21s
# Presolved: 2201 rows, 195806 columns, 394242 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 2420 rows, 195806 columns, 394704 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 11061 iterations, 0.18 seconds (0.26 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   33          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   33          - 2720.00000      -     -   11s
#      0     0 2720.00000    0    -          - 2720.00000      -     -   16s
# *    0     0               0    2720.0000000 2720.00000  0.00%     -   17s
#
# Cutting planes:
#   Lazy constraints: 240
#
# Explored 1 nodes (47671 simplex iterations) in 17.46 seconds (4.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 528, time in user-callback 15.35 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2658 rows, 195806 columns and 395156 nonzeros
# Model fingerprint: 0x87b8bbaf
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 24 rows and 0 columns
# Presolve time: 0.21s
# Presolved: 2634 rows, 195806 columns, 395108 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 2851 rows, 195806 columns, 395586 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 10389 iterations, 0.18 seconds (0.27 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   35          - 2720.00000      -     -    6s
# H    0     0                    2720.0000000 2720.00000  0.00%     -    9s
#
# Cutting planes:
#   Lazy constraints: 229
#
# Explored 1 nodes (10585 simplex iterations) in 9.78 seconds (1.56 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 373, time in user-callback 8.91 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3101 rows, 195806 columns and 396042 nonzeros
# Model fingerprint: 0xc52dd3a8
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 38 rows and 0 columns
# Presolve time: 0.21s
# Presolved: 3063 rows, 195806 columns, 395966 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 3278 rows, 195806 columns, 396460 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 11326 iterations, 0.19 seconds (0.28 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   56          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   56          - 2720.00000      -     -   10s
# H    0     0                    2720.0000000 2720.00000  0.00%     -   11s
#      0     0 2720.00000    0   56 2720.00000 2720.00000  0.00%     -   11s
#
# Cutting planes:
#   Lazy constraints: 229
#
# Explored 1 nodes (11344 simplex iterations) in 11.23 seconds (1.52 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 444, time in user-callback 10.29 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 7974 rows, 195806 columns and 411104 nonzeros
# Model fingerprint: 0x67fa220d
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 98 rows and 0 columns
# Presolve time: 0.21s
# Presolved: 7876 rows, 195806 columns, 410834 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 8093 rows, 195806 columns, 411312 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 9957 iterations, 0.21 seconds (0.35 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   49          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   49          - 2720.00000      -     -   11s
#      0     0 2720.00000    0    -          - 2720.00000      -     -   15s
#      0     0 2720.00000    0   12          - 2720.00000      -     -   15s
# H    0     0                    2720.0000000 2720.00000  0.00%     -   19s
#      0     0 2720.00000    0   12 2720.00000 2720.00000  0.00%     -   19s
#
# Cutting planes:
#   Lazy constraints: 245
#
# Explored 1 nodes (28452 simplex iterations) in 19.39 seconds (4.71 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 739, time in user-callback 16.67 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 11961 rows, 195806 columns and 422622 nonzeros
# Model fingerprint: 0xf1b179a0
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 196 rows and 0 columns
# Presolve time: 0.23s
# Presolved: 11765 rows, 195806 columns, 422072 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 11980 rows, 195806 columns, 422566 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.7390000e+03   1.000000e+00   2.914933e+06      5s
#     8713    2.7200000e+03   0.000000e+00   0.000000e+00      5s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 8713 iterations, 0.21 seconds (0.34 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    6s
#      0     0 2720.00000    0   48          - 2720.00000      -     -    7s
#      0     0 2720.00000    0   48          - 2720.00000      -     -   12s
#      0     0 2720.00000    0    -          - 2720.00000      -     -   16s
# *    0     0               0    2720.0000000 2720.00000  0.00%     -   16s
#
# Cutting planes:
#   Lazy constraints: 243
#
# Explored 1 nodes (29341 simplex iterations) in 16.65 seconds (4.74 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 566, time in user-callback 14.18 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38541 rows, 195806 columns and 528942 nonzeros
# Model fingerprint: 0xeb48c79c
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 700 rows and 0 columns
# Presolve time: 0.30s
# Presolved: 37841 rows, 195806 columns, 526376 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Root relaxation presolved: 38056 rows, 195806 columns, 526870 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.59s
#
# Barrier performed 0 iterations in 5.68 seconds (1.64 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.56s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#
# Root relaxation: objective 2.720000e+03, 4748 iterations, 0.84 seconds (0.60 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    7s
#      0     0 2720.00000    0   30          - 2720.00000      -     -    7s
#      0     0 2720.00000    0   30          - 2720.00000      -     -   12s
#      0     0 2720.00000    0    -          - 2720.00000      -     -   14s
# *    0     0               0    2720.0000000 2720.00000  0.00%     -   15s
#
# Cutting planes:
#   Lazy constraints: 228
#
# Explored 1 nodes (33615 simplex iterations) in 15.11 seconds (5.41 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 676, time in user-callback 12.02 sec

# %% [markdown]
# ### Graph

# %%
# Convert pairs to string format for labeling
pairs_2 = [(2, 3), (2, 4), (2, 5), (3, 4), (3, 5), (4, 5)]
pair_labels = [f"({card}, {l})" for card, l in pairs_2]

# Plotting computational time
plt.figure(figsize=(10, 6))
plt.bar(pair_labels, solve_time_q3, color='skyblue')
plt.hlines(No_cardinality, xmin=-0.5, xmax=len(pair_labels)-0.5, colors='red', label='No added constraints')
plt.xlabel('K, L Pairs')
plt.ylabel('Solve Time (Seconds)')
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.legend()
plt.show()

# %% [markdown]
# # Fractional

# %%
# Looping through different cardinality constraints
pairs = [(3.2, 3), (3.2, 4), (3.2, 5), (3.3, 4), (3.3, 5), (3.4, 5)]
solve_time_q3_frac = list()
iter_q3_frac = list()
objective_list_q3_frac = list()

for cardinality, l in pairs:
    solver = TspFractionalBCSolver(instance=i, cardinality=cardinality, len = l)
    solution = solver.solve()

    if solution == 'Solution not found':
        solve_time_q3.append(300)
        iter_q3.append(0)
        objective_list_q3_frac.append(0)
        nrows_list_q3_frac.append(0)
    else:
        solve_time_q3_frac.append(solver._model.Runtime)
        iter_q3_frac.append(solution.model_metrics['IterCount'])
        objective_list_q3_frac.append(solver._model.ObjVal)
        nrows_list_q3_frac.append(solver._model.NumConstrs)
# Out:
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2215 rows, 195806 columns and 394270 nonzeros
# Model fingerprint: 0x5c03eefe
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 320
# Presolve removed 14 rows and 0 columns
# Presolve time: 0.22s
# Presolved: 2201 rows, 195806 columns, 394242 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 441
# Root relaxation presolved: 2202 rows, 195806 columns, 394244 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.7719000e+02   1.028701e+02   2.196071e+09      5s
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1787    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#      399 DPushes remaining with DInf 0.0000000e+00                 5s
#        0 DPushes remaining with DInf 0.0000000e+00                 5s
#
#      454 PPushes remaining with PInf 0.0000000e+00                 5s
#        0 PPushes remaining with PInf 0.0000000e+00                 5s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      5s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2585    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.720000e+03, 2585 iterations, 0.36 seconds (0.44 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 329
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    8s
#      0     0 2720.00000    0   62          - 2720.00000      -     -    8s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 100
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 162
#      0     0 2720.00000    0   62          - 2720.00000      -     -   23s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 133
#      0     0 2720.00000    0   62          - 2720.00000      -     -   28s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.636 < 1)
# 	Set size: 221
# 	Found a subset which violate a SEC (flow = 0.727 < 1)
# 	Set size: 124
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 93
#      0     0 2720.00000    0    -          - 2720.00000      -     -   37s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 131
#      0     0 2720.00000    0    -          - 2720.00000      -     -   42s
#      0     0 2720.00000    0   14          - 2720.00000      -     -   42s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 30
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 126
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 35
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 343
#      0     0 2720.00000    0   14          - 2720.00000      -     -   50s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 439
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 117
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 23
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 119
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 105
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 313
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 282
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 117
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 96
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 163
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 142
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# Separation round!
# *    0     0               0    2720.0000000 2720.00000  0.00%     -  120s
#
# Cutting planes:
#   Lazy constraints: 29
#
# Explored 1 nodes (25342 simplex iterations) in 120.17 seconds (8.44 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 834, time in user-callback 115.60 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2658 rows, 195806 columns and 395156 nonzeros
# Model fingerprint: 0x87b8bbaf
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 320
# Presolve removed 24 rows and 0 columns
# Presolve time: 0.21s
# Presolved: 2634 rows, 195806 columns, 395108 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 441
# Root relaxation presolved: 2635 rows, 195806 columns, 395110 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.9963700e+02   1.074375e+02   2.245823e+09      5s
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1772    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#      398 DPushes remaining with DInf 0.0000000e+00                 5s
#        0 DPushes remaining with DInf 0.0000000e+00                 5s
#
#      373 PPushes remaining with PInf 0.0000000e+00                 5s
#        0 PPushes remaining with PInf 0.0000000e+00                 5s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      5s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2462    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.720000e+03, 2462 iterations, 0.37 seconds (0.49 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 94
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -   10s
#      0     0 2720.00000    0   40          - 2720.00000      -     -   10s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 185
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 116
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 356
#      0     0 2720.00000    0   40          - 2720.00000      -     -   22s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 351
#      0     0 2720.00000    0   40          - 2720.00000      -     -   25s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 54
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 63
# 	Found a subset which violate a SEC (flow = 0.875 < 1)
# 	Set size: 33
#      0     0 2720.00000    0    -          - 2720.00000      -     -   31s
#      0     0 2720.00000    0   10          - 2720.00000      -     -   31s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 247
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 80
#      0     0 2720.00000    0   10          - 2720.00000      -     -   40s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 47
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 420
#      0     0 2720.00000    0   10          - 2720.00000      -     -   49s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 54
#      0     0 2720.00000    0   10          - 2720.00000      -     -   54s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 253
#      0     0 2720.00000    0   10          - 2720.00000      -     -   58s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 403
#      0     0 2720.00000    0   10          - 2720.00000      -     -   60s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 23
#      0     0 2720.00000    0   10          - 2720.00000      -     -   66s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 201
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 397
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 178
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 129
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 126
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 77
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 409
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 201
#      0     2 2720.00000    0    8          - 2720.00000      -     -  100s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 206
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 142
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 70
#      2     4 2720.00000    1   18          - 2720.00000      -   250  110s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
#      3     6 2720.00000    2   12          - 2720.00000      -   272  117s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
#      7     4 2720.00000    3    -          - 2720.00000      -   141  142s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 63
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 63
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 63
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 194
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 194
#     12     9 2720.00000    3   12          - 2720.00000      -  88.0  169s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 80
#     13     9 2720.00000    3   10          - 2720.00000      -  95.5  174s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 10
#     14     1 2720.00000    3    -          - 2720.00000      -   112  181s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 66
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 197
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 331
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 211
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 419
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 310
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 405
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
#     22     7 2720.00000    3    -          - 2720.00000      -  91.0  213s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 190
#     23     8 2720.00000    4   12          - 2720.00000      -  92.4  218s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.600 < 1)
# 	Set size: 304
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 13
#     24     8 2720.00000    4   22          - 2720.00000      -   102  221s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 190
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 152
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 272
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 17
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 138
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
#     30    10 2720.00000    3    -          - 2720.00000      -  85.4  252s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
#     31    11 2720.00000    5   12          - 2720.00000      -  86.3  259s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 92
#     32    11 2720.00000    5    -          - 2720.00000      -  92.0  264s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 131
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 10
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 324
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
#     37    15 2720.00000    2   16          - 2720.00000      -  87.1  291s
# Separation round!
# Separation round!
# *   38    11               3    2720.0000000 2720.00000  0.00%  84.8  305s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 347
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 286
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 265
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 187
#     43    11     cutoff    4      2720.00000 2720.00000  0.00%  83.2  326s
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 351
#
# Cutting planes:
#   Lazy constraints: 65
#
# Explored 46 nodes (23817 simplex iterations) in 335.99 seconds (19.67 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 2625, time in user-callback 326.29 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3101 rows, 195806 columns and 396042 nonzeros
# Model fingerprint: 0xc52dd3a8
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 320
# Presolve removed 38 rows and 0 columns
# Presolve time: 0.23s
# Presolved: 3063 rows, 195806 columns, 395966 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 441
# Root relaxation presolved: 3064 rows, 195806 columns, 395968 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.0134600e+02   2.187061e+02   2.425471e+09      5s
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1797    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#      397 DPushes remaining with DInf 0.0000000e+00                 5s
#        0 DPushes remaining with DInf 0.0000000e+00                 5s
#
#      348 PPushes remaining with PInf 0.0000000e+00                 5s
#        0 PPushes remaining with PInf 0.0000000e+00                 5s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      5s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2487    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.720000e+03, 2487 iterations, 0.36 seconds (0.46 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 427
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    7s
#      0     0 2720.00000    0   20          - 2720.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 109
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 199
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 388
#      0     0 2720.00000    0   20          - 2720.00000      -     -   18s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 180
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 187
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 108
#      0     0 2720.00000    0    -          - 2720.00000      -     -   28s
#      0     0 2720.00000    0   28          - 2720.00000      -     -   28s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.600 < 1)
# 	Set size: 86
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 31
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 28
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 13
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 406
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 101
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 200
#      0     0 2720.00000    0   28          - 2720.00000      -     -   45s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 72
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 331
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 80
#      0     2 2720.00000    0    8          - 2720.00000      -     -   61s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 74
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 30
#      1     4 2720.00000    1   28          - 2720.00000      -   261   67s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 30
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
#      3     2 2720.00000    2    -          - 2720.00000      -   180   79s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
#      4     3 2720.00000    2    -          - 2720.00000      -   156   86s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
#      5     4 2720.00000    2    -          - 2720.00000      -   158   92s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.600 < 1)
# 	Set size: 67
#      6     5 2720.00000    2   26          - 2720.00000      -   145   98s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 11
#      7     4 2720.00000    2    -          - 2720.00000      -   125  104s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 61
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 17
#      8     5 2720.00000    2   14          - 2720.00000      -   110  110s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 110
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 17
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 17
#     11     7 2720.00000    3   22          - 2720.00000      -  81.3  128s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 329
#     12     0 2720.00000    2    -          - 2720.00000      -  79.4  131s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 80
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 163
#     14     2 2720.00000    3    -          - 2720.00000      -  76.9  141s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 147
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 305
#     16     4 2720.00000    4    -          - 2720.00000      -  78.1  149s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 245
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 251
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 179
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 119
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 229
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 13
#     19    10 2720.00000    2   20          - 2720.00000      -  79.9  165s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 279
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 69
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 78
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 19
#     21    10 2720.00000    3   16          - 2720.00000      -  99.0  174s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 95
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 98
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 134
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 19
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 67
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 246
#     26    18 2720.00000    3    -          - 2720.00000      -  89.7  202s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 106
#     27    19 2720.00000    5   16          - 2720.00000      -  90.6  207s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#     28    19 2720.00000    4   16          - 2720.00000      -  88.8  213s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 82
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 67
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
#     31    19 2720.00000    4   20          - 2720.00000      -  88.5  231s
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 50
# Separation round!
#     34    17 2720.00000    3    8          - 2720.00000      -  88.4  251s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 390
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 261
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 295
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 356
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 157
# Separation round!
# Separation round!
# *   42    22               4    2720.0000000 2720.00000  0.00%  84.1  294s
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 163
# Separation round!
#     45    22     cutoff    6      2720.00000 2720.00000  0.00%  84.8  312s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 76
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 67
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 306
#     48    22     cutoff    4      2720.00000 2720.00000  0.00%  92.8  327s
# Separation round!
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 252
#
# Cutting planes:
#   Lazy constraints: 66
#
# Explored 52 nodes (23362 simplex iterations) in 344.06 seconds (16.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 1584, time in user-callback 335.98 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 7974 rows, 195806 columns and 411104 nonzeros
# Model fingerprint: 0x67fa220d
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 320
# Presolve removed 98 rows and 0 columns
# Presolve time: 0.29s
# Presolved: 7876 rows, 195806 columns, 410834 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 441
# Root relaxation presolved: 7877 rows, 195806 columns, 410836 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.9963700e+02   1.074375e+02   2.223573e+09      5s
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2343    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 5s
#
#      441 PPushes remaining with PInf 0.0000000e+00                 5s
#        0 PPushes remaining with PInf 0.0000000e+00                 5s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      5s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3118    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.720000e+03, 3118 iterations, 0.43 seconds (0.55 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 417
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    7s
#      0     0 2720.00000    0   36          - 2720.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 325
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 83
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 273
#      0     0 2720.00000    0   36          - 2720.00000      -     -   19s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 227
#      0     0 2720.00000    0   36          - 2720.00000      -     -   23s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.833 < 1)
# 	Set size: 378
# 	Found a subset which violate a SEC (flow = 0.167 < 1)
# 	Set size: 51
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
#      0     0 2720.00000    0    -          - 2720.00000      -     -   31s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 82
#      0     0 2720.00000    0    -          - 2720.00000      -     -   37s
#      0     0 2720.00000    0   16          - 2720.00000      -     -   37s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 30
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 62
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 308
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 367
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 77
#      0     0 2720.00000    0   16          - 2720.00000      -     -   54s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 69
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 152
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 304
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 190
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 124
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 10
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 80
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 294
# Separation round!
# H    0     0                    2720.0000000 2720.00000  0.00%     -  100s
#
# Cutting planes:
#   Lazy constraints: 23
#
# Explored 1 nodes (21944 simplex iterations) in 100.09 seconds (9.76 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 1287, time in user-callback 94.73 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 11961 rows, 195806 columns and 422622 nonzeros
# Model fingerprint: 0xf1b179a0
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 320
# Presolve removed 196 rows and 0 columns
# Presolve time: 0.26s
# Presolved: 11765 rows, 195806 columns, 422072 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 441
# Root relaxation presolved: 11766 rows, 195806 columns, 422074 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.0134600e+02   2.187061e+02   2.411972e+09      5s
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2601    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#      365 DPushes remaining with DInf 0.0000000e+00                 5s
#        0 DPushes remaining with DInf 0.0000000e+00                 5s
#
#      415 PPushes remaining with PInf 0.0000000e+00                 5s
#        0 PPushes remaining with PInf 0.0000000e+00                 5s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      5s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3320    2.7200000e+03   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.720000e+03, 3320 iterations, 0.44 seconds (0.62 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 386
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    7s
#      0     0 2720.00000    0   40          - 2720.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 278
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 394
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 235
#      0     0 2720.00000    0   40          - 2720.00000      -     -   17s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 419
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 351
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 56
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 77
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 380
#      0     0 2720.00000    0    -          - 2720.00000      -     -   24s
#      0     0 2720.00000    0   10          - 2720.00000      -     -   24s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 243
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 59
#      0     0 2720.00000    0   10          - 2720.00000      -     -   34s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 235
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 211
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 47
#      0     0 2720.00000    0   10          - 2720.00000      -     -   55s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 61
#      0     0 2720.00000    0   10          - 2720.00000      -     -   60s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 277
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 349
#      0     0 2720.00000    0   10          - 2720.00000      -     -   67s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 281
#      0     0 2720.00000    0   10          - 2720.00000      -     -   70s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 63
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 344
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 52
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 31
# Separation round!
# H    0     0                    2720.0000000 2720.00000  0.00%     -   98s
#
# Cutting planes:
#   Lazy constraints: 24
#
# Explored 1 nodes (20830 simplex iterations) in 98.19 seconds (8.58 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2720
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+03, best bound 2.720000000000e+03, gap 0.0000%
#
# User-callback calls 1553, time in user-callback 93.46 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38541 rows, 195806 columns and 528942 nonzeros
# Model fingerprint: 0xeb48c79c
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 320
# Presolve removed 700 rows and 0 columns
# Presolve time: 0.31s
# Presolved: 37841 rows, 195806 columns, 526376 nonzeros
# Variable types: 0 continuous, 195806 integer (195806 binary)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 441
# Root relaxation presolved: 37842 rows, 195806 columns, 526378 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.36s
#
# Barrier statistics:
#  Dense cols : 99
#  AA' NZ     : 1.030e+06
#  Factor NZ  : 3.939e+06 (roughly 100 MB of memory)
#  Factor Ops : 1.018e+09 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.50614401e+07  0.00000000e+00  9.09e+02 0.00e+00  1.35e+02     6s
#    1   5.47257236e+06 -1.18059107e+05  2.20e+02 1.65e+01  3.00e+01     6s
#    2   9.76960212e+05 -7.53996464e+04  3.96e+01 4.96e-01  5.16e+00     6s
#
# Barrier performed 2 iterations in 5.80 seconds (1.77 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.36s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2258    2.7200000e+03   0.000000e+00   0.000000e+00      6s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 6s
#
#      423 PPushes remaining with PInf 0.0000000e+00                 6s
#        0 PPushes remaining with PInf 0.0000000e+00                 6s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      6s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2946    2.7200000e+03   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 2.720000e+03, 2946 iterations, 0.90 seconds (0.90 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 423
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2720.00000    0    -          - 2720.00000      -     -    7s
#      0     0 2720.00000    0   60          - 2720.00000      -     -    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 121
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 184
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 295
#      0     0 2720.00000    0   60          - 2720.00000      -     -   20s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.857 < 1)
# 	Set size: 280
# 	Found a subset which violate a SEC (flow = 0.714 < 1)
# 	Set size: 172
#      0     0 2720.00000    0    -          - 2720.00000      -     -   36s
#      0     0 2720.00000    0   20          - 2720.00000      -     -   36s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 355
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 394
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 162
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 202
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39

# %% [markdown]
# ### Graph

# %%
# Convert pairs to string format for labeling
pairs_2 = [(2, 3), (2, 4), (2, 5), (3, 4), (3, 5), (4, 5)]
pair_labels = [f"({card}, {l})" for card, l in pairs_2]

# Plotting computational time
plt.figure(figsize=(10, 6))
plt.bar(pair_labels, solve_time_q3_frac, color='skyblue')
plt.hlines(No_cardinality_frac, xmin=-0.5, xmax=len(pair_labels)-0.5, colors='red', label='No added constraints')
plt.xlabel('K, L Pairs')
plt.ylabel('Solve Time (Seconds)')
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.show()

# %% [markdown]
# ### Table

# %%
int_q3 = pd.DataFrame({'time': solve_time_q3, 'obj': objective_list_q3, 'rows': nrows_list_q3, 'iter': iter_q3})
int_q3['type'] = 'integer'

frac_q3 = pd.DataFrame({'time': solve_time_q3_frac, 'obj': objective_list_q3_frac, 'rows': nrows_list_q3_frac, 'iter': iter_q3_frac})
frac_q3['type'] = 'fractional'


pd.concat([int_q3, frac_q3], axis='rows').to_csv('question 3')

latex_table_temp = pd.concat([int_q3, frac_q3], axis='rows')
latex_table_3_frac = latex_table_temp.to_latex(index = False)
